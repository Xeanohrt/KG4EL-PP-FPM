# %% [markdown]
# # Transforming the Meta-DataFrame into a Neo4j Event Log Class Diagram Graph
# The following script demonstrates how the Meta-DataFrame can be modelled in Neo4j as an Event Log Class Diagram Graph of a given event log.

# %%
# import the libraries
import json
import pandas as pd
import numpy
import re #regular expressions for working with text data, especially extracting information from a piece of text

# %%
# Change the title names to circumvent certain Neo4j whitespace issues. The index_to_neo4j dictionary  maps keys will map the values from the Meta-DataFrame to the Neo4j graph later
index_to_neo4j = {
    'Title': 'title',
    'Data_type': 'data_type',
    'Number_of_entries': 'num_entries',
    'Number_of_unique_entries': 'num_unique_entries',
    'Number_of_duplicate_entries':'num_duplicate_entries',
    'Number_of_undefined_entries': 'num_undefined_entries',
    'Percentage_of_undefined_entries': 'percentage_undefined_entries',
}
index_to_neo4j
# Out:
# {'Title': 'title',
#  'Data_type': 'data_type',
#  'Number_of_entries': 'num_entries',
#  'Number_of_unique_entries': 'num_unique_entries',
#  'Number_of_duplicate_entries': 'num_duplicate_entries',
#  'Number_of_undefined_entries': 'num_undefined_entries',
#  'Percentage_of_undefined_entries': 'percentage_undefined_entries'}

# %%
#Define the Meta-DataFrame and generate the first command to clear any related event data in Neo4j
event_log_name = 'BPI_C_2019_1_final_synthetic' #change accordingly for each EL
print('// Delete all nodes and their relationships:')
print(f'MATCH (node:{event_log_name}) DETACH DELETE node;')
print()
# Out:
# // Delete all nodes and their relationships:
# MATCH (node:BPI_C_2019_1_final_synthetic) DETACH DELETE node;

# %%
#Import the event log Meta-DataFrame based on event_log_name above
overview_table = pd.read_csv(f'analysis/overview_{event_log_name}.csv', index_col = 'Property') #use Property as the index_column
overview_table = overview_table.T #switch table layout
overview_table
# Out:
# Property                                                                                       caseID  \
# Unnamed: 0                                                                                          0
# BPI_C_2019_1st_Supplier                                                       BPI_C_2019_1st_Supplier
# Title                                                                                         Case ID
# Importance                                                                        Mandatory attribute
# Level                                                                                      Case level
# Data type                                                                                      string
# Number of entries                                                                              349524
# Number of unique entries                                                                        73329
# List up to 100 unique entries to view the struc...  ['4507004931 20', '4507004931 10', '4507004931...
# Length of the list of up to 100 unique entries                                                    100
# Number of duplicate entries                                                                    276195
# Number of undefined entries                                                                         0
# Percentage of undefined entries                                                                   0.0
#
# Property                                                                         event time:timestamp  \
# Unnamed: 0                                                                                          1
# BPI_C_2019_1st_Supplier                                                       BPI_C_2019_1st_Supplier
# Title                                                                                       Timestamp
# Importance                                                                        Mandatory attribute
# Level                                                                                     Event level
# Data type                                                                              datetime64[ns]
# Number of entries                                                                              349524
# Number of unique entries                                                                        41898
# List up to 100 unique entries to view the struc...  [numpy.datetime64('1948-01-26T23:59:00.0000000...
# Length of the list of up to 100 unique entries                                                    100
# Number of duplicate entries                                                                    307626
# Number of undefined entries                                                                         0
# Percentage of undefined entries                                                                   0.0
#
# Property                                                                           event concept:name  \
# Unnamed: 0                                                                                          2
# BPI_C_2019_1st_Supplier                                                       BPI_C_2019_1st_Supplier
# Title                                                                                        Activity
# Importance                                                                        Mandatory attribute
# Level                                                                                     Event level
# Data type                                                                                      string
# Number of entries                                                                              349524
# Number of unique entries                                                                           39
# List up to 100 unique entries to view the struc...  ['Vendor creates invoice', 'Vendor creates deb...
# Length of the list of up to 100 unique entries                                                     39
# Number of duplicate entries                                                                    349485
# Number of undefined entries                                                                         0
# Percentage of undefined entries                                                                   0.0
#
# Property                                                                                     eventID   \
# Unnamed: 0                                                                                          3
# BPI_C_2019_1st_Supplier                                                       BPI_C_2019_1st_Supplier
# Title                                                                                        Event ID
# Importance                                                                        Mandatory attribute
# Level                                                                                     Event level
# Data type                                                                                     float64
# Number of entries                                                                              349524
# Number of unique entries                                                                        73538
# List up to 100 unique entries to view the struc...  [65781700000000.0, 65777400000000.0, 657946000...
# Length of the list of up to 100 unique entries                                                    100
# Number of duplicate entries                                                                    275986
# Number of undefined entries                                                                         0
# Percentage of undefined entries                                                                   0.0
#
# Property                                                                         case Spend area text  \
# Unnamed: 0                                                                                          4
# BPI_C_2019_1st_Supplier                                                       BPI_C_2019_1st_Supplier
# Title                                                                            case Spend area text
# Importance                                                                       Additional attribute
# Level                                                                                      Case level
# Data type                                                                                      string
# Number of entries                                                                              349524
# Number of unique entries                                                                           20
# List up to 100 unique entries to view the struc...  ['Sales', 'Trading & End Products', 'Logistics...
# Length of the list of up to 100 unique entries                                                     21
# Number of duplicate entries                                                                    349504
# Number of undefined entries                                                                      2323
# Percentage of undefined entries                                                                  0.66
#
# Property                                                                                 case Company  \
# Unnamed: 0                                                                                          5
# BPI_C_2019_1st_Supplier                                                       BPI_C_2019_1st_Supplier
# Title                                                                                    case Company
# Importance                                                                       Additional attribute
# Level                                                                                      Case level
# Data type                                                                                      string
# Number of entries                                                                              349524
# Number of unique entries                                                                            3
# List up to 100 unique entries to view the struc...  ['companyID_0000', 'companyID_0003', 'companyI...
# Length of the list of up to 100 unique entries                                                      3
# Number of duplicate entries                                                                    349521
# Number of undefined entries                                                                         0
# Percentage of undefined entries                                                                   0.0
#
# Property                                                                           case Document Type  \
# Unnamed: 0                                                                                          6
# BPI_C_2019_1st_Supplier                                                       BPI_C_2019_1st_Supplier
# Title                                                                              case Document Type
# Importance                                                                       Additional attribute
# Level                                                                                      Case level
# Data type                                                                                      string
# Number of entries                                                                              349524
# Number of unique entries                                                                            3
# List up to 100 unique entries to view the struc...  ['Standard PO', 'Framework order', 'EC Purchas...
# Length of the list of up to 100 unique entries                                                      3
# Number of duplicate entries                                                                    349521
# Number of undefined entries                                                                         0
# Percentage of undefined entries                                                                   0.0
#
# Property                                                                     case Sub spend area text  \
# Unnamed: 0                                                                                          7
# BPI_C_2019_1st_Supplier                                                       BPI_C_2019_1st_Supplier
# Title                                                                        case Sub spend area text
# Importance                                                                       Additional attribute
# Level                                                                                      Case level
# Data type                                                                                      string
# Number of entries                                                                              349524
# Number of unique entries                                                                          129
# List up to 100 unique entries to view the struc...  ['Products for Resale', 'Trading products (old...
# Length of the list of up to 100 unique entries                                                    100
# Number of duplicate entries                                                                    349395
# Number of undefined entries                                                                      2323
# Percentage of undefined entries                                                                  0.66
#
# Property                                                                     case Purchasing Document  \
# Unnamed: 0                                                                                          8
# BPI_C_2019_1st_Supplier                                                       BPI_C_2019_1st_Supplier
# Title                                                                        case Purchasing Document
# Importance                                                                       Additional attribute
# Level                                                                                      Case level
# Data type                                                                                       int64
# Number of entries                                                                              349524
# Number of unique entries                                                                        21961
# List up to 100 unique entries to view the struc...  [4507004931, 4507014062, 4507000647, 450700952...
# Length of the list of up to 100 unique entries                                                    100
# Number of duplicate entries                                                                    327563
# Number of undefined entries                                                                         0
# Percentage of undefined entries                                                                   0.0
#
# Property                                            case Purch. Doc. Category name  \
# Unnamed: 0                                                                       9
# BPI_C_2019_1st_Supplier                                    BPI_C_2019_1st_Supplier
# Title                                               case Purch. Doc. Category name
# Importance                                                    Additional attribute
# Level                                                                   Case level
# Data type                                                                   string
# Number of entries                                                           349524
# Number of unique entries                                                         1
# List up to 100 unique entries to view the struc...              ['Purchase order']
# Length of the list of up to 100 unique entries                                   1
# Number of duplicate entries                                                 349523
# Number of undefined entries                                                      0
# Percentage of undefined entries                                                0.0
#
# Property                                            ...  \
# Unnamed: 0                                          ...
# BPI_C_2019_1st_Supplier                             ...
# Title                                               ...
# Importance                                          ...
# Level                                               ...
# Data type                                           ...
# Number of entries                                   ...
# Number of unique entries                            ...
# List up to 100 unique entries to view the struc...  ...
# Length of the list of up to 100 unique entries      ...
# Number of duplicate entries                         ...
# Number of undefined entries                         ...
# Percentage of undefined entries                     ...
#
# Property                                            case Spend classification text  \
# Unnamed: 0                                                                      13
# BPI_C_2019_1st_Supplier                                    BPI_C_2019_1st_Supplier
# Title                                               case Spend classification text
# Importance                                                    Additional attribute
# Level                                                                   Case level
# Data type                                                                   string
# Number of entries                                                           349524
# Number of unique entries                                                         3
# List up to 100 unique entries to view the struc...    ['NPR', 'PR', <NA>, 'OTHER']
# Length of the list of up to 100 unique entries                                   4
# Number of duplicate entries                                                 349521
# Number of undefined entries                                                   2323
# Percentage of undefined entries                                               0.66
#
# Property                                                        case Source  \
# Unnamed: 0                                                               14
# BPI_C_2019_1st_Supplier                             BPI_C_2019_1st_Supplier
# Title                                                           case Source
# Importance                                             Additional attribute
# Level                                                            Case level
# Data type                                                            string
# Number of entries                                                    349524
# Number of unique entries                                                  1
# List up to 100 unique entries to view the struc...  ['sourceSystemID_0000']
# Length of the list of up to 100 unique entries                            1
# Number of duplicate entries                                          349523
# Number of undefined entries                                               0
# Percentage of undefined entries                                         0.0
#
# Property                                                                                    case Name  \
# Unnamed: 0                                                                                         15
# BPI_C_2019_1st_Supplier                                                       BPI_C_2019_1st_Supplier
# Title                                                                                       case Name
# Importance                                                                       Additional attribute
# Level                                                                                      Case level
# Data type                                                                                      string
# Number of entries                                                                              349524
# Number of unique entries                                                                         1480
# List up to 100 unique entries to view the struc...  ['vendor_0645', 'vendor_0415', 'vendor_0298', ...
# Length of the list of up to 100 unique entries                                                    100
# Number of duplicate entries                                                                    348044
# Number of undefined entries                                                                         0
# Percentage of undefined entries                                                                   0.0
#
# Property                                            case GR-Based Inv. Verif.  \
# Unnamed: 0                                                                 16
# BPI_C_2019_1st_Supplier                               BPI_C_2019_1st_Supplier
# Title                                               case GR-Based Inv. Verif.
# Importance                                               Additional attribute
# Level                                                              Case level
# Data type                                                                bool
# Number of entries                                                      349524
# Number of unique entries                                                    2
# List up to 100 unique entries to view the struc...              [False, True]
# Length of the list of up to 100 unique entries                              2
# Number of duplicate entries                                            349522
# Number of undefined entries                                                 0
# Percentage of undefined entries                                           0.0
#
# Property                                                                                    case Item  \
# Unnamed: 0                                                                                         17
# BPI_C_2019_1st_Supplier                                                       BPI_C_2019_1st_Supplier
# Title                                                                                       case Item
# Importance                                                                       Additional attribute
# Level                                                                                      Case level
# Data type                                                                                       int64
# Number of entries                                                                              349524
# Number of unique entries                                                                          321
# List up to 100 unique entries to view the struc...  [20, 10, 50, 40, 30, 90, 80, 70, 60, 1, 110, 3...
# Length of the list of up to 100 unique entries                                                    100
# Number of duplicate entries                                                                    349203
# Number of undefined entries                                                                         0
# Percentage of undefined entries                                                                   0.0
#
# Property                                                                            case concept:name  \
# Unnamed: 0                                                                                         18
# BPI_C_2019_1st_Supplier                                                       BPI_C_2019_1st_Supplier
# Title                                                                               case concept:name
# Importance                                                                       Additional attribute
# Level                                                                                      Case level
# Data type                                                                                      string
# Number of entries                                                                              349524
# Number of unique entries                                                                        73329
# List up to 100 unique entries to view the struc...  ['4507004931_00020', '4507004931_00010', '4507...
# Length of the list of up to 100 unique entries                                                    100
# Number of duplicate entries                                                                    276195
# Number of undefined entries                                                                         0
# Percentage of undefined entries                                                                   0.0
#
# Property                                                 case Goods Receipt  \
# Unnamed: 0                                                               19
# BPI_C_2019_1st_Supplier                             BPI_C_2019_1st_Supplier
# Title                                                    case Goods Receipt
# Importance                                             Additional attribute
# Level                                                            Case level
# Data type                                                              bool
# Number of entries                                                    349524
# Number of unique entries                                                  2
# List up to 100 unique entries to view the struc...            [True, False]
# Length of the list of up to 100 unique entries                            2
# Number of duplicate entries                                          349522
# Number of undefined entries                                               0
# Percentage of undefined entries                                         0.0
#
# Property                                                                                   event User  \
# Unnamed: 0                                                                                         20
# BPI_C_2019_1st_Supplier                                                       BPI_C_2019_1st_Supplier
# Title                                                                                      event User
# Importance                                                                       Additional attribute
# Level                                                                                     Event level
# Data type                                                                                      string
# Number of entries                                                                              349524
# Number of unique entries                                                                          348
# List up to 100 unique entries to view the struc...  ['NONE', 'user_329', 'user_236', 'user_124', '...
# Length of the list of up to 100 unique entries                                                    100
# Number of duplicate entries                                                                    349176
# Number of undefined entries                                                                         0
# Percentage of undefined entries                                                                   0.0
#
# Property                                                                           event org:resource  \
# Unnamed: 0                                                                                         21
# BPI_C_2019_1st_Supplier                                                       BPI_C_2019_1st_Supplier
# Title                                                                              event org:resource
# Importance                                                                       Additional attribute
# Level                                                                                     Event level
# Data type                                                                                      string
# Number of entries                                                                              349524
# Number of unique entries                                                                          348
# List up to 100 unique entries to view the struc...  ['NONE', 'user_329', 'user_236', 'user_124', '...
# Length of the list of up to 100 unique entries                                                    100
# Number of duplicate entries                                                                    349176
# Number of undefined entries                                                                         0
# Percentage of undefined entries                                                                   0.0
#
# Property                                                             event Cumulative net worth (EUR)
# Unnamed: 0                                                                                         22
# BPI_C_2019_1st_Supplier                                                       BPI_C_2019_1st_Supplier
# Title                                                                event Cumulative net worth (EUR)
# Importance                                                                       Additional attribute
# Level                                                                                     Event level
# Data type                                                                                       int64
# Number of entries                                                                              349524
# Number of unique entries                                                                        12805
# List up to 100 unique entries to view the struc...  [68, 325, 102, 72, 1856, 274, 9978, 2416, 2032...
# Length of the list of up to 100 unique entries                                                    100
# Number of duplicate entries                                                                    336719
# Number of undefined entries                                                                         0
# Percentage of undefined entries                                                                   0.0
#
# [13 rows x 23 columns]

# %%
# Gather overview_columns
overview_columns = overview_table.columns

#View
overview_columns
# Out:
# Index(['caseID', 'event time:timestamp', 'event concept:name', 'eventID ',
#        'case Spend area text', 'case Company', 'case Document Type',
#        'case Sub spend area text', 'case Purchasing Document',
#        'case Purch. Doc. Category name', 'case Vendor', 'case Item Type',
#        'case Item Category', 'case Spend classification text', 'case Source',
#        'case Name', 'case GR-Based Inv. Verif.', 'case Item',
#        'case concept:name', 'case Goods Receipt', 'event User',
#        'event org:resource', 'event Cumulative net worth (EUR)'],
#       dtype='object', name='Property')

# %% [markdown]
# <h1>Creating the Neo4j Commands</h1>
# The author hardcoded the Neo4j commands as changes could be made easily - when adjustments have to be made to the Neo4jDB instance.

# %%
# create a two lists
neo4j_lines = []
mandatory_columns = []

for overview_column in overview_columns:
  spalte = overview_table[overview_column]
  spalte_json_string = spalte.to_json(default_handler=str)
  neo4j_properties = json.loads(spalte_json_string)

  overview_level = neo4j_properties['Level']

  property_label_identifier = neo4j_properties['Importance']
  if property_label_identifier == 'Mandatory attribute':
    mandatory_columns.append(overview_column)

  properties_list_of_strings = [f'`{key}`: "{value}"' for (key, value) in neo4j_properties.items()]

  neo4j_create_command = ''
  neo4j_create_command += f'''CREATE (`{overview_column}`:`{overview_column}`:`{overview_level}`:`{property_label_identifier}`:{event_log_name} '''
  neo4j_create_command += f'''{{name: '{overview_column}', {', '.join(properties_list_of_strings)}}})'''

  neo4j_lines.append(neo4j_create_command)

neo4j_lines.append('CREATE (`caseID`) - [:CASE_TO_EVENT] -> (`eventID `)')
neo4j_lines.append('CREATE (`eventID `) - [:EVENT_RELATIONSHIP] -> (`event concept:name`)')
neo4j_lines.append('CREATE (`eventID `) - [:EVENT_RELATIONSHIP] -> (`event time:timestamp`)')

for overview_column in overview_columns:
  if overview_column not in mandatory_columns and 'event' in overview_column:
    neo4j_create_command = f'''CREATE (`eventID `) - [:EVENT_RELATIONSHIP] -> (`{overview_column}`)'''
    neo4j_lines.append(neo4j_create_command)
  if overview_column not in mandatory_columns and 'case' in overview_column:
    neo4j_create_command = f'''CREATE (`caseID`) - [:CASE_RELATIONSHIP] -> (`{overview_column}`)'''
    neo4j_lines.append(neo4j_create_command)

# To add the preceding sequence of Cypher CREATE commands.
neo4j_lines.append(';')

neo4j_command = '\n'.join(neo4j_lines)

neo4j_command = '// Create all nodes and their relationships\n' + neo4j_command

with open(f'analysis/overview_{event_log_name}.cypher', 'w') as overview_file:
  print(neo4j_command, file=overview_file)

# %%
print('// Show all nodes and their relationships:')
print(f'MATCH (event_log:{event_log_name}) RETURN event_log;')
print()
# Out:
# // Show all nodes and their relationships:
# MATCH (event_log:BPI_C_2019_1_final_synthetic) RETURN event_log;

# %%
# The case table is an exploratory acitivty to model the longest case to visualize all event contained in that case in Neo4j commands

case_table = pd.read_csv(f'analysis/longest_case_in_{event_log_name}.csv', index_col='EventIndex')
case_table
# Out:
#                   caseID event time:timestamp          event concept:name  \
# EventIndex
# 179262      4507013227 1  2018-01-03 11:29:00  Record Service Entry Sheet
# 179271      4507013227 1  2018-01-03 11:29:00  Record Service Entry Sheet
# 179270      4507013227 1  2018-01-03 11:29:00  Record Service Entry Sheet
# 179269      4507013227 1  2018-01-03 11:29:00  Record Service Entry Sheet
# 179268      4507013227 1  2018-01-03 11:29:00  Record Service Entry Sheet
# ...                  ...                  ...                         ...
# 186673      4507013227 1  2018-03-03 01:07:00  Record Service Entry Sheet
# 186672      4507013227 1  2018-03-03 01:07:00  Record Service Entry Sheet
# 186678      4507013227 1  2018-03-03 01:07:00  Record Service Entry Sheet
# 186686      4507013227 1  2018-03-03 01:08:00        Record Goods Receipt
# 186687      4507013227 1  2018-03-03 01:08:00  Record Service Entry Sheet
#
#                 eventID  case Spend area text    case Company  \
# EventIndex
# 179262      1.843310e+14            Logistics  companyID_0000
# 179271      1.843310e+14            Logistics  companyID_0000
# 179270      1.843310e+14            Logistics  companyID_0000
# 179269      1.843310e+14            Logistics  companyID_0000
# 179268      1.843310e+14            Logistics  companyID_0000
# ...                  ...                  ...             ...
# 186673      1.843310e+14            Logistics  companyID_0000
# 186672      1.843310e+14            Logistics  companyID_0000
# 186678      1.843310e+14            Logistics  companyID_0000
# 186686      1.843310e+14            Logistics  companyID_0000
# 186687      1.843310e+14            Logistics  companyID_0000
#
#            case Document Type case Sub spend area text  \
# EventIndex
# 179262            Standard PO              Road Packed
# 179271            Standard PO              Road Packed
# 179270            Standard PO              Road Packed
# 179269            Standard PO              Road Packed
# 179268            Standard PO              Road Packed
# ...                       ...                      ...
# 186673            Standard PO              Road Packed
# 186672            Standard PO              Road Packed
# 186678            Standard PO              Road Packed
# 186686            Standard PO              Road Packed
# 186687            Standard PO              Road Packed
#
#             case Purchasing Document case Purch. Doc. Category name  ...  \
# EventIndex                                                           ...
# 179262                    4507013227                 Purchase order  ...
# 179271                    4507013227                 Purchase order  ...
# 179270                    4507013227                 Purchase order  ...
# 179269                    4507013227                 Purchase order  ...
# 179268                    4507013227                 Purchase order  ...
# ...                              ...                            ...  ...
# 186673                    4507013227                 Purchase order  ...
# 186672                    4507013227                 Purchase order  ...
# 186678                    4507013227                 Purchase order  ...
# 186686                    4507013227                 Purchase order  ...
# 186687                    4507013227                 Purchase order  ...
#
#            case Spend classification text          case Source    case Name  \
# EventIndex
# 179262                                NPR  sourceSystemID_0000  vendor_0229
# 179271                                NPR  sourceSystemID_0000  vendor_0229
# 179270                                NPR  sourceSystemID_0000  vendor_0229
# 179269                                NPR  sourceSystemID_0000  vendor_0229
# 179268                                NPR  sourceSystemID_0000  vendor_0229
# ...                                   ...                  ...          ...
# 186673                                NPR  sourceSystemID_0000  vendor_0229
# 186672                                NPR  sourceSystemID_0000  vendor_0229
# 186678                                NPR  sourceSystemID_0000  vendor_0229
# 186686                                NPR  sourceSystemID_0000  vendor_0229
# 186687                                NPR  sourceSystemID_0000  vendor_0229
#
#            case GR-Based Inv. Verif. case Item case concept:name  \
# EventIndex
# 179262                          True         1  4507013227_00001
# 179271                          True         1  4507013227_00001
# 179270                          True         1  4507013227_00001
# 179269                          True         1  4507013227_00001
# 179268                          True         1  4507013227_00001
# ...                              ...       ...               ...
# 186673                          True         1  4507013227_00001
# 186672                          True         1  4507013227_00001
# 186678                          True         1  4507013227_00001
# 186686                          True         1  4507013227_00001
# 186687                          True         1  4507013227_00001
#
#             case Goods Receipt  event User event org:resource  \
# EventIndex
# 179262                    True        NONE               NONE
# 179271                    True        NONE               NONE
# 179270                    True        NONE               NONE
# 179269                    True        NONE               NONE
# 179268                    True        NONE               NONE
# ...                        ...         ...                ...
# 186673                    True        NONE               NONE
# 186672                    True        NONE               NONE
# 186678                    True        NONE               NONE
# 186686                    True    batch_02           batch_02
# 186687                    True        NONE               NONE
#
#             event Cumulative net worth (EUR)
# EventIndex
# 179262                                    71
# 179271                                    47
# 179270                                    71
# 179269                                    23
# 179268                                    94
# ...                                      ...
# 186673                                    23
# 186672                                    23
# 186678                                    71
# 186686                                 10780
# 186687                                    23
#
# [509 rows x 23 columns]

# %%
# The index of a case table is the index of an event.
# The case table is an event table that only contains events belonging to a certain case.

cypher_code = 'CREATE\n'
for event_index in case_table.index:
  event = case_table.loc[event_index]
  cypher_code += \
    f'''  (event_{event_index}:`{event['event concept:name']}` {{\n''' +\
    f'''    `caseID`: "{event['caseID']}",\n''' +\
    f'''    `event time:timestamp`: "{event['event time:timestamp']}",\n''' +\
    f'''    `event concept:name`: "{event['event concept:name']}",\n''' +\
    f'''    `eventID `: "{event['eventID ']}",\n''' +\
    f'''    `case Spend area text`: "{event['case Spend area text']}",\n''' +\
    f'''    `case Company`: "{event['case Company']}",\n''' +\
    f'''    `case Document Type`: "{event['case Document Type']}",\n''' +\
    f'''    `case Sub spend area text`: "{event['case Sub spend area text']}",\n''' +\
    f'''    `case Purchasing Document`: "{event['case Purchasing Document']}",\n''' +\
    f'''    `case Purch. Doc. Category name`: "{event['case Purch. Doc. Category name']}",\n''' +\
    f'''    `case Vendor`: "{event['case Vendor']}",\n''' +\
    f'''    `case Item Type`: "{event['case Item Type']}",\n''' +\
    f'''    `case Item Category`: "{event['case Item Category']}",\n''' +\
    f'''    `case Spend classification text`: "{event['case Spend classification text']}",\n''' +\
    f'''    `case Source`: "{event['case Source']}",\n''' +\
    f'''    `case Name`: "{event['case Name']}",\n''' +\
    f'''    `case GR-Based Inv. Verif.`: "{event['case GR-Based Inv. Verif.']}",\n''' +\
    f'''    `case Item`: "{event['case Item']}",\n''' +\
    f'''    `case concept:name`: "{event['case concept:name']}",\n''' +\
    f'''    `case Goods Receipt`: "{event['case Goods Receipt']}",\n''' +\
    f'''    `event User`: "{event['event User']}",\n''' +\
    f'''    `event org:resource`: "{event['event org:resource']}",\n''' +\
    f'''    `event Cumulative net worth (EUR)`: "{event['event Cumulative net worth (EUR)']}"\n''' +\
    f'''  }}),\n'''

for first_event_index, second_event_index in zip(case_table.index, case_table.index[1:]):
  first_event = case_table.loc[first_event_index]
  second_event = case_table.loc[second_event_index]
  cypher_code += f'''  (event_{first_event_index})-[:DIRECTLY_FOLLOWS]->(event_{second_event_index}),\n'''

# Delete the last comma symbol occurrence.
cypher_code = cypher_code[:-2]
cypher_code += '\n;'

with open(f'analysis/longest_case_in_{event_log_name}.cypher', 'w') as case_file:
  print(cypher_code, file=case_file)

# %% [markdown]
# # End of Script 2 Transforming the Meta-DataFrame into a Neo4j Event Log Class Diagram Graph
# Author: Kyle Smith <br>
# Script: For Masterthesis <br>
# University of Camerino & University of Applied Sciences Northwestern Switzerland

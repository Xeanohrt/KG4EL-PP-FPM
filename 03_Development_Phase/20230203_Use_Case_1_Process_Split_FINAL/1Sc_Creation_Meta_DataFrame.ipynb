# %% [markdown]
# # First Script: Creating the Meta-DataFrame
# In this script the author analyzes each column of the synthetic BPI_C 2019 event logs.

# %%
#import libraries
import json
import os
import pandas as pd
import numpy
import re

# %%
event_log_name = 'BPI_C_2019_3_final_synthetic' #addd the name of the event log - change for each event log
event_log_file_path = f'event_logs/{event_log_name}.csv' #string interpolation, one has to create a folder called 'event_logs' to import the event log.csv
print(event_log_file_path) # review the path
# Out:
# event_logs/BPI_C_2019_3_final_synthetic.csv

# %%
#import the event log
event_log_table = pd.read_csv(event_log_file_path) #optionally this can be added; header = 0, encoding = 'ISO-8859-1') if encoding issues arise
event_log_table.head(20) #view the first 20 rows
# Out:
# /var/folders/vz/snd73j8d2mj817493bt9ykfc0000gn/T/ipykernel_99122/3280910462.py:2: DtypeWarning: Columns (14,17) have mixed types. Specify dtype option on import or set low_memory=False.
#   event_log_table = pd.read_csv(event_log_file_path) #optionally this can be added; header = 0, encoding = 'ISO-8859-1') if encoding issues arise
#                          event time          event concept:name     event ID   \
# 0   Thu, 01 Jan 1970 00:00:25 GMT+2  Receive Order Confirmation  5.550000e+14
# 1   Thu, 01 Jan 1970 00:00:25 GMT+2  Receive Order Confirmation  5.550000e+14
# 2   Thu, 01 Jan 1970 00:00:25 GMT+2  Record Service Entry Sheet  5.580000e+14
# 3   Thu, 01 Jan 1970 00:00:25 GMT+2  Receive Order Confirmation  5.550000e+14
# 4   Thu, 01 Jan 1970 00:00:25 GMT+2  Receive Order Confirmation  5.550000e+14
# 5   Thu, 01 Jan 1970 00:00:25 GMT+2  Record Service Entry Sheet  5.580000e+14
# 6   Thu, 01 Jan 1970 00:00:25 GMT+2  Record Service Entry Sheet  5.580000e+14
# 7   Thu, 01 Jan 1970 00:00:25 GMT+2  Receive Order Confirmation  5.550000e+14
# 8   Thu, 01 Jan 1970 00:00:25 GMT+2  Receive Order Confirmation  5.550000e+14
# 9   Thu, 01 Jan 1970 00:00:25 GMT+2  Receive Order Confirmation  5.550000e+14
# 10  Thu, 01 Jan 1970 00:00:25 GMT+2  Receive Order Confirmation  5.550000e+14
# 11  Thu, 01 Jan 1970 00:00:25 GMT+2        Record Goods Receipt  5.580000e+14
# 12  Thu, 01 Jan 1970 00:00:25 GMT+2  Receive Order Confirmation  5.550000e+14
# 13  Thu, 01 Jan 1970 00:00:25 GMT+2  Receive Order Confirmation  5.550000e+14
# 14  Thu, 01 Jan 1970 00:00:25 GMT+2  Receive Order Confirmation  5.550000e+14
# 15  Thu, 01 Jan 1970 00:00:25 GMT+2  Receive Order Confirmation  5.550000e+14
# 16  Thu, 01 Jan 1970 00:00:25 GMT+2  Receive Order Confirmation  5.550000e+14
# 17  Thu, 01 Jan 1970 00:00:25 GMT+2  Create Purchase Order Item  5.580000e+14
# 18  Thu, 01 Jan 1970 00:00:25 GMT+2  Receive Order Confirmation  5.550000e+14
# 19  Thu, 01 Jan 1970 00:00:25 GMT+2  Receive Order Confirmation  5.550000e+14
#
#       case Spend area text       Company case Document Type  \
# 0      Packaging Type Case  company ID_A        Standard PO
# 1      Packaging Type Case  company ID_A        Standard PO
# 2   Supply Chain Logistics  company ID_A        Standard PO
# 3      Packaging Type Case  company ID_A        Standard PO
# 4      Packaging Type Case  company ID_A        Standard PO
# 5   Supply Chain Logistics  company ID_A        Standard PO
# 6   Supply Chain Logistics  company ID_A        Standard PO
# 7      Packaging Type Case  company ID_A        Standard PO
# 8      Packaging Type Case  company ID_A        Standard PO
# 9      Packaging Type Case  company ID_A        Standard PO
# 10     Packaging Type Case  company ID_A        Standard PO
# 11  Supply Chain Logistics  company ID_A        Standard PO
# 12     Packaging Type Case  company ID_A        Standard PO
# 13     Packaging Type Case  company ID_A        Standard PO
# 14     Packaging Type Case  company ID_A        Standard PO
# 15     Packaging Type Case  company ID_A        Standard PO
# 16     Packaging Type Case  company ID_A        Standard PO
# 17                   Sales  company ID_A        Standard PO
# 18     Packaging Type Case  company ID_A        Standard PO
# 19     Packaging Type Case  company ID_A        Standard PO
#
#    case Sub spend area text  case Purchasing Document    case Vendor  \
# 0         Packaging - Other              4.507039e+09  vendorID_0104
# 1         Packaging - Other              4.507039e+09  vendorID_0104
# 2               Road Packed              4.507039e+09  vendorID_0541
# 3         Packaging - Other              4.507039e+09  vendorID_0104
# 4         Packaging - Other              4.507039e+09  vendorID_0104
# 5               Road Packed              4.507039e+09  vendorID_0541
# 6               Road Packed              4.507039e+09  vendorID_0541
# 7         Packaging - Other              4.507039e+09  vendorID_0104
# 8         Packaging - Other              4.507039e+09  vendorID_0104
# 9         Packaging - Other              4.507039e+09  vendorID_0104
# 10        Packaging - Other              4.507039e+09  vendorID_0104
# 11              Road Packed              4.507039e+09  vendorID_0541
# 12        Packaging - Other              4.507039e+09  vendorID_0104
# 13        Packaging - Other              4.507039e+09  vendorID_0104
# 14        Packaging - Other              4.507039e+09  vendorID_0104
# 15        Packaging - Other              4.507039e+09  vendorID_0104
# 16        Packaging - Other              4.507039e+09  vendorID_0104
# 17      Products for Resale              4.507039e+09  vendorID_0724
# 18        Packaging - Other              4.507039e+09  vendorID_0104
# 19        Packaging - Other              4.507039e+09  vendorID_0104
#
#    case Item Type  ... case Spend classification text          case Source  \
# 0        Standard  ...                             PR  sourceSystemID_0000
# 1        Standard  ...                             PR  sourceSystemID_0000
# 2         Service  ...                            NPR  sourceSystemID_0000
# 3        Standard  ...                             PR  sourceSystemID_0000
# 4        Standard  ...                             PR  sourceSystemID_0000
# 5         Service  ...                            NPR  sourceSystemID_0000
# 6         Service  ...                            NPR  sourceSystemID_0000
# 7        Standard  ...                             PR  sourceSystemID_0000
# 8        Standard  ...                             PR  sourceSystemID_0000
# 9        Standard  ...                             PR  sourceSystemID_0000
# 10       Standard  ...                             PR  sourceSystemID_0000
# 11        Service  ...                            NPR  sourceSystemID_0000
# 12       Standard  ...                             PR  sourceSystemID_0000
# 13       Standard  ...                             PR  sourceSystemID_0000
# 14       Standard  ...                             PR  sourceSystemID_0000
# 15       Standard  ...                             PR  sourceSystemID_0000
# 16       Standard  ...                             PR  sourceSystemID_0000
# 17       Standard  ...                            NPR  sourceSystemID_0000
# 18       Standard  ...                             PR  sourceSystemID_0000
# 19       Standard  ...                             PR  sourceSystemID_0000
#
#       case Name C_GR-Based case Item  case concept:name case Goods Receipt  \
# 0   vendor_0104      False     220.0   4507038569_00220               True
# 1   vendor_0104      False     350.0   4507038569_00350               True
# 2   vendor_0525       True       1.0   4507038753_00001               True
# 3   vendor_0104      False     300.0   4507038569_00300               True
# 4   vendor_0104      False     210.0   4507038569_00210               True
# 5   vendor_0525       True       1.0   4507038753_00001               True
# 6   vendor_0525       True       1.0   4507038753_00001               True
# 7   vendor_0104      False     370.0   4507038569_00370               True
# 8   vendor_0104      False     340.0   4507038569_00340               True
# 9   vendor_0104      False     380.0   4507038569_00380               True
# 10  vendor_0104      False     360.0   4507038569_00360               True
# 11  vendor_0525       True       1.0   4507038753_00001               True
# 12  vendor_0104      False     240.0   4507038569_00240               True
# 13  vendor_0104      False     250.0   4507038569_00250               True
# 14  vendor_0104      False     280.0   4507038569_00280               True
# 15  vendor_0104      False     190.0   4507038569_00190               True
# 16  vendor_0104      False     200.0   4507038569_00200               True
# 17  vendor_0693      False      20.0   4507038755_00020               True
# 18  vendor_0104      False     150.0   4507038569_00150               True
# 19  vendor_0104      False     180.0   4507038569_00180               True
#
#    event User Account event org type resource Currency Costs in Dollars
# 0            user_063                user_063                      2346
# 1            user_063                user_063                     15640
# 2                NONE                    NONE                      1829
# 3            user_063                user_063                      9950
# 4            user_063                user_063                      3519
# 5                NONE                    NONE                      1829
# 6                NONE                    NONE                      3659
# 7            user_063                user_063                      2346
# 8            user_063                user_063                     11876
# 9            user_063                user_063                     15249
# 10           user_063                user_063                      3519
# 11           user_200                user_200                    554447
# 12           user_063                user_063                      9308
# 13           user_063                user_063                      1564
# 14           user_063                user_063                      1955
# 15           user_063                user_063                     12518
# 16           user_063                user_063                      6256
# 17           user_164                user_164                       519
# 18           user_063                user_063                      3128
# 19           user_063                user_063                      4814
#
# [20 rows x 21 columns]

# %%
event_log_table.columns
# Out:
# Index(['event time', 'event concept:name', 'event ID ', 'case Spend area text',
#        'Company', 'case Document Type', 'case Sub spend area text',
#        'case Purchasing Document', 'case Vendor', 'case Item Type',
#        'case Item Category', 'case Spend classification text', 'case Source',
#        'case Name', 'C_GR-Based', 'case Item', 'case concept:name',
#        'case Goods Receipt', 'event User Account', 'event org type resource',
#        'Currency Costs in Dollars'],
#       dtype='object')

# %%
event_log_table
# Out:
#                              event time          event concept:name  \
# 0       Thu, 01 Jan 1970 00:00:25 GMT+2  Receive Order Confirmation
# 1       Thu, 01 Jan 1970 00:00:25 GMT+2  Receive Order Confirmation
# 2       Thu, 01 Jan 1970 00:00:25 GMT+2  Record Service Entry Sheet
# 3       Thu, 01 Jan 1970 00:00:25 GMT+2  Receive Order Confirmation
# 4       Thu, 01 Jan 1970 00:00:25 GMT+2  Receive Order Confirmation
# ...                                 ...                         ...
# 349521  Thu, 01 Jan 1970 00:00:06 GMT+2        Record Goods Receipt
# 349522  Thu, 01 Jan 1970 00:00:06 GMT+2        Record Goods Receipt
# 349523  Thu, 01 Jan 1970 00:00:06 GMT+2        Record Goods Receipt
# 349524  Thu, 01 Jan 1970 00:00:06 GMT+2        Record Goods Receipt
# 349525  Thu, 01 Jan 1970 00:00:06 GMT+2        Record Goods Receipt
#
#            event ID     case Spend area text       Company case Document Type  \
# 0       5.550000e+14     Packaging Type Case  company ID_A        Standard PO
# 1       5.550000e+14     Packaging Type Case  company ID_A        Standard PO
# 2       5.580000e+14  Supply Chain Logistics  company ID_A        Standard PO
# 3       5.550000e+14     Packaging Type Case  company ID_A        Standard PO
# 4       5.550000e+14     Packaging Type Case  company ID_A        Standard PO
# ...              ...                     ...           ...                ...
# 349521  7.530000e+14            CAPEX & SOCS  company ID_A        Standard PO
# 349522  7.530000e+14            CAPEX & SOCS  company ID_A        Standard PO
# 349523  7.530000e+14            CAPEX & SOCS  company ID_A        Standard PO
# 349524  7.530000e+14            CAPEX & SOCS  company ID_A        Standard PO
# 349525  7.420000e+14        Latex & Monomers  company ID_A        Standard PO
#
#        case Sub spend area text  case Purchasing Document    case Vendor  \
# 0             Packaging - Other              4.507039e+09  vendorID_0104
# 1             Packaging - Other              4.507039e+09  vendorID_0104
# 2                   Road Packed              4.507039e+09  vendorID_0541
# 3             Packaging - Other              4.507039e+09  vendorID_0104
# 4             Packaging - Other              4.507039e+09  vendorID_0104
# ...                         ...                       ...            ...
# 349521         MRO (components)              4.508052e+09  vendorID_0237
# 349522         MRO (components)              4.508052e+09  vendorID_0237
# 349523         MRO (components)              4.508052e+09  vendorID_0237
# 349524         MRO (components)              4.508052e+09  vendorID_0237
# 349525           Vinyl Acrylics              4.508052e+09  vendorID_0159
#
#        case Item Type  ... case Spend classification text  \
# 0            Standard  ...                             PR
# 1            Standard  ...                             PR
# 2             Service  ...                            NPR
# 3            Standard  ...                             PR
# 4            Standard  ...                             PR
# ...               ...  ...                            ...
# 349521       Standard  ...                            NPR
# 349522       Standard  ...                            NPR
# 349523       Standard  ...                            NPR
# 349524       Standard  ...                            NPR
# 349525       Standard  ...                             PR
#
#                 case Source    case Name C_GR-Based case Item  \
# 0       sourceSystemID_0000  vendor_0104      False     220.0
# 1       sourceSystemID_0000  vendor_0104      False     350.0
# 2       sourceSystemID_0000  vendor_0525       True       1.0
# 3       sourceSystemID_0000  vendor_0104      False     300.0
# 4       sourceSystemID_0000  vendor_0104      False     210.0
# ...                     ...          ...        ...       ...
# 349521  sourceSystemID_0000  vendor_0232      False      70.0
# 349522  sourceSystemID_0000  vendor_0232      False      60.0
# 349523  sourceSystemID_0000  vendor_0232      False      50.0
# 349524  sourceSystemID_0000  vendor_0232      False      30.0
# 349525  sourceSystemID_0000  vendor_0157      False      10.0
#
#         case concept:name case Goods Receipt event User Account  \
# 0        4507038569_00220               True           user_063
# 1        4507038569_00350               True           user_063
# 2        4507038753_00001               True               NONE
# 3        4507038569_00300               True           user_063
# 4        4507038569_00210               True           user_063
# ...                   ...                ...                ...
# 349521   4508052444_00070               True           user_029
# 349522   4508052444_00060               True           user_029
# 349523   4508052444_00050               True           user_029
# 349524   4508052444_00030               True           user_029
# 349525   4508051663_00010               True           batch_03
#
#        event org type resource Currency Costs in Dollars
# 0                     user_063                      2346
# 1                     user_063                     15640
# 2                         NONE                      1829
# 3                     user_063                      9950
# 4                     user_063                      3519
# ...                        ...                       ...
# 349521                user_029                        69
# 349522                user_029                        17
# 349523                user_029                        61
# 349524                user_029                      3856
# 349525                batch_03                     44425
#
# [349526 rows x 21 columns]

# %%
# Modification 1: Add a caseID column, that is defined as a merge of two other columns based on the requirements from the TFPM webpage
'''
  The case ID is a combination of the purchase document and the purchase item.
  https://icpmconference.org/2019/icpm-2019/contests-challenges/bpi-challenge-2019/
'''
#create the caseID and add it to the event log table
event_log_table['caseID'] = event_log_table['case Purchasing Document'].astype('string') + ' ' + event_log_table['case Item Type'].astype('string')

# %%
#review changes on the last column
event_log_table
# Out:
#                              event time          event concept:name  \
# 0       Thu, 01 Jan 1970 00:00:25 GMT+2  Receive Order Confirmation
# 1       Thu, 01 Jan 1970 00:00:25 GMT+2  Receive Order Confirmation
# 2       Thu, 01 Jan 1970 00:00:25 GMT+2  Record Service Entry Sheet
# 3       Thu, 01 Jan 1970 00:00:25 GMT+2  Receive Order Confirmation
# 4       Thu, 01 Jan 1970 00:00:25 GMT+2  Receive Order Confirmation
# ...                                 ...                         ...
# 349521  Thu, 01 Jan 1970 00:00:06 GMT+2        Record Goods Receipt
# 349522  Thu, 01 Jan 1970 00:00:06 GMT+2        Record Goods Receipt
# 349523  Thu, 01 Jan 1970 00:00:06 GMT+2        Record Goods Receipt
# 349524  Thu, 01 Jan 1970 00:00:06 GMT+2        Record Goods Receipt
# 349525  Thu, 01 Jan 1970 00:00:06 GMT+2        Record Goods Receipt
#
#            event ID     case Spend area text       Company case Document Type  \
# 0       5.550000e+14     Packaging Type Case  company ID_A        Standard PO
# 1       5.550000e+14     Packaging Type Case  company ID_A        Standard PO
# 2       5.580000e+14  Supply Chain Logistics  company ID_A        Standard PO
# 3       5.550000e+14     Packaging Type Case  company ID_A        Standard PO
# 4       5.550000e+14     Packaging Type Case  company ID_A        Standard PO
# ...              ...                     ...           ...                ...
# 349521  7.530000e+14            CAPEX & SOCS  company ID_A        Standard PO
# 349522  7.530000e+14            CAPEX & SOCS  company ID_A        Standard PO
# 349523  7.530000e+14            CAPEX & SOCS  company ID_A        Standard PO
# 349524  7.530000e+14            CAPEX & SOCS  company ID_A        Standard PO
# 349525  7.420000e+14        Latex & Monomers  company ID_A        Standard PO
#
#        case Sub spend area text  case Purchasing Document    case Vendor  \
# 0             Packaging - Other              4.507039e+09  vendorID_0104
# 1             Packaging - Other              4.507039e+09  vendorID_0104
# 2                   Road Packed              4.507039e+09  vendorID_0541
# 3             Packaging - Other              4.507039e+09  vendorID_0104
# 4             Packaging - Other              4.507039e+09  vendorID_0104
# ...                         ...                       ...            ...
# 349521         MRO (components)              4.508052e+09  vendorID_0237
# 349522         MRO (components)              4.508052e+09  vendorID_0237
# 349523         MRO (components)              4.508052e+09  vendorID_0237
# 349524         MRO (components)              4.508052e+09  vendorID_0237
# 349525           Vinyl Acrylics              4.508052e+09  vendorID_0159
#
#        case Item Type  ...          case Source    case Name C_GR-Based  \
# 0            Standard  ...  sourceSystemID_0000  vendor_0104      False
# 1            Standard  ...  sourceSystemID_0000  vendor_0104      False
# 2             Service  ...  sourceSystemID_0000  vendor_0525       True
# 3            Standard  ...  sourceSystemID_0000  vendor_0104      False
# 4            Standard  ...  sourceSystemID_0000  vendor_0104      False
# ...               ...  ...                  ...          ...        ...
# 349521       Standard  ...  sourceSystemID_0000  vendor_0232      False
# 349522       Standard  ...  sourceSystemID_0000  vendor_0232      False
# 349523       Standard  ...  sourceSystemID_0000  vendor_0232      False
# 349524       Standard  ...  sourceSystemID_0000  vendor_0232      False
# 349525       Standard  ...  sourceSystemID_0000  vendor_0157      False
#
#        case Item case concept:name  case Goods Receipt event User Account  \
# 0          220.0  4507038569_00220                True           user_063
# 1          350.0  4507038569_00350                True           user_063
# 2            1.0  4507038753_00001                True               NONE
# 3          300.0  4507038569_00300                True           user_063
# 4          210.0  4507038569_00210                True           user_063
# ...          ...               ...                 ...                ...
# 349521      70.0  4508052444_00070                True           user_029
# 349522      60.0  4508052444_00060                True           user_029
# 349523      50.0  4508052444_00050                True           user_029
# 349524      30.0  4508052444_00030                True           user_029
# 349525      10.0  4508051663_00010                True           batch_03
#
#        event org type resource Currency Costs in Dollars  \
# 0                     user_063                      2346
# 1                     user_063                     15640
# 2                         NONE                      1829
# 3                     user_063                      9950
# 4                     user_063                      3519
# ...                        ...                       ...
# 349521                user_029                        69
# 349522                user_029                        17
# 349523                user_029                        61
# 349524                user_029                      3856
# 349525                batch_03                     44425
#
#                        caseID
# 0       4507038569.0 Standard
# 1       4507038569.0 Standard
# 2        4507038753.0 Service
# 3       4507038569.0 Standard
# 4       4507038569.0 Standard
# ...                       ...
# 349521  4508052444.0 Standard
# 349522  4508052444.0 Standard
# 349523  4508052444.0 Standard
# 349524  4508052444.0 Standard
# 349525  4508051663.0 Standard
#
# [349526 rows x 22 columns]

# %%
event_log_table.columns
# Out:
# Index(['event time', 'event concept:name', 'event ID ', 'case Spend area text',
#        'Company', 'case Document Type', 'case Sub spend area text',
#        'case Purchasing Document', 'case Vendor', 'case Item Type',
#        'case Item Category', 'case Spend classification text', 'case Source',
#        'case Name', 'C_GR-Based', 'case Item', 'case concept:name',
#        'case Goods Receipt', 'event User Account', 'event org type resource',
#        'Currency Costs in Dollars', 'caseID'],
#       dtype='object')

# %%
#Review all og the event log columns, to decide which ones are mandatory and which ones are additional

log_columns = event_log_table.columns
log_columns # this variable is important for the Meta-DataFrame generation
# Out:
# Index(['event time', 'event concept:name', 'event ID ', 'case Spend area text',
#        'Company', 'case Document Type', 'case Sub spend area text',
#        'case Purchasing Document', 'case Vendor', 'case Item Type',
#        'case Item Category', 'case Spend classification text', 'case Source',
#        'case Name', 'C_GR-Based', 'case Item', 'case concept:name',
#        'case Goods Receipt', 'event User Account', 'event org type resource',
#        'Currency Costs in Dollars', 'caseID'],
#       dtype='object')

# %%
# This has to be tailored to each event log
#caseID is created from 'case Purchasing Document' and 'case Item', define the mandatory columns based on domain knowledge analysis

mandatory_columns = ['caseID', 'event time', 'event concept:name', 'event ID ']

#Create an object/dictionary and corresponding key:value pairs to add the semantic titles which the csv titles represent in a variable  which are relevant for the Meta-DataFrame
titles = {
  'caseID': 'Case ID',
  'event concept:name': 'Activity',
  'event ID ': 'Event ID',
  'event time': 'Timestamp',
}

print(mandatory_columns)
# Out:
# ['caseID', 'event time', 'event concept:name', 'event ID ']

# %%
#Review titles object which are relevant for the Meta-DataFrame
titles
# Out:
# {'caseID': 'Case ID',
#  'event concept:name': 'Activity',
#  'event ID ': 'Event ID',
#  'event time': 'Timestamp'}

# %%
#Review the datatypes for datatype harmonization
event_log_table.dtypes
# Out:
# event time                         object
# event concept:name                 object
# event ID                          float64
# case Spend area text               object
# Company                            object
# case Document Type                 object
# case Sub spend area text           object
# case Purchasing Document          float64
# case Vendor                        object
# case Item Type                     object
# case Item Category                 object
# case Spend classification text     object
# case Source                        object
# case Name                          object
# C_GR-Based                         object
# case Item                         float64
# case concept:name                  object
# case Goods Receipt                 object
# event User Account                 object
# event org type resource            object
# Currency Costs in Dollars           int64
# caseID                             string
# dtype: object

# %%
#This step is optional to minimize the work needed in harmonization 
# was purposefully not performed for BPI_C synthetic dataset 3

#Translate object data types of timestamp data into a datetime64[ns] data type for the timestamp. This is a unique datatype from pandas.
timestamp_objects = event_log_table['event time'] #declare timestamp to a variable
event_log_table['event time']=pd.to_datetime(timestamp_objects)

#Review changes made
#event_log_table['event time'].dtypes
event_log_table.dtypes
# Out:
# event time                        datetime64[ns, pytz.FixedOffset(-120)]
# event concept:name                                                object
# event ID                                                         float64
# case Spend area text                                              object
# Company                                                           object
# case Document Type                                                object
# case Sub spend area text                                          object
# case Purchasing Document                                         float64
# case Vendor                                                       object
# case Item Type                                                    object
# case Item Category                                                object
# case Spend classification text                                    object
# case Source                                                       object
# case Name                                                         object
# C_GR-Based                                                        object
# case Item                                                        float64
# case concept:name                                                 object
# case Goods Receipt                                                object
# event User Account                                                object
# event org type resource                                           object
# Currency Costs in Dollars                                          int64
# caseID                                                            string
# dtype: object

# %%
#This step is optional to minimize the work needed in harmonization 
# was purposefully not performed for BPI_C synthetic dataset 3

#Translate object data types of object data types (which contains different possible formats) to a clear string data type format
#for loops where used as they enable somewhat automated transformations 
# = for assigning values
# == operator is used to test equality
for log_column in log_columns:
    if event_log_table[log_column].dtype == 'object': #check if the column has an object data type
        event_log_table[log_column] = event_log_table[log_column].astype('string') #change it to a string

#Review changes
#event_log_table['event time'].dtypes
event_log_table.dtypes
# Out:
# event time                        datetime64[ns, pytz.FixedOffset(-120)]
# event concept:name                                                string
# event ID                                                         float64
# case Spend area text                                              string
# Company                                                           string
# case Document Type                                                string
# case Sub spend area text                                          string
# case Purchasing Document                                         float64
# case Vendor                                                       string
# case Item Type                                                    string
# case Item Category                                                string
# case Spend classification text                                    string
# case Source                                                       string
# case Name                                                         string
# C_GR-Based                                                        string
# case Item                                                        float64
# case concept:name                                                 string
# case Goods Receipt                                                string
# event User Account                                                string
# event org type resource                                           string
# Currency Costs in Dollars                                          int64
# caseID                                                            string
# dtype: object

# %%
event_log_table.dtypes
# Out:
# event time                        datetime64[ns, pytz.FixedOffset(-120)]
# event concept:name                                                string
# event ID                                                         float64
# case Spend area text                                              string
# Company                                                           string
# case Document Type                                                string
# case Sub spend area text                                          string
# case Purchasing Document                                         float64
# case Vendor                                                       string
# case Item Type                                                    string
# case Item Category                                                string
# case Spend classification text                                    string
# case Source                                                       string
# case Name                                                         string
# C_GR-Based                                                        string
# case Item                                                        float64
# case concept:name                                                 string
# case Goods Receipt                                                string
# event User Account                                                string
# event org type resource                                           string
# Currency Costs in Dollars                                          int64
# caseID                                                            string
# dtype: object

# %%
# Reorder the columns of the event log table.
# Checking the log columns list contains each item on the mandatory columns list with the assert statement raises an 'AssertionError' if any of the elements are missing. 
# With the delete method and the == operator, the items are removed in the mandatory columns list from the log columns list.
# Then  using the + operator to combine the mandatory columns list and the log columns list (which has been turned into a list using the tolist method). By doing so, a fresh list of columns in # the desired order is created. Using the [] operator to select only the columns in the newly created list, subsetting the event log table DataFrame. By doing this, the columns in the new #DataFrame are created in the desired order.

for mandatory_column in mandatory_columns:
  assert mandatory_column in log_columns 
  log_columns = log_columns.delete(log_columns == mandatory_column)
log_columns = mandatory_columns + log_columns.tolist()

event_log_table = event_log_table[log_columns]
event_log_table #the for loop above resultes in a move of the mandatory columns to the left side (changes order)
# Out:
#                        caseID                event time  \
# 0       4507038569.0 Standard 1970-01-01 00:00:25-02:00
# 1       4507038569.0 Standard 1970-01-01 00:00:25-02:00
# 2        4507038753.0 Service 1970-01-01 00:00:25-02:00
# 3       4507038569.0 Standard 1970-01-01 00:00:25-02:00
# 4       4507038569.0 Standard 1970-01-01 00:00:25-02:00
# ...                       ...                       ...
# 349521  4508052444.0 Standard 1970-01-01 00:00:06-02:00
# 349522  4508052444.0 Standard 1970-01-01 00:00:06-02:00
# 349523  4508052444.0 Standard 1970-01-01 00:00:06-02:00
# 349524  4508052444.0 Standard 1970-01-01 00:00:06-02:00
# 349525  4508051663.0 Standard 1970-01-01 00:00:06-02:00
#
#                 event concept:name     event ID     case Spend area text  \
# 0       Receive Order Confirmation  5.550000e+14     Packaging Type Case
# 1       Receive Order Confirmation  5.550000e+14     Packaging Type Case
# 2       Record Service Entry Sheet  5.580000e+14  Supply Chain Logistics
# 3       Receive Order Confirmation  5.550000e+14     Packaging Type Case
# 4       Receive Order Confirmation  5.550000e+14     Packaging Type Case
# ...                            ...           ...                     ...
# 349521        Record Goods Receipt  7.530000e+14            CAPEX & SOCS
# 349522        Record Goods Receipt  7.530000e+14            CAPEX & SOCS
# 349523        Record Goods Receipt  7.530000e+14            CAPEX & SOCS
# 349524        Record Goods Receipt  7.530000e+14            CAPEX & SOCS
# 349525        Record Goods Receipt  7.420000e+14        Latex & Monomers
#
#              Company case Document Type case Sub spend area text  \
# 0       company ID_A        Standard PO        Packaging - Other
# 1       company ID_A        Standard PO        Packaging - Other
# 2       company ID_A        Standard PO              Road Packed
# 3       company ID_A        Standard PO        Packaging - Other
# 4       company ID_A        Standard PO        Packaging - Other
# ...              ...                ...                      ...
# 349521  company ID_A        Standard PO         MRO (components)
# 349522  company ID_A        Standard PO         MRO (components)
# 349523  company ID_A        Standard PO         MRO (components)
# 349524  company ID_A        Standard PO         MRO (components)
# 349525  company ID_A        Standard PO           Vinyl Acrylics
#
#         case Purchasing Document    case Vendor  ...  \
# 0                   4.507039e+09  vendorID_0104  ...
# 1                   4.507039e+09  vendorID_0104  ...
# 2                   4.507039e+09  vendorID_0541  ...
# 3                   4.507039e+09  vendorID_0104  ...
# 4                   4.507039e+09  vendorID_0104  ...
# ...                          ...            ...  ...
# 349521              4.508052e+09  vendorID_0237  ...
# 349522              4.508052e+09  vendorID_0237  ...
# 349523              4.508052e+09  vendorID_0237  ...
# 349524              4.508052e+09  vendorID_0237  ...
# 349525              4.508052e+09  vendorID_0159  ...
#
#        case Spend classification text          case Source    case Name  \
# 0                                  PR  sourceSystemID_0000  vendor_0104
# 1                                  PR  sourceSystemID_0000  vendor_0104
# 2                                 NPR  sourceSystemID_0000  vendor_0525
# 3                                  PR  sourceSystemID_0000  vendor_0104
# 4                                  PR  sourceSystemID_0000  vendor_0104
# ...                               ...                  ...          ...
# 349521                            NPR  sourceSystemID_0000  vendor_0232
# 349522                            NPR  sourceSystemID_0000  vendor_0232
# 349523                            NPR  sourceSystemID_0000  vendor_0232
# 349524                            NPR  sourceSystemID_0000  vendor_0232
# 349525                             PR  sourceSystemID_0000  vendor_0157
#
#        C_GR-Based case Item case concept:name  case Goods Receipt  \
# 0           False     220.0  4507038569_00220                True
# 1           False     350.0  4507038569_00350                True
# 2            True       1.0  4507038753_00001                True
# 3           False     300.0  4507038569_00300                True
# 4           False     210.0  4507038569_00210                True
# ...           ...       ...               ...                 ...
# 349521      False      70.0  4508052444_00070                True
# 349522      False      60.0  4508052444_00060                True
# 349523      False      50.0  4508052444_00050                True
# 349524      False      30.0  4508052444_00030                True
# 349525      False      10.0  4508051663_00010                True
#
#        event User Account event org type resource Currency Costs in Dollars
# 0                user_063                user_063                      2346
# 1                user_063                user_063                     15640
# 2                    NONE                    NONE                      1829
# 3                user_063                user_063                      9950
# 4                user_063                user_063                      3519
# ...                   ...                     ...                       ...
# 349521           user_029                user_029                        69
# 349522           user_029                user_029                        17
# 349523           user_029                user_029                        61
# 349524           user_029                user_029                      3856
# 349525           batch_03                batch_03                     44425
#
# [349526 rows x 22 columns]

# %% [markdown]
# Here we are going to reset the index and reorder the event log with a new index
#
# Setting the inplace parameter to True and using the reset index method to reset the DataFrame's index.
# This adds a new column to the DataFrame containing the old index values and resets the index to a range of sequential integers beginning at 0.
# Using the rename method and the inplace parameter set to True, rename the column containing the previous index values.
# A dictionary that maps the old column name "index" to the new column name "EventIndex" makes up the columns parameter.
# Using the set index method and the inplace parameter set to True, the DataFrame's index is changed to the 'EventIndex' column.
# This will remove the "EventIndex" column from the data and make it the new index of the DataFrame.

# %%
# Number every single event in the event log.
# Every single event is represented by a line in the event log file.
event_log_table.reset_index(inplace=True)
event_log_table.rename(columns={'index': 'EventIndex'}, inplace=True)
event_log_table.set_index('EventIndex', inplace=True)

#review changes
event_log_table
# Out:
# /var/folders/vz/snd73j8d2mj817493bt9ykfc0000gn/T/ipykernel_99122/2322881527.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   event_log_table.rename(columns={'index': 'EventIndex'}, inplace=True)
#                            caseID                event time  \
# EventIndex
# 0           4507038569.0 Standard 1970-01-01 00:00:25-02:00
# 1           4507038569.0 Standard 1970-01-01 00:00:25-02:00
# 2            4507038753.0 Service 1970-01-01 00:00:25-02:00
# 3           4507038569.0 Standard 1970-01-01 00:00:25-02:00
# 4           4507038569.0 Standard 1970-01-01 00:00:25-02:00
# ...                           ...                       ...
# 349521      4508052444.0 Standard 1970-01-01 00:00:06-02:00
# 349522      4508052444.0 Standard 1970-01-01 00:00:06-02:00
# 349523      4508052444.0 Standard 1970-01-01 00:00:06-02:00
# 349524      4508052444.0 Standard 1970-01-01 00:00:06-02:00
# 349525      4508051663.0 Standard 1970-01-01 00:00:06-02:00
#
#                     event concept:name     event ID     case Spend area text  \
# EventIndex
# 0           Receive Order Confirmation  5.550000e+14     Packaging Type Case
# 1           Receive Order Confirmation  5.550000e+14     Packaging Type Case
# 2           Record Service Entry Sheet  5.580000e+14  Supply Chain Logistics
# 3           Receive Order Confirmation  5.550000e+14     Packaging Type Case
# 4           Receive Order Confirmation  5.550000e+14     Packaging Type Case
# ...                                ...           ...                     ...
# 349521            Record Goods Receipt  7.530000e+14            CAPEX & SOCS
# 349522            Record Goods Receipt  7.530000e+14            CAPEX & SOCS
# 349523            Record Goods Receipt  7.530000e+14            CAPEX & SOCS
# 349524            Record Goods Receipt  7.530000e+14            CAPEX & SOCS
# 349525            Record Goods Receipt  7.420000e+14        Latex & Monomers
#
#                  Company case Document Type case Sub spend area text  \
# EventIndex
# 0           company ID_A        Standard PO        Packaging - Other
# 1           company ID_A        Standard PO        Packaging - Other
# 2           company ID_A        Standard PO              Road Packed
# 3           company ID_A        Standard PO        Packaging - Other
# 4           company ID_A        Standard PO        Packaging - Other
# ...                  ...                ...                      ...
# 349521      company ID_A        Standard PO         MRO (components)
# 349522      company ID_A        Standard PO         MRO (components)
# 349523      company ID_A        Standard PO         MRO (components)
# 349524      company ID_A        Standard PO         MRO (components)
# 349525      company ID_A        Standard PO           Vinyl Acrylics
#
#             case Purchasing Document    case Vendor  ...  \
# EventIndex                                           ...
# 0                       4.507039e+09  vendorID_0104  ...
# 1                       4.507039e+09  vendorID_0104  ...
# 2                       4.507039e+09  vendorID_0541  ...
# 3                       4.507039e+09  vendorID_0104  ...
# 4                       4.507039e+09  vendorID_0104  ...
# ...                              ...            ...  ...
# 349521                  4.508052e+09  vendorID_0237  ...
# 349522                  4.508052e+09  vendorID_0237  ...
# 349523                  4.508052e+09  vendorID_0237  ...
# 349524                  4.508052e+09  vendorID_0237  ...
# 349525                  4.508052e+09  vendorID_0159  ...
#
#            case Spend classification text          case Source    case Name  \
# EventIndex
# 0                                      PR  sourceSystemID_0000  vendor_0104
# 1                                      PR  sourceSystemID_0000  vendor_0104
# 2                                     NPR  sourceSystemID_0000  vendor_0525
# 3                                      PR  sourceSystemID_0000  vendor_0104
# 4                                      PR  sourceSystemID_0000  vendor_0104
# ...                                   ...                  ...          ...
# 349521                                NPR  sourceSystemID_0000  vendor_0232
# 349522                                NPR  sourceSystemID_0000  vendor_0232
# 349523                                NPR  sourceSystemID_0000  vendor_0232
# 349524                                NPR  sourceSystemID_0000  vendor_0232
# 349525                                 PR  sourceSystemID_0000  vendor_0157
#
#            C_GR-Based case Item case concept:name  case Goods Receipt  \
# EventIndex
# 0               False     220.0  4507038569_00220                True
# 1               False     350.0  4507038569_00350                True
# 2                True       1.0  4507038753_00001                True
# 3               False     300.0  4507038569_00300                True
# 4               False     210.0  4507038569_00210                True
# ...               ...       ...               ...                 ...
# 349521          False      70.0  4508052444_00070                True
# 349522          False      60.0  4508052444_00060                True
# 349523          False      50.0  4508052444_00050                True
# 349524          False      30.0  4508052444_00030                True
# 349525          False      10.0  4508051663_00010                True
#
#            event User Account event org type resource  \
# EventIndex
# 0                    user_063                user_063
# 1                    user_063                user_063
# 2                        NONE                    NONE
# 3                    user_063                user_063
# 4                    user_063                user_063
# ...                       ...                     ...
# 349521               user_029                user_029
# 349522               user_029                user_029
# 349523               user_029                user_029
# 349524               user_029                user_029
# 349525               batch_03                batch_03
#
#            Currency Costs in Dollars
# EventIndex
# 0                               2346
# 1                              15640
# 2                               1829
# 3                               9950
# 4                               3519
# ...                              ...
# 349521                            69
# 349522                            17
# 349523                            61
# 349524                          3856
# 349525                         44425
#
# [349526 rows x 22 columns]

# %%
#defining a new dictionary  overview_columns with log columns as the elements
content_overview_columns = [(log_column, ['BPI_C_2019_3rd_Supplier']) for log_column in log_columns]
extra_overview_columns = [('Event log column property', ['BPI_C_2019_3rd_Supplier'])]
overview_columns = dict(extra_overview_columns + content_overview_columns)
overview_table = pd.DataFrame(overview_columns)

# To add a vertically indented name to the index in the console output.
overview_table.set_index('Event log column property', inplace=True)
overview_columns
# Out:
# {'Event log column property': ['BPI_C_2019_3rd_Supplier'],
#  'caseID': ['BPI_C_2019_3rd_Supplier'],
#  'event time': ['BPI_C_2019_3rd_Supplier'],
#  'event concept:name': ['BPI_C_2019_3rd_Supplier'],
#  'event ID ': ['BPI_C_2019_3rd_Supplier'],
#  'case Spend area text': ['BPI_C_2019_3rd_Supplier'],
#  'Company': ['BPI_C_2019_3rd_Supplier'],
#  'case Document Type': ['BPI_C_2019_3rd_Supplier'],
#  'case Sub spend area text': ['BPI_C_2019_3rd_Supplier'],
#  'case Purchasing Document': ['BPI_C_2019_3rd_Supplier'],
#  'case Vendor': ['BPI_C_2019_3rd_Supplier'],
#  'case Item Type': ['BPI_C_2019_3rd_Supplier'],
#  'case Item Category': ['BPI_C_2019_3rd_Supplier'],
#  'case Spend classification text': ['BPI_C_2019_3rd_Supplier'],
#  'case Source': ['BPI_C_2019_3rd_Supplier'],
#  'case Name': ['BPI_C_2019_3rd_Supplier'],
#  'C_GR-Based': ['BPI_C_2019_3rd_Supplier'],
#  'case Item': ['BPI_C_2019_3rd_Supplier'],
#  'case concept:name': ['BPI_C_2019_3rd_Supplier'],
#  'case Goods Receipt': ['BPI_C_2019_3rd_Supplier'],
#  'event User Account': ['BPI_C_2019_3rd_Supplier'],
#  'event org type resource': ['BPI_C_2019_3rd_Supplier'],
#  'Currency Costs in Dollars': ['BPI_C_2019_3rd_Supplier']}

# %%
#view the new overview_table to construct the Meta-DataFrame
overview_table
# Out:
#                                             caseID               event time  \
# Event log column property
# BPI_C_2019_3rd_Supplier    BPI_C_2019_3rd_Supplier  BPI_C_2019_3rd_Supplier
#
#                                 event concept:name                event ID   \
# Event log column property
# BPI_C_2019_3rd_Supplier    BPI_C_2019_3rd_Supplier  BPI_C_2019_3rd_Supplier
#
#                               case Spend area text                  Company  \
# Event log column property
# BPI_C_2019_3rd_Supplier    BPI_C_2019_3rd_Supplier  BPI_C_2019_3rd_Supplier
#
#                                 case Document Type case Sub spend area text  \
# Event log column property
# BPI_C_2019_3rd_Supplier    BPI_C_2019_3rd_Supplier  BPI_C_2019_3rd_Supplier
#
#                           case Purchasing Document              case Vendor  \
# Event log column property
# BPI_C_2019_3rd_Supplier    BPI_C_2019_3rd_Supplier  BPI_C_2019_3rd_Supplier
#
#                            ... case Spend classification text  \
# Event log column property  ...
# BPI_C_2019_3rd_Supplier    ...        BPI_C_2019_3rd_Supplier
#
#                                        case Source                case Name  \
# Event log column property
# BPI_C_2019_3rd_Supplier    BPI_C_2019_3rd_Supplier  BPI_C_2019_3rd_Supplier
#
#                                         C_GR-Based                case Item  \
# Event log column property
# BPI_C_2019_3rd_Supplier    BPI_C_2019_3rd_Supplier  BPI_C_2019_3rd_Supplier
#
#                                  case concept:name       case Goods Receipt  \
# Event log column property
# BPI_C_2019_3rd_Supplier    BPI_C_2019_3rd_Supplier  BPI_C_2019_3rd_Supplier
#
#                                 event User Account  event org type resource  \
# Event log column property
# BPI_C_2019_3rd_Supplier    BPI_C_2019_3rd_Supplier  BPI_C_2019_3rd_Supplier
#
#                           Currency Costs in Dollars
# Event log column property
# BPI_C_2019_3rd_Supplier     BPI_C_2019_3rd_Supplier
#
# [1 rows x 22 columns]

# %% [markdown]
# <h2>Multiple variables based on event data proprocessing which are used for the Meta-DataFrame</h2>
#
# The author uses the pandas .loc function which is an indexer in Pandas is used to choose rows and columns from a DataFrame based on labels.
#
# The snippet below is called title property X as it will be added to the overview table (Meta-DataFrame) with the log columns list's elements as keys and the log column itself as a value, if the title associated with the log column is present in the titles dictionary (if it does not exist in the titles dictionary).
#
# Then, a new row with the label "Title" and the values from the title property dictionary is added to the overview table DataFrame. The assignment will add the new row to the DataFrame, and the.loc indexer will be used to select the row by its label.
#
# When this code block is run, a new row with the label "Title" and values representing the names of each log column will appear in the overview table DataFrame (or the log column itself if no title is provided).

# %%
# Overview for property: Titles - For the Meta-DataFrame
# Depending on whether the title for the log column is present in the titles dictionary, the values of the log columns list are either the log column itself or its associated title (if it does not exist in the titles dictionary).
title_property = {}

for log_column in log_columns:
    if log_column in titles:
        title = titles[log_column]
    else:
        title = log_column
    title_property[log_column] = title

# %% [markdown]
# Then, a new row with the label "Title" and the values from the title property dictionary is added to the overview table DataFrame. The assignment will add the new row to the DataFrame, and the.loc indexer will be used to select the row by its label.
# When this code block is run, a new row with the label "Title" and values representing the names of each log column will appear in the overview table DataFrame (or the log column itself if no title is provided).

# %%
overview_table.loc['Title'] = title_property
overview_table.loc['Title']
# Out:
# caseID                                                   Case ID
# event time                                             Timestamp
# event concept:name                                      Activity
# event ID                                                Event ID
# case Spend area text                        case Spend area text
# Company                                                  Company
# case Document Type                            case Document Type
# case Sub spend area text                case Sub spend area text
# case Purchasing Document                case Purchasing Document
# case Vendor                                          case Vendor
# case Item Type                                    case Item Type
# case Item Category                            case Item Category
# case Spend classification text    case Spend classification text
# case Source                                          case Source
# case Name                                              case Name
# C_GR-Based                                            C_GR-Based
# case Item                                              case Item
# case concept:name                              case concept:name
# case Goods Receipt                            case Goods Receipt
# event User Account                            event User Account
# event org type resource                  event org type resource
# Currency Costs in Dollars              Currency Costs in Dollars
# Name: Title, dtype: object

# %% [markdown]
# <h2>Dictionary {for mandatory and additional attributes}</h2>
#
# This code block generates a new dictionary called importance property whose keys are the items in the list of log columns and whose values are either "Mandatory attribute" or "Additional attribute" depending on whether the log column is included in the mandatory columns list or not.
# Then, a new row with the label "Importance" and values taken from the importance property dictionary is added to the overview table DataFrame. The assignment will add the new row to the DataFrame, and the.loc indexer will be used to select the row by its label.
# When this code block is run, a new row with the label "Importance" and the values "Mandatory attribute" or "Additional attribute" for each log column, depending on whether that column is in the mandatory columns list or not, will appear in the overview table DataFrame.
#
# The concept is used for other data attributes as well

# %%
# Overview property: Label for columns either 'Mandatory attribute' or 'additional_attributes' - For the Meta-DataFrame

importance_property = {}
for log_column in log_columns:
    if log_column in mandatory_columns:
        importance_property[log_column] = 'Mandatory attribute'
    else:
        importance_property[log_column] = 'Additional attribute'

overview_table.loc['Importance'] = importance_property
overview_table.loc['Importance']
# Out:
# caseID                             Mandatory attribute
# event time                         Mandatory attribute
# event concept:name                 Mandatory attribute
# event ID                           Mandatory attribute
# case Spend area text              Additional attribute
# Company                           Additional attribute
# case Document Type                Additional attribute
# case Sub spend area text          Additional attribute
# case Purchasing Document          Additional attribute
# case Vendor                       Additional attribute
# case Item Type                    Additional attribute
# case Item Category                Additional attribute
# case Spend classification text    Additional attribute
# case Source                       Additional attribute
# case Name                         Additional attribute
# C_GR-Based                        Additional attribute
# case Item                         Additional attribute
# case concept:name                 Additional attribute
# case Goods Receipt                Additional attribute
# event User Account                Additional attribute
# event org type resource           Additional attribute
# Currency Costs in Dollars         Additional attribute
# Name: Importance, dtype: object

# %% [markdown]
# The goal of this code snippet is to add a new row to the Meta-Dataframe termed overview table, where the keys are the columns in a list called log columns and the values are strings indicating whether the column is at the "Event level" or the "Case level." The values are determined by examining the column name for the string "event" or "case," respectively.

# %%
# Overview property: The level of the event data attribute in the overview table
level_property = {}
for log_column in log_columns:
  if 'event' in log_column:
    level_property[log_column] = 'Event level'
  if 'case' in log_column:
    level_property[log_column] = 'Case level'

overview_table.loc['Level'] = level_property
overview_table.loc['Level']
# Out:
# caseID                             Case level
# event time                        Event level
# event concept:name                Event level
# event ID                          Event level
# case Spend area text               Case level
# Company                                   NaN
# case Document Type                 Case level
# case Sub spend area text           Case level
# case Purchasing Document           Case level
# case Vendor                        Case level
# case Item Type                     Case level
# case Item Category                 Case level
# case Spend classification text     Case level
# case Source                        Case level
# case Name                          Case level
# C_GR-Based                                NaN
# case Item                          Case level
# case concept:name                  Case level
# case Goods Receipt                 Case level
# event User Account                Event level
# event org type resource           Event level
# Currency Costs in Dollars                 NaN
# Name: Level, dtype: object

# %%
# Overview property: Data type
data_type_property = {}
datatypes = event_log_table.dtypes
for log_column in log_columns:
  data_type_property[log_column] = datatypes[log_column]

overview_table.loc['Data type'] = data_type_property

# %% [markdown]
# This snippet adds a new row to the Meta-Dataframe in Pandas, with the keys being the columns in a list called log columns and the values being the data types of the corresponding columns in an event log table DataFrame.

# %%
# Overview property: Data type
data_type_property = {}
datatypes = event_log_table.dtypes
for log_column in log_columns:
    data_type_property[log_column] = datatypes[log_column]

overview_table.loc['Data type'] = data_type_property
overview_table.loc['Data type']
# Out:
# caseID                                                            string
# event time                        datetime64[ns, pytz.FixedOffset(-120)]
# event concept:name                                                string
# event ID                                                         float64
# case Spend area text                                              string
# Company                                                           string
# case Document Type                                                string
# case Sub spend area text                                          string
# case Purchasing Document                                         float64
# case Vendor                                                       string
# case Item Type                                                    string
# case Item Category                                                string
# case Spend classification text                                    string
# case Source                                                       string
# case Name                                                         string
# C_GR-Based                                                        string
# case Item                                                        float64
# case concept:name                                                 string
# case Goods Receipt                                                string
# event User Account                                                string
# event org type resource                                           string
# Currency Costs in Dollars                                          int64
# Name: Data type, dtype: object

# %%
# Overview property: Count the number of entries for the Meta-Dataframe
number_of_entries_property = {}
for log_column in log_columns:
    number_of_entries_property[log_column] = len(event_log_table)

overview_table.loc['Number of entries'] = number_of_entries_property
overview_table.loc['Number of entries']
# Out:
# caseID                            349526
# event time                        349526
# event concept:name                349526
# event ID                          349526
# case Spend area text              349526
# Company                           349526
# case Document Type                349526
# case Sub spend area text          349526
# case Purchasing Document          349526
# case Vendor                       349526
# case Item Type                    349526
# case Item Category                349526
# case Spend classification text    349526
# case Source                       349526
# case Name                         349526
# C_GR-Based                        349526
# case Item                         349526
# case concept:name                 349526
# case Goods Receipt                349526
# event User Account                349526
# event org type resource           349526
# Currency Costs in Dollars         349526
# Name: Number of entries, dtype: object

# %%
# Overview property: Number of unique entries
number_of_unique_entries_property = {}
for log_column in log_columns:
  count = event_log_table[log_column].value_counts().count()
  number_of_unique_entries_property[log_column] = count

overview_table.loc['Number of unique entries'] = number_of_unique_entries_property
overview_table.loc['Number of unique entries']
# Out:
# caseID                             33958
# event time                            31
# event concept:name                    37
# event ID                            1504
# case Spend area text                  19
# Company                                3
# case Document Type                     3
# case Sub spend area text             131
# case Purchasing Document           33621
# case Vendor                         1465
# case Item Type                         6
# case Item Category                     4
# case Spend classification text         3
# case Source                            1
# case Name                           1401
# C_GR-Based                             2
# case Item                            320
# case concept:name                 109813
# case Goods Receipt                     2
# event User Account                   431
# event org type resource              431
# Currency Costs in Dollars          14473
# Name: Number of unique entries, dtype: object

# %%
#Overview property: List of up to 100 unique entries (to grasp an understanding of how the data looks and it is structured and not just metrics)
unique_entries_property = {}
for log_column in log_columns:
    unique_entries = event_log_table[log_column].unique()
    unique_entries = list(unique_entries)
    unique_entries = unique_entries[:100]
    unique_entries_property[log_column] = unique_entries

overview_table.loc['List up to 100 unique entries to view the structure of the event attributes']= unique_entries_property
unique_entries_property
# Out:
# {'caseID': ['4507038569.0 Standard',
#   '4507038753.0 Service',
#   '4507038755.0 Standard',
#   '4507038732.0 Standard',
#   '4507038756.0 Standard',
#   '4507038676.0 Standard',
#   '4507037708.0 Standard',
#   '4507035390.0 Consignment',
#   '4507035387.0 Consignment',
#   '4507035015.0 Standard',
#   '4507038758.0 Standard',
#   '4507036060.0 Standard',
#   '4507033367.0 Standard',
#   '4507033994.0 Standard',
#   '4507030058.0 Standard',
#   '4507038757.0 Standard',
#   '4507037532.0 Standard',
#   '4507035316.0 Standard',
#   '4507038667.0 Standard',
#   '2000033504.0 Standard',
#   '4507026002.0 Standard',
#   '4507038759.0 Consignment',
#   '4507023375.0 Standard',
#   '4507021476.0 Standard',
#   '4507032711.0 Standard',
#   '4507024651.0 Standard',
#   '4507030061.0 Standard',
#   '4507036456.0 Standard',
#   '4507038760.0 Standard',
#   '4507035095.0 Standard',
#   '4507038761.0 Third-party',
#   '4507038762.0 Third-party',
#   '4507035322.0 Standard',
#   '4507026592.0 Standard',
#   '4507035003.0 Standard',
#   '4507038763.0 Standard',
#   '4507023988.0 Standard',
#   '4507037448.0 Standard',
#   '4507038765.0 Standard',
#   '4507036130.0 Consignment',
#   '4507038764.0 Standard',
#   '4507029193.0 Standard',
#   '4507022875.0 Standard',
#   '4507038766.0 Standard',
#   '4507037322.0 Standard',
#   '4507037854.0 Standard',
#   '4507029440.0 Standard',
#   '4507036458.0 Standard',
#   '4507038767.0 Consignment',
#   '4507038514.0 Standard',
#   '4507031638.0 Standard',
#   '4507020119.0 Consignment',
#   '4507036401.0 Standard',
#   '4507038126.0 Standard',
#   '4507005000.0 Service',
#   '4507038560.0 Standard',
#   '4507030865.0 Standard',
#   '4507016594.0 Standard',
#   '4507037446.0 Standard',
#   '4507035488.0 Standard',
#   '4507035485.0 Consignment',
#   '4507014539.0 Service',
#   '4507016587.0 Standard',
#   '4507030453.0 Standard',
#   '4507036594.0 Standard',
#   '4507032540.0 Consignment',
#   '4507016769.0 Service',
#   '4507038768.0 Subcontracting',
#   '4507036962.0 Standard',
#   '4507026979.0 Standard',
#   '4507030661.0 Standard',
#   '4507038769.0 Standard',
#   '4507031450.0 Standard',
#   '4507024198.0 Standard',
#   '4507037563.0 Standard',
#   '4507034760.0 Standard',
#   '4507034969.0 Standard',
#   '4507003653.0 Service',
#   '4507038770.0 Standard',
#   '4507023202.0 Standard',
#   '4507018445.0 Service',
#   '4507028928.0 Standard',
#   '2000000178.0 Standard',
#   '4507035945.0 Standard',
#   '4507036042.0 Standard',
#   '4507038771.0 Standard',
#   '4507037858.0 Consignment',
#   '4507019931.0 Standard',
#   '4507027333.0 Standard',
#   '4507033278.0 Standard',
#   '4507036620.0 Standard',
#   '4507037291.0 Standard',
#   '4507035949.0 Standard',
#   '4507038772.0 Standard',
#   '4507034826.0 Standard',
#   '4507038774.0 Standard',
#   '4507038773.0 Standard',
#   '4507036709.0 Standard',
#   '4507035869.0 Standard',
#   '4507038775.0 Standard'],
#  'event time': [Timestamp('1970-01-01 00:00:25-0200', tz='pytz.FixedOffset(-120)'),
#   Timestamp('1970-01-01 00:00:26-0200', tz='pytz.FixedOffset(-120)'),
#   Timestamp('1970-01-01 00:00:27-0200', tz='pytz.FixedOffset(-120)'),
#   Timestamp('1970-01-01 00:00:28-0200', tz='pytz.FixedOffset(-120)'),
#   Timestamp('1970-01-01 00:00:29-0200', tz='pytz.FixedOffset(-120)'),
#   Timestamp('1970-01-01 00:00:30-0200', tz='pytz.FixedOffset(-120)'),
#   Timestamp('1970-01-01 00:00:01-0200', tz='pytz.FixedOffset(-120)'),
#   Timestamp('1970-01-01 00:00:02-0200', tz='pytz.FixedOffset(-120)'),
#   Timestamp('1970-01-01 00:00:03-0200', tz='pytz.FixedOffset(-120)'),
#   Timestamp('1970-01-01 00:00:04-0200', tz='pytz.FixedOffset(-120)'),
#   Timestamp('1970-01-01 00:00:05-0200', tz='pytz.FixedOffset(-120)'),
#   Timestamp('1970-01-01 00:00:06-0200', tz='pytz.FixedOffset(-120)'),
#   Timestamp('1970-01-01 00:00:07-0200', tz='pytz.FixedOffset(-120)'),
#   Timestamp('1970-01-01 00:00:08-0200', tz='pytz.FixedOffset(-120)'),
#   Timestamp('1970-01-01 00:00:09-0200', tz='pytz.FixedOffset(-120)'),
#   Timestamp('1970-01-01 00:00:10-0200', tz='pytz.FixedOffset(-120)'),
#   Timestamp('1970-01-01 00:00:11-0200', tz='pytz.FixedOffset(-120)'),
#   Timestamp('1970-01-01 00:00:12-0200', tz='pytz.FixedOffset(-120)'),
#   Timestamp('1970-01-01 00:00:13-0200', tz='pytz.FixedOffset(-120)'),
#   Timestamp('1970-01-01 00:00:14-0200', tz='pytz.FixedOffset(-120)'),
#   Timestamp('1970-01-01 00:00:15-0200', tz='pytz.FixedOffset(-120)'),
#   Timestamp('1970-01-01 00:00:16-0200', tz='pytz.FixedOffset(-120)'),
#   Timestamp('1970-01-01 00:00:17-0200', tz='pytz.FixedOffset(-120)'),
#   Timestamp('1970-01-01 00:00:18-0200', tz='pytz.FixedOffset(-120)'),
#   Timestamp('1970-01-01 00:00:19-0200', tz='pytz.FixedOffset(-120)'),
#   Timestamp('1970-01-01 00:00:20-0200', tz='pytz.FixedOffset(-120)'),
#   Timestamp('1970-01-01 00:00:21-0200', tz='pytz.FixedOffset(-120)'),
#   Timestamp('1970-01-01 00:00:22-0200', tz='pytz.FixedOffset(-120)'),
#   Timestamp('1970-01-01 00:00:23-0200', tz='pytz.FixedOffset(-120)'),
#   Timestamp('1970-01-01 00:00:24-0200', tz='pytz.FixedOffset(-120)'),
#   Timestamp('1970-01-01 00:00:31-0200', tz='pytz.FixedOffset(-120)')],
#  'event concept:name': ['Receive Order Confirmation',
#   'Record Service Entry Sheet',
#   'Record Goods Receipt',
#   'Create Purchase Order Item',
#   'Cancel Goods Receipt',
#   'Change Quantity',
#   'Change Delivery Indicator',
#   'SRM: Created',
#   'Record Invoice Receipt',
#   'Change Storage Location',
#   'Delete Purchase Order Item',
#   'Change Price',
#   'Cancel Invoice Receipt',
#   'SRM: Change was Transmitted',
#   'SRM: In Transfer to Execution Syst.',
#   'SRM: Awaiting Approval',
#   'SRM: Document Completed',
#   'SRM: Ordered',
#   'SRM: Complete',
#   'SRM: Deleted',
#   'Reactivate Purchase Order Item',
#   'Remove Payment Block',
#   'Clear Invoice',
#   'Change Approval for Purchase Order',
#   'Vendor creates invoice',
#   'Vendor creates debit memo',
#   'Create Purchase Requisition Item',
#   'Record Subsequent Invoice',
#   'Cancel Subsequent Invoice',
#   'Block Purchase Order Item',
#   'Update Order Confirmation',
#   'Set Payment Block',
#   'Release Purchase Order',
#   'Change Final Invoice Indicator',
#   'Change payment term',
#   'Change Currency',
#   'SRM: Transaction Completed'],
#  'event ID ': [555000000000000.0,
#   558000000000000.0,
#   557000000000000.0,
#   556000000000000.0,
#   544000000000000.0,
#   513000000000000.0,
#   507000000000000.0,
#   523000000000000.0,
#   486000000000000.0,
#   493000000000000.0,
#   436000000000000.0,
#   542000000000000.0,
#   512000000000000.0,
#   487000000000000.0,
#   378000000000000.0,
#   339000000000000.0,
#   309000000000000.0,
#   478000000000000.0,
#   358000000000000.0,
#   527000000000000.0,
#   508000000000000.0,
#   386000000000000.0,
#   348000000000000.0,
#   541000000000000.0,
#   524000000000000.0,
#   425000000000000.0,
#   330000000000000.0,
#   539000000000000.0,
#   546000000000000.0,
#   428000000000000.0,
#   528000000000000.0,
#   462000000000000.0,
#   288000000000000.0,
#   549000000000000.0,
#   66900000000000.0,
#   449000000000000.0,
#   233000000000000.0,
#   540000000000000.0,
#   514000000000000.0,
#   202000000000000.0,
#   443000000000000.0,
#   529000000000000.0,
#   476000000000000.0,
#   236000000000000.0,
#   534000000000000.0,
#   392000000000000.0,
#   446000000000000.0,
#   458000000000000.0,
#   351000000000000.0,
#   543000000000000.0,
#   504000000000000.0,
#   48500000000000.0,
#   336000000000000.0,
#   260000000000000.0,
#   421000000000000.0,
#   1190000000000.0,
#   521000000000000.0,
#   522000000000000.0,
#   285000000000000.0,
#   397000000000000.0,
#   485000000000000.0,
#   530000000000000.0,
#   505000000000000.0,
#   531000000000000.0,
#   520000000000000.0,
#   492000000000000.0,
#   439000000000000.0,
#   552000000000000.0,
#   274000000000000.0,
#   554000000000000.0,
#   500000000000000.0,
#   511000000000000.0,
#   466000000000000.0,
#   525000000000000.0,
#   435000000000000.0,
#   472000000000000.0,
#   447000000000000.0,
#   550000000000000.0,
#   24900000000000.0,
#   548000000000000.0,
#   473000000000000.0,
#   410000000000000.0,
#   537000000000000.0,
#   9180000000000.0,
#   9190000000000.0,
#   9160000000000.0,
#   9150000000000.0,
#   9170000000000.0,
#   9200000000000.0,
#   424000000000000.0,
#   517000000000000.0,
#   382000000000000.0,
#   533000000000000.0,
#   489000000000000.0,
#   412000000000000.0,
#   411000000000000.0,
#   545000000000000.0,
#   480000000000000.0,
#   280000000000000.0,
#   269000000000000.0],
#  'case Spend area text': ['Packaging Type Case',
#   'Supply Chain Logistics',
#   'Sales',
#   'Latex & Monomers',
#   'Trading & End Products',
#   'Additives',
#   'Solvents',
#   ' ',
#   <NA>,
#   'CAPEX & SOCS',
#   'Specialty Resins',
#   'Pigments & Colorants',
#   'Titanium Dioxides',
#   'Real Estate',
#   'Commodity Resins',
#   'Marketing',
#   'Workforce Services',
#   'Spend Area Unidentified',
#   'Enterprise Services',
#   'Energy'],
#  'Company': ['company ID_A', 'company ID_C', <NA>, 'company ID_B'],
#  'case Document Type': ['Standard PO',
#   'EC Purchase order',
#   'Framework order',
#   <NA>],
#  'case Sub spend area text': ['Packaging - Other',
#   'Road Packed',
#   'Products for Resale',
#   'Sachets',
#   'Pure Acrylics',
#   'Metal Containers & Lids < 30L',
#   'Trading products (old structure)',
#   'Extenders',
#   'Labels',
#   'Neutralisation Agents',
#   'Glycol & Ether Solvents',
#   'Raw Material',
#   'Styrene Acrylics',
#   'Paperboard',
#   'Aliphatic Solvents',
#   'Packaging',
#   'Defoamers & Antifoams',
#   <NA>,
#   'Facility Management',
#   'Ester Solvents',
#   'Alcohol Solvents',
#   'Alkyd Resins',
#   'Surfactants',
#   'Specialty Resins Precursors',
#   'Effect Pigments',
#   'Chloride',
#   'Plastic Containers & Lids < 30L',
#   'Rheology & Thixotropic Agents',
#   'Customers',
#   'Colorants',
#   'Business Gifts & Promotional Items',
#   'Aromatic Solvents',
#   'Pallets',
#   'Polyurethane Resins',
#   'Biocides',
#   'Acrylic Resins ñ Liquid',
#   'Specialty Resins - Other',
#   'Opaque Polymers',
#   'Vinyl Acetate Ethylenes',
#   'Utilities',
#   'Sea',
#   'Real Estate - To Be Approved',
#   'Closures',
#   'Driers & Antiskinning Agents',
#   'Tubes',
#   'Inorganic Pigments',
#   'Commodity Resins Precursors',
#   'Drums',
#   'Plasticizers',
#   'Ketones Solvents',
#   'Epoxy Resins - Liquid',
#   'Polyamides & Polyamines',
#   'Caseins & Starches',
#   'Transport & Hoisting Equipment',
#   'Mixing Machines',
#   'MRO (components)',
#   'Waxes',
#   'Real estate brokers or agents',
#   'Point of Sales',
#   'Corrosion Inhibitors',
#   'Warehousing',
#   'Color Collateral',
#   'Pigments - Other',
#   'Commercial Printing',
#   'Sulphate',
#   'Other Logistics Services',
#   'Spend Area Unidentified',
#   'Laboratory Supplies & Services',
#   'Third Party Labor',
#   'Polyvinyl Acetates',
#   'Vinyl Acrylics',
#   'Isocyanates',
#   'Digital Marketing',
#   'Catalysts & Initiators',
#   'Equipment',
#   'ICT Software',
#   'Plastic Film',
#   'Intermediate Bulk Containers (IBC)',
#   'Latexes - Other',
#   'Light & Heat Stabilizers',
#   'Additives - Other',
#   'Jerry Cans',
#   'Organic Pigments',
#   'Express',
#   'Advertising',
#   'Polyester Resins - Liquid',
#   'Epoxy Resins - Solid',
#   'Technical Services',
#   'Process Automation & Instrumentation',
#   'Bags',
#   'Design',
#   'Travel & expenses',
#   'Solvents - Other',
#   'HR Services',
#   'Hybrid Containers',
#   'Office Supplies',
#   'LOGISTICS - TO BE APPROVED',
#   'Gasses',
#   'Adhesion Promotors',
#   'Fire Protection Agents'],
#  'case Purchasing Document': [4507038569.0,
#   4507038753.0,
#   4507038755.0,
#   4507038732.0,
#   4507038756.0,
#   4507038676.0,
#   4507037708.0,
#   4507035390.0,
#   4507035387.0,
#   4507035015.0,
#   4507038758.0,
#   4507036060.0,
#   4507033367.0,
#   4507033994.0,
#   4507030058.0,
#   4507038757.0,
#   4507037532.0,
#   4507035316.0,
#   4507038667.0,
#   2000033504.0,
#   4507026002.0,
#   4507038759.0,
#   4507023375.0,
#   4507021476.0,
#   4507032711.0,
#   4507024651.0,
#   4507030061.0,
#   4507036456.0,
#   4507038760.0,
#   4507035095.0,
#   4507038761.0,
#   4507038762.0,
#   4507035322.0,
#   4507026592.0,
#   4507035003.0,
#   4507038763.0,
#   4507023988.0,
#   4507037448.0,
#   4507038765.0,
#   4507036130.0,
#   4507038764.0,
#   4507029193.0,
#   4507022875.0,
#   4507038766.0,
#   4507037322.0,
#   4507037854.0,
#   4507029440.0,
#   4507036458.0,
#   4507038767.0,
#   4507038514.0,
#   4507031638.0,
#   4507020119.0,
#   4507036401.0,
#   4507038126.0,
#   4507005000.0,
#   4507038560.0,
#   4507030865.0,
#   4507016594.0,
#   4507037446.0,
#   4507035488.0,
#   4507035485.0,
#   4507014539.0,
#   4507016587.0,
#   4507030453.0,
#   4507036594.0,
#   4507032540.0,
#   4507016769.0,
#   4507038768.0,
#   4507036962.0,
#   4507026979.0,
#   4507030661.0,
#   4507038769.0,
#   4507031450.0,
#   4507024198.0,
#   4507037563.0,
#   4507034760.0,
#   4507034969.0,
#   4507003653.0,
#   4507038770.0,
#   4507023202.0,
#   4507018445.0,
#   4507028928.0,
#   2000000178.0,
#   4507035945.0,
#   4507036042.0,
#   4507038771.0,
#   4507037858.0,
#   4507019931.0,
#   4507027333.0,
#   4507033278.0,
#   4507036620.0,
#   4507037291.0,
#   4507035949.0,
#   4507038772.0,
#   4507034826.0,
#   4507038774.0,
#   4507038773.0,
#   4507036709.0,
#   4507035869.0,
#   4507038775.0],
#  'case Vendor': ['vendorID_0104',
#   'vendorID_0541',
#   'vendorID_0724',
#   'vendorID_0771',
#   'vendorID_0484',
#   'vendorID_1299',
#   'vendorID_1134',
#   'vendorID_0149',
#   'vendorID_0136',
#   'vendorID_0125',
#   'vendorID_0225',
#   'vendorID_0167',
#   'vendorID_0414',
#   'vendorID_0138',
#   'vendorID_0419',
#   'vendorID_0027',
#   'vendorID_0135',
#   'vendorID_0619',
#   'vendorID_0733',
#   'vendorID_0820',
#   'vendorID_1477',
#   'vendorID_0390',
#   'vendorID_0874',
#   'vendorID_0782',
#   'vendorID_0175',
#   'vendorID_0299',
#   'vendorID_0137',
#   'vendorID_0113',
#   'vendorID_0608',
#   'vendorID_0118',
#   'vendorID_0391',
#   'vendorID_0445',
#   'vendorID_0278',
#   'vendorID_0106',
#   'vendorID_0133',
#   'vendorID_1385',
#   'vendorID_0181',
#   'vendorID_0193',
#   'vendorID_0259',
#   'vendorID_0283',
#   'vendorID_0231',
#   'vendorID_0449',
#   'vendorID_1450',
#   'vendorID_0897',
#   'vendorID_0378',
#   'vendorID_1518',
#   'vendorID_0256',
#   'vendorID_0371',
#   'vendorID_0887',
#   'vendorID_1090',
#   'vendorID_0880',
#   'vendorID_0479',
#   'vendorID_0284',
#   'vendorID_0124',
#   'vendorID_0393',
#   'vendorID_0873',
#   'vendorID_1529',
#   'vendorID_0465',
#   'vendorID_0166',
#   'vendorID_0502',
#   'vendorID_0151',
#   'vendorID_0252',
#   'vendorID_1062',
#   'vendorID_0165',
#   'vendorID_0741',
#   'vendorID_0300',
#   'vendorID_1100',
#   'vendorID_0184',
#   'vendorID_1297',
#   'vendorID_0202',
#   'vendorID_0311',
#   'vendorID_0455',
#   'vendorID_0042',
#   'vendorID_0722',
#   'vendorID_0228',
#   'vendorID_0610',
#   'vendorID_0139',
#   'vendorID_0707',
#   'vendorID_0000',
#   'vendorID_0220',
#   'vendorID_0767',
#   'vendorID_0831',
#   'vendorID_0478',
#   'vendorID_0192',
#   'vendorID_0287',
#   'vendorID_0437',
#   'vendorID_0103',
#   'vendorID_0359',
#   'vendorID_0436',
#   'vendorID_0092',
#   'vendorID_0254',
#   'vendorID_0409',
#   'vendorID_0145',
#   'vendorID_0130',
#   'vendorID_0224',
#   'vendorID_0274',
#   'vendorID_0388',
#   'vendorID_0189',
#   'vendorID_0159',
#   'vendorID_1128'],
#  'case Item Type': ['Standard',
#   'Service',
#   'Consignment',
#   'Third-party',
#   'Subcontracting',
#   'Limit',
#   <NA>],
#  'case Item Category': ['3-way match, invoice before GR',
#   '3-way match, invoice after GR',
#   'Consignment',
#   '2-way match',
#   <NA>],
#  'case Spend classification text': ['PR', 'NPR', 'OTHER', <NA>],
#  'case Source': ['sourceSystemID_0000', <NA>],
#  'case Name': ['vendor_0104',
#   'vendor_0525',
#   'vendor_0693',
#   'vendor_0734',
#   'vendor_0468',
#   'vendor_0737',
#   'vendor_1078',
#   'vendor_0147',
#   'vendor_0135',
#   'vendor_0124',
#   'vendor_0220',
#   'vendor_0165',
#   'vendor_0403',
#   'vendor_0137',
#   'vendor_0408',
#   'vendor_0027',
#   'vendor_0134',
#   'vendor_0164',
#   'vendor_0113',
#   'vendor_0780',
#   'vendor_1410',
#   'vendor_0379',
#   'vendor_0834',
#   'vendor_0744',
#   'vendor_0173',
#   'vendor_0290',
#   'vendor_0136',
#   'vendor_0271',
#   'vendor_0117',
#   'vendor_0380',
#   'vendor_0432',
#   'vendor_0270',
#   'vendor_0106',
#   'vendor_0132',
#   'vendor_1322',
#   'vendor_0179',
#   'vendor_0190',
#   'vendor_0252',
#   'vendor_0275',
#   'vendor_0226',
#   'vendor_0436',
#   'vendor_1384',
#   'vendor_0856',
#   'vendor_0367',
#   'vendor_1449',
#   'vendor_0249',
#   'vendor_0360',
#   'vendor_0847',
#   'vendor_1039',
#   'vendor_0840',
#   'vendor_0143',
#   'vendor_0276',
#   'vendor_0123',
#   'vendor_0382',
#   'vendor_0833',
#   'vendor_1460',
#   'vendor_0450',
#   'vendor_0486',
#   'vendor_0149',
#   'vendor_0245',
#   'vendor_1013',
#   'vendor_0163',
#   'vendor_0706',
#   'vendor_0291',
#   'vendor_1047',
#   'vendor_1240',
#   'vendor_0199',
#   'vendor_0302',
#   'vendor_0441',
#   'vendor_0042',
#   'vendor_0691',
#   'vendor_0223',
#   'vendor_0590',
#   'vendor_0138',
#   'vendor_0000',
#   'vendor_0216',
#   'vendor_0791',
#   'vendor_0463',
#   'vendor_0189',
#   'vendor_0278',
#   'vendor_0424',
#   'vendor_0103',
#   'vendor_0416',
#   'vendor_0092',
#   'vendor_0247',
#   'vendor_0398',
#   'vendor_0144',
#   'vendor_0129',
#   'vendor_0219',
#   'vendor_0266',
#   'vendor_0377',
#   'vendor_0186',
#   'vendor_0157',
#   'vendor_1072',
#   'vendor_0213',
#   'vendor_0350',
#   'vendor_0107',
#   'vendor_0480',
#   'vendor_0148',
#   'vendor_0553'],
#  'C_GR-Based': ['False', 'True', <NA>],
#  'case Item': [220.0,
#   350.0,
#   1.0,
#   300.0,
#   210.0,
#   370.0,
#   340.0,
#   380.0,
#   360.0,
#   240.0,
#   250.0,
#   280.0,
#   190.0,
#   200.0,
#   20.0,
#   150.0,
#   180.0,
#   10.0,
#   60.0,
#   100.0,
#   90.0,
#   140.0,
#   110.0,
#   130.0,
#   160.0,
#   120.0,
#   80.0,
#   70.0,
#   170.0,
#   40.0,
#   50.0,
#   30.0,
#   260.0,
#   230.0,
#   270.0,
#   3.0,
#   390.0,
#   420.0,
#   410.0,
#   400.0,
#   310.0,
#   450.0,
#   430.0,
#   2.0,
#   440.0,
#   470.0,
#   480.0,
#   320.0,
#   490.0,
#   500.0,
#   510.0,
#   520.0,
#   460.0,
#   nan,
#   530.0,
#   540.0,
#   550.0,
#   560.0,
#   590.0,
#   290.0,
#   330.0,
#   610.0,
#   680.0,
#   660.0,
#   690.0,
#   600.0,
#   930.0,
#   700.0,
#   810.0,
#   650.0,
#   820.0,
#   640.0,
#   910.0,
#   570.0,
#   920.0,
#   620.0,
#   580.0,
#   840.0,
#   830.0,
#   630.0,
#   4.0,
#   670.0,
#   710.0,
#   720.0,
#   730.0,
#   740.0,
#   750.0,
#   760.0,
#   770.0,
#   780.0,
#   790.0,
#   800.0,
#   850.0,
#   860.0,
#   870.0,
#   880.0,
#   890.0,
#   900.0,
#   940.0,
#   950.0],
#  'case concept:name': ['4507038569_00220',
#   '4507038569_00350',
#   '4507038753_00001',
#   '4507038569_00300',
#   '4507038569_00210',
#   '4507038569_00370',
#   '4507038569_00340',
#   '4507038569_00380',
#   '4507038569_00360',
#   '4507038569_00240',
#   '4507038569_00250',
#   '4507038569_00280',
#   '4507038569_00190',
#   '4507038569_00200',
#   '4507038755_00020',
#   '4507038569_00150',
#   '4507038569_00180',
#   '4507038755_00010',
#   '4507038732_00010',
#   '4507038569_00060',
#   '4507038569_00100',
#   '4507038569_00090',
#   '4507038569_00140',
#   '4507038569_00110',
#   '4507038756_00010',
#   '4507038676_00010',
#   '4507037708_00110',
#   '4507035390_00010',
#   '4507035387_00010',
#   '4507035015_00150',
#   '4507038758_00130',
#   '4507038758_00220',
#   '4507038758_00160',
#   '4507038758_00210',
#   '4507038758_00200',
#   '4507038758_00190',
#   '4507038758_00120',
#   '4507038758_00180',
#   '4507038758_00080',
#   '4507038758_00070',
#   '4507036060_00010',
#   '4507038758_00150',
#   '4507038758_00170',
#   '4507038758_00100',
#   '4507033367_00040',
#   '4507038758_00050',
#   '4507038758_00110',
#   '4507038758_00090',
#   '4507038758_00040',
#   '4507033994_00010',
#   '4507030058_00010',
#   '4507033367_00050',
#   '4507038758_00060',
#   '4507033367_00130',
#   '4507038758_00020',
#   '4507038758_00140',
#   '4507038758_00010',
#   '4507038757_00010',
#   '4507038758_00030',
#   '4507038758_00260',
#   '4507038758_00250',
#   '4507038758_00240',
#   '4507038758_00230',
#   '4507037532_00080',
#   '4507035316_00030',
#   '4507035316_00040',
#   '4507035316_00070',
#   '4507038667_00020',
#   '4507038667_00030',
#   '4507038667_00040',
#   '2000033504_00001',
#   '4507026002_00010',
#   '4507038759_00010',
#   '4507023375_00010',
#   '4507021476_00010',
#   '4507032711_00010',
#   '4507024651_00010',
#   '4507037708_00040',
#   '4507037532_00040',
#   '4507030061_00010',
#   '4507036456_00010',
#   '4507038760_00010',
#   '4507037708_00050',
#   '4507037708_00030',
#   '4507037708_00080',
#   '4507037532_00050',
#   '4507035095_00010',
#   '4507037708_00090',
#   '4507037708_00060',
#   '4507038761_00010',
#   '4507038761_00020',
#   '4507038762_00010',
#   '4507037532_00160',
#   '4507035322_00050',
#   '4507026592_00030',
#   '4507035003_00010',
#   '4507038763_00030',
#   '4507038763_00020',
#   '4507038763_00010',
#   '4507037532_00090'],
#  'case Goods Receipt': ['True', 'False', <NA>],
#  'event User Account': ['user_063',
#   'NONE',
#   'user_200',
#   'user_164',
#   'user_168',
#   'user_187',
#   'user_085',
#   'user_061',
#   'user_064',
#   'user_107',
#   'user_068',
#   'user_104',
#   'user_142',
#   'user_172',
#   'user_046',
#   'batch_00',
#   'user_277',
#   'user_019',
#   'user_089',
#   'user_015',
#   'batch_12',
#   'user_239',
#   'user_020',
#   'batch_02',
#   'batch_05',
#   'user_062',
#   'user_029',
#   'user_384',
#   'user_059',
#   'user_045',
#   'user_012',
#   'user_033',
#   'user_077',
#   'user_001',
#   'user_080',
#   'user_216',
#   'user_377',
#   'user_177',
#   'user_013',
#   'user_099',
#   'user_016',
#   'user_096',
#   'user_193',
#   'user_182',
#   'user_060',
#   'user_000',
#   'user_075',
#   'user_057',
#   'user_125',
#   'user_158',
#   'user_152',
#   'user_188',
#   'user_151',
#   'batch_07',
#   'user_066',
#   'user_113',
#   <NA>,
#   'user_065',
#   'user_074',
#   'user_178',
#   'user_263',
#   'user_040',
#   'user_218',
#   'user_038',
#   'user_004',
#   'user_147',
#   'user_335',
#   'user_056',
#   'user_087',
#   'user_102',
#   'user_359',
#   'user_036',
#   'user_294',
#   'user_133',
#   'user_067',
#   'user_121',
#   'user_031',
#   'user_034',
#   'user_395',
#   'user_156',
#   'user_049',
#   'user_084',
#   'user_103',
#   'user_101',
#   'batch_03',
#   'user_120',
#   'user_138',
#   'user_311',
#   'user_043',
#   'user_388',
#   'user_253',
#   'user_176',
#   'user_283',
#   'user_086',
#   'user_058',
#   'user_128',
#   'user_181',
#   'user_184',
#   'user_037',
#   'user_206'],
#  'event org type resource': ['user_063',
#   'NONE',
#   'user_200',
#   'user_164',
#   'user_168',
#   'user_187',
#   'user_085',
#   'user_061',
#   'user_064',
#   'user_107',
#   'user_068',
#   'user_104',
#   'user_142',
#   'user_172',
#   'user_046',
#   'batch_00',
#   'user_277',
#   'user_019',
#   'user_089',
#   'user_015',
#   'batch_12',
#   'user_239',
#   'user_020',
#   'batch_02',
#   'batch_05',
#   'user_062',
#   'user_029',
#   'user_384',
#   'user_059',
#   'user_045',
#   'user_012',
#   'user_033',
#   'user_077',
#   'user_001',
#   'user_080',
#   'user_216',
#   'user_377',
#   'user_177',
#   'user_013',
#   'user_099',
#   'user_016',
#   'user_096',
#   'user_193',
#   'user_182',
#   'user_060',
#   'user_000',
#   'user_075',
#   'user_057',
#   'user_125',
#   'user_158',
#   'user_152',
#   'user_188',
#   'user_151',
#   'batch_07',
#   'user_066',
#   'user_113',
#   'user_176',
#   'user_117',
#   'user_092',
#   'user_034',
#   'user_039',
#   'user_087',
#   'user_359',
#   'user_167',
#   'user_084',
#   'user_147',
#   'user_058',
#   'user_133',
#   'user_065',
#   'user_105',
#   'user_335',
#   'user_049',
#   'user_030',
#   'user_184',
#   'user_044',
#   'user_038',
#   'user_042',
#   'user_263',
#   'user_135',
#   'user_232',
#   'user_091',
#   'user_159',
#   'user_074',
#   'user_178',
#   'user_040',
#   'user_218',
#   'user_004',
#   'user_056',
#   'user_102',
#   'user_036',
#   'user_294',
#   'user_067',
#   'user_121',
#   'user_031',
#   'user_395',
#   'user_156',
#   'user_103',
#   'user_101',
#   'batch_03',
#   'user_120'],
#  'Currency Costs in Dollars': [2346,
#   15640,
#   1829,
#   9950,
#   3519,
#   3659,
#   11876,
#   15249,
#   554447,
#   9308,
#   1564,
#   1955,
#   12518,
#   6256,
#   519,
#   3128,
#   4814,
#   1226,
#   483,
#   21185,
#   22469,
#   62353,
#   5466,
#   407,
#   0,
#   313,
#   381,
#   512,
#   524,
#   282,
#   1040,
#   4127,
#   612,
#   493,
#   285,
#   346,
#   387,
#   474,
#   204,
#   775,
#   9182,
#   19423,
#   570,
#   151,
#   250,
#   21131,
#   1634,
#   778,
#   200,
#   1763,
#   2071,
#   3628,
#   4421,
#   614,
#   753,
#   66404,
#   996,
#   6020,
#   8259,
#   26668,
#   1063,
#   452,
#   1251,
#   5359,
#   10082,
#   163,
#   327,
#   207,
#   447,
#   1593,
#   410,
#   90,
#   748,
#   783,
#   294,
#   622,
#   4844,
#   1915,
#   141,
#   308,
#   1439,
#   392,
#   1524,
#   4621,
#   286,
#   31,
#   34,
#   43,
#   473,
#   32,
#   110,
#   46,
#   471,
#   27,
#   231,
#   239,
#   73,
#   92,
#   564,
#   75]}

# %%
# Overview property: Length of the list of up to 100 unique entries
num_displayed_unique_entries_property = {}
for log_column in log_columns:
  unique_entries = event_log_table[log_column].unique()
  unique_entries = list(unique_entries)
  unique_entries = unique_entries[:100]
  num_displayed_unique_entries_property[log_column] = len(unique_entries)

overview_table.loc['Length of the list of up to 100 unique entries'] = num_displayed_unique_entries_property
num_displayed_unique_entries_property
# Out:
# {'caseID': 100,
#  'event time': 31,
#  'event concept:name': 37,
#  'event ID ': 100,
#  'case Spend area text': 20,
#  'Company': 4,
#  'case Document Type': 4,
#  'case Sub spend area text': 100,
#  'case Purchasing Document': 100,
#  'case Vendor': 100,
#  'case Item Type': 7,
#  'case Item Category': 5,
#  'case Spend classification text': 4,
#  'case Source': 2,
#  'case Name': 100,
#  'C_GR-Based': 3,
#  'case Item': 100,
#  'case concept:name': 100,
#  'case Goods Receipt': 3,
#  'event User Account': 100,
#  'event org type resource': 100,
#  'Currency Costs in Dollars': 100}

# %%
# Inspect the overview table
overview_table
# Out:
#                                                                                                caseID  \
# Event log column property
# BPI_C_2019_3rd_Supplier                                                       BPI_C_2019_3rd_Supplier
# Title                                                                                         Case ID
# Importance                                                                        Mandatory attribute
# Level                                                                                      Case level
# Data type                                                                                      string
# Number of entries                                                                              349526
# Number of unique entries                                                                        33958
# List up to 100 unique entries to view the struc...  [4507038569.0 Standard, 4507038753.0 Service, ...
# Length of the list of up to 100 unique entries                                                    100
#
#                                                                                            event time  \
# Event log column property
# BPI_C_2019_3rd_Supplier                                                       BPI_C_2019_3rd_Supplier
# Title                                                                                       Timestamp
# Importance                                                                        Mandatory attribute
# Level                                                                                     Event level
# Data type                                                      datetime64[ns, pytz.FixedOffset(-120)]
# Number of entries                                                                              349526
# Number of unique entries                                                                           31
# List up to 100 unique entries to view the struc...  [1970-01-01 00:00:25-02:00, 1970-01-01 00:00:2...
# Length of the list of up to 100 unique entries                                                     31
#
#                                                                                    event concept:name  \
# Event log column property
# BPI_C_2019_3rd_Supplier                                                       BPI_C_2019_3rd_Supplier
# Title                                                                                        Activity
# Importance                                                                        Mandatory attribute
# Level                                                                                     Event level
# Data type                                                                                      string
# Number of entries                                                                              349526
# Number of unique entries                                                                           37
# List up to 100 unique entries to view the struc...  [Receive Order Confirmation, Record Service En...
# Length of the list of up to 100 unique entries                                                     37
#
#                                                                                             event ID   \
# Event log column property
# BPI_C_2019_3rd_Supplier                                                       BPI_C_2019_3rd_Supplier
# Title                                                                                        Event ID
# Importance                                                                        Mandatory attribute
# Level                                                                                     Event level
# Data type                                                                                     float64
# Number of entries                                                                              349526
# Number of unique entries                                                                         1504
# List up to 100 unique entries to view the struc...  [555000000000000.0, 558000000000000.0, 5570000...
# Length of the list of up to 100 unique entries                                                    100
#
#                                                                                  case Spend area text  \
# Event log column property
# BPI_C_2019_3rd_Supplier                                                       BPI_C_2019_3rd_Supplier
# Title                                                                            case Spend area text
# Importance                                                                       Additional attribute
# Level                                                                                      Case level
# Data type                                                                                      string
# Number of entries                                                                              349526
# Number of unique entries                                                                           19
# List up to 100 unique entries to view the struc...  [Packaging Type Case, Supply Chain Logistics, ...
# Length of the list of up to 100 unique entries                                                     20
#
#                                                                                              Company  \
# Event log column property
# BPI_C_2019_3rd_Supplier                                                      BPI_C_2019_3rd_Supplier
# Title                                                                                        Company
# Importance                                                                      Additional attribute
# Level                                                                                            NaN
# Data type                                                                                     string
# Number of entries                                                                             349526
# Number of unique entries                                                                           3
# List up to 100 unique entries to view the struc...  [company ID_A, company ID_C, <NA>, company ID_B]
# Length of the list of up to 100 unique entries                                                     4
#
#                                                                                    case Document Type  \
# Event log column property
# BPI_C_2019_3rd_Supplier                                                       BPI_C_2019_3rd_Supplier
# Title                                                                              case Document Type
# Importance                                                                       Additional attribute
# Level                                                                                      Case level
# Data type                                                                                      string
# Number of entries                                                                              349526
# Number of unique entries                                                                            3
# List up to 100 unique entries to view the struc...  [Standard PO, EC Purchase order, Framework ord...
# Length of the list of up to 100 unique entries                                                      4
#
#                                                                              case Sub spend area text  \
# Event log column property
# BPI_C_2019_3rd_Supplier                                                       BPI_C_2019_3rd_Supplier
# Title                                                                        case Sub spend area text
# Importance                                                                       Additional attribute
# Level                                                                                      Case level
# Data type                                                                                      string
# Number of entries                                                                              349526
# Number of unique entries                                                                          131
# List up to 100 unique entries to view the struc...  [Packaging - Other, Road Packed, Products for ...
# Length of the list of up to 100 unique entries                                                    100
#
#                                                                              case Purchasing Document  \
# Event log column property
# BPI_C_2019_3rd_Supplier                                                       BPI_C_2019_3rd_Supplier
# Title                                                                        case Purchasing Document
# Importance                                                                       Additional attribute
# Level                                                                                      Case level
# Data type                                                                                     float64
# Number of entries                                                                              349526
# Number of unique entries                                                                        33621
# List up to 100 unique entries to view the struc...  [4507038569.0, 4507038753.0, 4507038755.0, 450...
# Length of the list of up to 100 unique entries                                                    100
#
#                                                                                           case Vendor  \
# Event log column property
# BPI_C_2019_3rd_Supplier                                                       BPI_C_2019_3rd_Supplier
# Title                                                                                     case Vendor
# Importance                                                                       Additional attribute
# Level                                                                                      Case level
# Data type                                                                                      string
# Number of entries                                                                              349526
# Number of unique entries                                                                         1465
# List up to 100 unique entries to view the struc...  [vendorID_0104, vendorID_0541, vendorID_0724, ...
# Length of the list of up to 100 unique entries                                                    100
#
#                                                     ...  \
# Event log column property                           ...
# BPI_C_2019_3rd_Supplier                             ...
# Title                                               ...
# Importance                                          ...
# Level                                               ...
# Data type                                           ...
# Number of entries                                   ...
# Number of unique entries                            ...
# List up to 100 unique entries to view the struc...  ...
# Length of the list of up to 100 unique entries      ...
#
#                                                     case Spend classification text  \
# Event log column property
# BPI_C_2019_3rd_Supplier                                    BPI_C_2019_3rd_Supplier
# Title                                               case Spend classification text
# Importance                                                    Additional attribute
# Level                                                                   Case level
# Data type                                                                   string
# Number of entries                                                           349526
# Number of unique entries                                                         3
# List up to 100 unique entries to view the struc...          [PR, NPR, OTHER, <NA>]
# Length of the list of up to 100 unique entries                                   4
#
#                                                                     case Source  \
# Event log column property
# BPI_C_2019_3rd_Supplier                                 BPI_C_2019_3rd_Supplier
# Title                                                               case Source
# Importance                                                 Additional attribute
# Level                                                                Case level
# Data type                                                                string
# Number of entries                                                        349526
# Number of unique entries                                                      1
# List up to 100 unique entries to view the struc...  [sourceSystemID_0000, <NA>]
# Length of the list of up to 100 unique entries                                2
#
#                                                                                             case Name  \
# Event log column property
# BPI_C_2019_3rd_Supplier                                                       BPI_C_2019_3rd_Supplier
# Title                                                                                       case Name
# Importance                                                                       Additional attribute
# Level                                                                                      Case level
# Data type                                                                                      string
# Number of entries                                                                              349526
# Number of unique entries                                                                         1401
# List up to 100 unique entries to view the struc...  [vendor_0104, vendor_0525, vendor_0693, vendor...
# Length of the list of up to 100 unique entries                                                    100
#
#                                                                  C_GR-Based  \
# Event log column property
# BPI_C_2019_3rd_Supplier                             BPI_C_2019_3rd_Supplier
# Title                                                            C_GR-Based
# Importance                                             Additional attribute
# Level                                                                   NaN
# Data type                                                            string
# Number of entries                                                    349526
# Number of unique entries                                                  2
# List up to 100 unique entries to view the struc...      [False, True, <NA>]
# Length of the list of up to 100 unique entries                            3
#
#                                                                                             case Item  \
# Event log column property
# BPI_C_2019_3rd_Supplier                                                       BPI_C_2019_3rd_Supplier
# Title                                                                                       case Item
# Importance                                                                       Additional attribute
# Level                                                                                      Case level
# Data type                                                                                     float64
# Number of entries                                                                              349526
# Number of unique entries                                                                          320
# List up to 100 unique entries to view the struc...  [220.0, 350.0, 1.0, 300.0, 210.0, 370.0, 340.0...
# Length of the list of up to 100 unique entries                                                    100
#
#                                                                                     case concept:name  \
# Event log column property
# BPI_C_2019_3rd_Supplier                                                       BPI_C_2019_3rd_Supplier
# Title                                                                               case concept:name
# Importance                                                                       Additional attribute
# Level                                                                                      Case level
# Data type                                                                                      string
# Number of entries                                                                              349526
# Number of unique entries                                                                       109813
# List up to 100 unique entries to view the struc...  [4507038569_00220, 4507038569_00350, 450703875...
# Length of the list of up to 100 unique entries                                                    100
#
#                                                          case Goods Receipt  \
# Event log column property
# BPI_C_2019_3rd_Supplier                             BPI_C_2019_3rd_Supplier
# Title                                                    case Goods Receipt
# Importance                                             Additional attribute
# Level                                                            Case level
# Data type                                                            string
# Number of entries                                                    349526
# Number of unique entries                                                  2
# List up to 100 unique entries to view the struc...      [True, False, <NA>]
# Length of the list of up to 100 unique entries                            3
#
#                                                                                    event User Account  \
# Event log column property
# BPI_C_2019_3rd_Supplier                                                       BPI_C_2019_3rd_Supplier
# Title                                                                              event User Account
# Importance                                                                       Additional attribute
# Level                                                                                     Event level
# Data type                                                                                      string
# Number of entries                                                                              349526
# Number of unique entries                                                                          431
# List up to 100 unique entries to view the struc...  [user_063, NONE, user_200, user_164, user_168,...
# Length of the list of up to 100 unique entries                                                    100
#
#                                                                               event org type resource  \
# Event log column property
# BPI_C_2019_3rd_Supplier                                                       BPI_C_2019_3rd_Supplier
# Title                                                                         event org type resource
# Importance                                                                       Additional attribute
# Level                                                                                     Event level
# Data type                                                                                      string
# Number of entries                                                                              349526
# Number of unique entries                                                                          431
# List up to 100 unique entries to view the struc...  [user_063, NONE, user_200, user_164, user_168,...
# Length of the list of up to 100 unique entries                                                    100
#
#                                                                             Currency Costs in Dollars
# Event log column property
# BPI_C_2019_3rd_Supplier                                                       BPI_C_2019_3rd_Supplier
# Title                                                                       Currency Costs in Dollars
# Importance                                                                       Additional attribute
# Level                                                                                             NaN
# Data type                                                                                       int64
# Number of entries                                                                              349526
# Number of unique entries                                                                        14473
# List up to 100 unique entries to view the struc...  [2346, 15640, 1829, 9950, 3519, 3659, 11876, 1...
# Length of the list of up to 100 unique entries                                                    100
#
# [9 rows x 22 columns]

# %%
# Overview property: Number of duplicate entries
number_of_duplicate_entries_property = {}
for log_column in log_columns:
  number_of_duplicate_entries_property[log_column] = number_of_entries_property[log_column] - number_of_unique_entries_property[log_column]

overview_table.loc['Number of duplicate entries'] = number_of_duplicate_entries_property
overview_table.loc['Number of duplicate entries']
# Out:
# caseID                            315568
# event time                        349495
# event concept:name                349489
# event ID                          348022
# case Spend area text              349507
# Company                           349523
# case Document Type                349523
# case Sub spend area text          349395
# case Purchasing Document          315905
# case Vendor                       348061
# case Item Type                    349520
# case Item Category                349522
# case Spend classification text    349523
# case Source                       349525
# case Name                         348125
# C_GR-Based                        349524
# case Item                         349206
# case concept:name                 239713
# case Goods Receipt                349524
# event User Account                349095
# event org type resource           349095
# Currency Costs in Dollars         335053
# Name: Number of duplicate entries, dtype: object

# %%
# Overview property: Number of undefined entries
number_of_undefined_entries_property = {}
nan_info = event_log_table.isna().sum()
for log_column in log_columns:
    number_of_undefined_entries_property[log_column] = nan_info[log_column]

overview_table.loc['Number of undefined entries'] = number_of_undefined_entries_property
number_of_undefined_entries_property
# Out:
# {'caseID': 3071,
#  'event time': 0,
#  'event concept:name': 0,
#  'event ID ': 1155,
#  'case Spend area text': 4161,
#  'Company': 1516,
#  'case Document Type': 1643,
#  'case Sub spend area text': 5363,
#  'case Purchasing Document': 3071,
#  'case Vendor': 2519,
#  'case Item Type': 1622,
#  'case Item Category': 1622,
#  'case Spend classification text': 4267,
#  'case Source': 2021,
#  'case Name': 1637,
#  'C_GR-Based': 1136,
#  'case Item': 1136,
#  'case concept:name': 1136,
#  'case Goods Receipt': 1136,
#  'event User Account': 1730,
#  'event org type resource': 994,
#  'Currency Costs in Dollars': 0}

# %%
# Overview propperty: Number of undefined entries in percentages
percentage_of_undefined_entries_property = {}
nan_info = event_log_table.isna().sum()
for log_column in log_columns:
    percentage = nan_info[log_column]/len(event_log_table)*100 #len calculates the length of a variable
    percentage = f'{percentage:.2f}'
    percentage_of_undefined_entries_property[log_column] = percentage

overview_table.loc['Percentage of undefined entries'] = percentage_of_undefined_entries_property
percentage_of_undefined_entries_property
# Out:
# {'caseID': '0.88',
#  'event time': '0.00',
#  'event concept:name': '0.00',
#  'event ID ': '0.33',
#  'case Spend area text': '1.19',
#  'Company': '0.43',
#  'case Document Type': '0.47',
#  'case Sub spend area text': '1.53',
#  'case Purchasing Document': '0.88',
#  'case Vendor': '0.72',
#  'case Item Type': '0.46',
#  'case Item Category': '0.46',
#  'case Spend classification text': '1.22',
#  'case Source': '0.58',
#  'case Name': '0.47',
#  'C_GR-Based': '0.33',
#  'case Item': '0.33',
#  'case concept:name': '0.33',
#  'case Goods Receipt': '0.33',
#  'event User Account': '0.49',
#  'event org type resource': '0.28',
#  'Currency Costs in Dollars': '0.00'}

# %%
overview_table
# Out:
#                                                                                                caseID  \
# Event log column property
# BPI_C_2019_3rd_Supplier                                                       BPI_C_2019_3rd_Supplier
# Title                                                                                         Case ID
# Importance                                                                        Mandatory attribute
# Level                                                                                      Case level
# Data type                                                                                      string
# Number of entries                                                                              349526
# Number of unique entries                                                                        33958
# List up to 100 unique entries to view the struc...  [4507038569.0 Standard, 4507038753.0 Service, ...
# Length of the list of up to 100 unique entries                                                    100
# Number of duplicate entries                                                                    315568
# Number of undefined entries                                                                      3071
# Percentage of undefined entries                                                                  0.88
#
#                                                                                            event time  \
# Event log column property
# BPI_C_2019_3rd_Supplier                                                       BPI_C_2019_3rd_Supplier
# Title                                                                                       Timestamp
# Importance                                                                        Mandatory attribute
# Level                                                                                     Event level
# Data type                                                      datetime64[ns, pytz.FixedOffset(-120)]
# Number of entries                                                                              349526
# Number of unique entries                                                                           31
# List up to 100 unique entries to view the struc...  [1970-01-01 00:00:25-02:00, 1970-01-01 00:00:2...
# Length of the list of up to 100 unique entries                                                     31
# Number of duplicate entries                                                                    349495
# Number of undefined entries                                                                         0
# Percentage of undefined entries                                                                  0.00
#
#                                                                                    event concept:name  \
# Event log column property
# BPI_C_2019_3rd_Supplier                                                       BPI_C_2019_3rd_Supplier
# Title                                                                                        Activity
# Importance                                                                        Mandatory attribute
# Level                                                                                     Event level
# Data type                                                                                      string
# Number of entries                                                                              349526
# Number of unique entries                                                                           37
# List up to 100 unique entries to view the struc...  [Receive Order Confirmation, Record Service En...
# Length of the list of up to 100 unique entries                                                     37
# Number of duplicate entries                                                                    349489
# Number of undefined entries                                                                         0
# Percentage of undefined entries                                                                  0.00
#
#                                                                                             event ID   \
# Event log column property
# BPI_C_2019_3rd_Supplier                                                       BPI_C_2019_3rd_Supplier
# Title                                                                                        Event ID
# Importance                                                                        Mandatory attribute
# Level                                                                                     Event level
# Data type                                                                                     float64
# Number of entries                                                                              349526
# Number of unique entries                                                                         1504
# List up to 100 unique entries to view the struc...  [555000000000000.0, 558000000000000.0, 5570000...
# Length of the list of up to 100 unique entries                                                    100
# Number of duplicate entries                                                                    348022
# Number of undefined entries                                                                      1155
# Percentage of undefined entries                                                                  0.33
#
#                                                                                  case Spend area text  \
# Event log column property
# BPI_C_2019_3rd_Supplier                                                       BPI_C_2019_3rd_Supplier
# Title                                                                            case Spend area text
# Importance                                                                       Additional attribute
# Level                                                                                      Case level
# Data type                                                                                      string
# Number of entries                                                                              349526
# Number of unique entries                                                                           19
# List up to 100 unique entries to view the struc...  [Packaging Type Case, Supply Chain Logistics, ...
# Length of the list of up to 100 unique entries                                                     20
# Number of duplicate entries                                                                    349507
# Number of undefined entries                                                                      4161
# Percentage of undefined entries                                                                  1.19
#
#                                                                                              Company  \
# Event log column property
# BPI_C_2019_3rd_Supplier                                                      BPI_C_2019_3rd_Supplier
# Title                                                                                        Company
# Importance                                                                      Additional attribute
# Level                                                                                            NaN
# Data type                                                                                     string
# Number of entries                                                                             349526
# Number of unique entries                                                                           3
# List up to 100 unique entries to view the struc...  [company ID_A, company ID_C, <NA>, company ID_B]
# Length of the list of up to 100 unique entries                                                     4
# Number of duplicate entries                                                                   349523
# Number of undefined entries                                                                     1516
# Percentage of undefined entries                                                                 0.43
#
#                                                                                    case Document Type  \
# Event log column property
# BPI_C_2019_3rd_Supplier                                                       BPI_C_2019_3rd_Supplier
# Title                                                                              case Document Type
# Importance                                                                       Additional attribute
# Level                                                                                      Case level
# Data type                                                                                      string
# Number of entries                                                                              349526
# Number of unique entries                                                                            3
# List up to 100 unique entries to view the struc...  [Standard PO, EC Purchase order, Framework ord...
# Length of the list of up to 100 unique entries                                                      4
# Number of duplicate entries                                                                    349523
# Number of undefined entries                                                                      1643
# Percentage of undefined entries                                                                  0.47
#
#                                                                              case Sub spend area text  \
# Event log column property
# BPI_C_2019_3rd_Supplier                                                       BPI_C_2019_3rd_Supplier
# Title                                                                        case Sub spend area text
# Importance                                                                       Additional attribute
# Level                                                                                      Case level
# Data type                                                                                      string
# Number of entries                                                                              349526
# Number of unique entries                                                                          131
# List up to 100 unique entries to view the struc...  [Packaging - Other, Road Packed, Products for ...
# Length of the list of up to 100 unique entries                                                    100
# Number of duplicate entries                                                                    349395
# Number of undefined entries                                                                      5363
# Percentage of undefined entries                                                                  1.53
#
#                                                                              case Purchasing Document  \
# Event log column property
# BPI_C_2019_3rd_Supplier                                                       BPI_C_2019_3rd_Supplier
# Title                                                                        case Purchasing Document
# Importance                                                                       Additional attribute
# Level                                                                                      Case level
# Data type                                                                                     float64
# Number of entries                                                                              349526
# Number of unique entries                                                                        33621
# List up to 100 unique entries to view the struc...  [4507038569.0, 4507038753.0, 4507038755.0, 450...
# Length of the list of up to 100 unique entries                                                    100
# Number of duplicate entries                                                                    315905
# Number of undefined entries                                                                      3071
# Percentage of undefined entries                                                                  0.88
#
#                                                                                           case Vendor  \
# Event log column property
# BPI_C_2019_3rd_Supplier                                                       BPI_C_2019_3rd_Supplier
# Title                                                                                     case Vendor
# Importance                                                                       Additional attribute
# Level                                                                                      Case level
# Data type                                                                                      string
# Number of entries                                                                              349526
# Number of unique entries                                                                         1465
# List up to 100 unique entries to view the struc...  [vendorID_0104, vendorID_0541, vendorID_0724, ...
# Length of the list of up to 100 unique entries                                                    100
# Number of duplicate entries                                                                    348061
# Number of undefined entries                                                                      2519
# Percentage of undefined entries                                                                  0.72
#
#                                                     ...  \
# Event log column property                           ...
# BPI_C_2019_3rd_Supplier                             ...
# Title                                               ...
# Importance                                          ...
# Level                                               ...
# Data type                                           ...
# Number of entries                                   ...
# Number of unique entries                            ...
# List up to 100 unique entries to view the struc...  ...
# Length of the list of up to 100 unique entries      ...
# Number of duplicate entries                         ...
# Number of undefined entries                         ...
# Percentage of undefined entries                     ...
#
#                                                     case Spend classification text  \
# Event log column property
# BPI_C_2019_3rd_Supplier                                    BPI_C_2019_3rd_Supplier
# Title                                               case Spend classification text
# Importance                                                    Additional attribute
# Level                                                                   Case level
# Data type                                                                   string
# Number of entries                                                           349526
# Number of unique entries                                                         3
# List up to 100 unique entries to view the struc...          [PR, NPR, OTHER, <NA>]
# Length of the list of up to 100 unique entries                                   4
# Number of duplicate entries                                                 349523
# Number of undefined entries                                                   4267
# Percentage of undefined entries                                               1.22
#
#                                                                     case Source  \
# Event log column property
# BPI_C_2019_3rd_Supplier                                 BPI_C_2019_3rd_Supplier
# Title                                                               case Source
# Importance                                                 Additional attribute
# Level                                                                Case level
# Data type                                                                string
# Number of entries                                                        349526
# Number of unique entries                                                      1
# List up to 100 unique entries to view the struc...  [sourceSystemID_0000, <NA>]
# Length of the list of up to 100 unique entries                                2
# Number of duplicate entries                                              349525
# Number of undefined entries                                                2021
# Percentage of undefined entries                                            0.58
#
#                                                                                             case Name  \
# Event log column property
# BPI_C_2019_3rd_Supplier                                                       BPI_C_2019_3rd_Supplier
# Title                                                                                       case Name
# Importance                                                                       Additional attribute
# Level                                                                                      Case level
# Data type                                                                                      string
# Number of entries                                                                              349526
# Number of unique entries                                                                         1401
# List up to 100 unique entries to view the struc...  [vendor_0104, vendor_0525, vendor_0693, vendor...
# Length of the list of up to 100 unique entries                                                    100
# Number of duplicate entries                                                                    348125
# Number of undefined entries                                                                      1637
# Percentage of undefined entries                                                                  0.47
#
#                                                                  C_GR-Based  \
# Event log column property
# BPI_C_2019_3rd_Supplier                             BPI_C_2019_3rd_Supplier
# Title                                                            C_GR-Based
# Importance                                             Additional attribute
# Level                                                                   NaN
# Data type                                                            string
# Number of entries                                                    349526
# Number of unique entries                                                  2
# List up to 100 unique entries to view the struc...      [False, True, <NA>]
# Length of the list of up to 100 unique entries                            3
# Number of duplicate entries                                          349524
# Number of undefined entries                                            1136
# Percentage of undefined entries                                        0.33
#
#                                                                                             case Item  \
# Event log column property
# BPI_C_2019_3rd_Supplier                                                       BPI_C_2019_3rd_Supplier
# Title                                                                                       case Item
# Importance                                                                       Additional attribute
# Level                                                                                      Case level
# Data type                                                                                     float64
# Number of entries                                                                              349526
# Number of unique entries                                                                          320
# List up to 100 unique entries to view the struc...  [220.0, 350.0, 1.0, 300.0, 210.0, 370.0, 340.0...
# Length of the list of up to 100 unique entries                                                    100
# Number of duplicate entries                                                                    349206
# Number of undefined entries                                                                      1136
# Percentage of undefined entries                                                                  0.33
#
#                                                                                     case concept:name  \
# Event log column property
# BPI_C_2019_3rd_Supplier                                                       BPI_C_2019_3rd_Supplier
# Title                                                                               case concept:name
# Importance                                                                       Additional attribute
# Level                                                                                      Case level
# Data type                                                                                      string
# Number of entries                                                                              349526
# Number of unique entries                                                                       109813
# List up to 100 unique entries to view the struc...  [4507038569_00220, 4507038569_00350, 450703875...
# Length of the list of up to 100 unique entries                                                    100
# Number of duplicate entries                                                                    239713
# Number of undefined entries                                                                      1136
# Percentage of undefined entries                                                                  0.33
#
#                                                          case Goods Receipt  \
# Event log column property
# BPI_C_2019_3rd_Supplier                             BPI_C_2019_3rd_Supplier
# Title                                                    case Goods Receipt
# Importance                                             Additional attribute
# Level                                                            Case level
# Data type                                                            string
# Number of entries                                                    349526
# Number of unique entries                                                  2
# List up to 100 unique entries to view the struc...      [True, False, <NA>]
# Length of the list of up to 100 unique entries                            3
# Number of duplicate entries                                          349524
# Number of undefined entries                                            1136
# Percentage of undefined entries                                        0.33
#
#                                                                                    event User Account  \
# Event log column property
# BPI_C_2019_3rd_Supplier                                                       BPI_C_2019_3rd_Supplier
# Title                                                                              event User Account
# Importance                                                                       Additional attribute
# Level                                                                                     Event level
# Data type                                                                                      string
# Number of entries                                                                              349526
# Number of unique entries                                                                          431
# List up to 100 unique entries to view the struc...  [user_063, NONE, user_200, user_164, user_168,...
# Length of the list of up to 100 unique entries                                                    100
# Number of duplicate entries                                                                    349095
# Number of undefined entries                                                                      1730
# Percentage of undefined entries                                                                  0.49
#
#                                                                               event org type resource  \
# Event log column property
# BPI_C_2019_3rd_Supplier                                                       BPI_C_2019_3rd_Supplier
# Title                                                                         event org type resource
# Importance                                                                       Additional attribute
# Level                                                                                     Event level
# Data type                                                                                      string
# Number of entries                                                                              349526
# Number of unique entries                                                                          431
# List up to 100 unique entries to view the struc...  [user_063, NONE, user_200, user_164, user_168,...
# Length of the list of up to 100 unique entries                                                    100
# Number of duplicate entries                                                                    349095
# Number of undefined entries                                                                       994
# Percentage of undefined entries                                                                  0.28
#
#                                                                             Currency Costs in Dollars
# Event log column property
# BPI_C_2019_3rd_Supplier                                                       BPI_C_2019_3rd_Supplier
# Title                                                                       Currency Costs in Dollars
# Importance                                                                       Additional attribute
# Level                                                                                             NaN
# Data type                                                                                       int64
# Number of entries                                                                              349526
# Number of unique entries                                                                        14473
# List up to 100 unique entries to view the struc...  [2346, 15640, 1829, 9950, 3519, 3659, 11876, 1...
# Length of the list of up to 100 unique entries                                                    100
# Number of duplicate entries                                                                    335053
# Number of undefined entries                                                                         0
# Percentage of undefined entries                                                                  0.00
#
# [12 rows x 22 columns]

# %%
# Switching the index of the Meta-DataFrame and table structure
# The current layout of the Meta-Dataframe is transformed, that the columns become the rows, and the rows become the columns.
overview_table = overview_table.T
overview_table.reset_index(inplace = True)
overview_table.rename(columns={'index': 'Property'}, inplace = True)
overview_table
# Out:
# Event log column property                        Property  \
# 0                                                  caseID
# 1                                              event time
# 2                                      event concept:name
# 3                                               event ID
# 4                                    case Spend area text
# 5                                                 Company
# 6                                      case Document Type
# 7                                case Sub spend area text
# 8                                case Purchasing Document
# 9                                             case Vendor
# 10                                         case Item Type
# 11                                     case Item Category
# 12                         case Spend classification text
# 13                                            case Source
# 14                                              case Name
# 15                                             C_GR-Based
# 16                                              case Item
# 17                                      case concept:name
# 18                                     case Goods Receipt
# 19                                     event User Account
# 20                                event org type resource
# 21                              Currency Costs in Dollars
#
# Event log column property  BPI_C_2019_3rd_Supplier  \
# 0                          BPI_C_2019_3rd_Supplier
# 1                          BPI_C_2019_3rd_Supplier
# 2                          BPI_C_2019_3rd_Supplier
# 3                          BPI_C_2019_3rd_Supplier
# 4                          BPI_C_2019_3rd_Supplier
# 5                          BPI_C_2019_3rd_Supplier
# 6                          BPI_C_2019_3rd_Supplier
# 7                          BPI_C_2019_3rd_Supplier
# 8                          BPI_C_2019_3rd_Supplier
# 9                          BPI_C_2019_3rd_Supplier
# 10                         BPI_C_2019_3rd_Supplier
# 11                         BPI_C_2019_3rd_Supplier
# 12                         BPI_C_2019_3rd_Supplier
# 13                         BPI_C_2019_3rd_Supplier
# 14                         BPI_C_2019_3rd_Supplier
# 15                         BPI_C_2019_3rd_Supplier
# 16                         BPI_C_2019_3rd_Supplier
# 17                         BPI_C_2019_3rd_Supplier
# 18                         BPI_C_2019_3rd_Supplier
# 19                         BPI_C_2019_3rd_Supplier
# 20                         BPI_C_2019_3rd_Supplier
# 21                         BPI_C_2019_3rd_Supplier
#
# Event log column property                           Title  \
# 0                                                 Case ID
# 1                                               Timestamp
# 2                                                Activity
# 3                                                Event ID
# 4                                    case Spend area text
# 5                                                 Company
# 6                                      case Document Type
# 7                                case Sub spend area text
# 8                                case Purchasing Document
# 9                                             case Vendor
# 10                                         case Item Type
# 11                                     case Item Category
# 12                         case Spend classification text
# 13                                            case Source
# 14                                              case Name
# 15                                             C_GR-Based
# 16                                              case Item
# 17                                      case concept:name
# 18                                     case Goods Receipt
# 19                                     event User Account
# 20                                event org type resource
# 21                              Currency Costs in Dollars
#
# Event log column property            Importance        Level  \
# 0                           Mandatory attribute   Case level
# 1                           Mandatory attribute  Event level
# 2                           Mandatory attribute  Event level
# 3                           Mandatory attribute  Event level
# 4                          Additional attribute   Case level
# 5                          Additional attribute          NaN
# 6                          Additional attribute   Case level
# 7                          Additional attribute   Case level
# 8                          Additional attribute   Case level
# 9                          Additional attribute   Case level
# 10                         Additional attribute   Case level
# 11                         Additional attribute   Case level
# 12                         Additional attribute   Case level
# 13                         Additional attribute   Case level
# 14                         Additional attribute   Case level
# 15                         Additional attribute          NaN
# 16                         Additional attribute   Case level
# 17                         Additional attribute   Case level
# 18                         Additional attribute   Case level
# 19                         Additional attribute  Event level
# 20                         Additional attribute  Event level
# 21                         Additional attribute          NaN
#
# Event log column property                               Data type  \
# 0                                                          string
# 1                          datetime64[ns, pytz.FixedOffset(-120)]
# 2                                                          string
# 3                                                         float64
# 4                                                          string
# 5                                                          string
# 6                                                          string
# 7                                                          string
# 8                                                         float64
# 9                                                          string
# 10                                                         string
# 11                                                         string
# 12                                                         string
# 13                                                         string
# 14                                                         string
# 15                                                         string
# 16                                                        float64
# 17                                                         string
# 18                                                         string
# 19                                                         string
# 20                                                         string
# 21                                                          int64
#
# Event log column property Number of entries Number of unique entries  \
# 0                                    349526                    33958
# 1                                    349526                       31
# 2                                    349526                       37
# 3                                    349526                     1504
# 4                                    349526                       19
# 5                                    349526                        3
# 6                                    349526                        3
# 7                                    349526                      131
# 8                                    349526                    33621
# 9                                    349526                     1465
# 10                                   349526                        6
# 11                                   349526                        4
# 12                                   349526                        3
# 13                                   349526                        1
# 14                                   349526                     1401
# 15                                   349526                        2
# 16                                   349526                      320
# 17                                   349526                   109813
# 18                                   349526                        2
# 19                                   349526                      431
# 20                                   349526                      431
# 21                                   349526                    14473
#
# Event log column property List up to 100 unique entries to view the structure of the event attributes  \
# 0                          [4507038569.0 Standard, 4507038753.0 Service, ...
# 1                          [1970-01-01 00:00:25-02:00, 1970-01-01 00:00:2...
# 2                          [Receive Order Confirmation, Record Service En...
# 3                          [555000000000000.0, 558000000000000.0, 5570000...
# 4                          [Packaging Type Case, Supply Chain Logistics, ...
# 5                           [company ID_A, company ID_C, <NA>, company ID_B]
# 6                          [Standard PO, EC Purchase order, Framework ord...
# 7                          [Packaging - Other, Road Packed, Products for ...
# 8                          [4507038569.0, 4507038753.0, 4507038755.0, 450...
# 9                          [vendorID_0104, vendorID_0541, vendorID_0724, ...
# 10                         [Standard, Service, Consignment, Third-party, ...
# 11                         [3-way match, invoice before GR, 3-way match, ...
# 12                                                    [PR, NPR, OTHER, <NA>]
# 13                                               [sourceSystemID_0000, <NA>]
# 14                         [vendor_0104, vendor_0525, vendor_0693, vendor...
# 15                                                       [False, True, <NA>]
# 16                         [220.0, 350.0, 1.0, 300.0, 210.0, 370.0, 340.0...
# 17                         [4507038569_00220, 4507038569_00350, 450703875...
# 18                                                       [True, False, <NA>]
# 19                         [user_063, NONE, user_200, user_164, user_168,...
# 20                         [user_063, NONE, user_200, user_164, user_168,...
# 21                         [2346, 15640, 1829, 9950, 3519, 3659, 11876, 1...
#
# Event log column property Length of the list of up to 100 unique entries  \
# 0                                                                    100
# 1                                                                     31
# 2                                                                     37
# 3                                                                    100
# 4                                                                     20
# 5                                                                      4
# 6                                                                      4
# 7                                                                    100
# 8                                                                    100
# 9                                                                    100
# 10                                                                     7
# 11                                                                     5
# 12                                                                     4
# 13                                                                     2
# 14                                                                   100
# 15                                                                     3
# 16                                                                   100
# 17                                                                   100
# 18                                                                     3
# 19                                                                   100
# 20                                                                   100
# 21                                                                   100
#
# Event log column property Number of duplicate entries  \
# 0                                              315568
# 1                                              349495
# 2                                              349489
# 3                                              348022
# 4                                              349507
# 5                                              349523
# 6                                              349523
# 7                                              349395
# 8                                              315905
# 9                                              348061
# 10                                             349520
# 11                                             349522
# 12                                             349523
# 13                                             349525
# 14                                             348125
# 15                                             349524
# 16                                             349206
# 17                                             239713
# 18                                             349524
# 19                                             349095
# 20                                             349095
# 21                                             335053
#
# Event log column property Number of undefined entries  \
# 0                                                3071
# 1                                                   0
# 2                                                   0
# 3                                                1155
# 4                                                4161
# 5                                                1516
# 6                                                1643
# 7                                                5363
# 8                                                3071
# 9                                                2519
# 10                                               1622
# 11                                               1622
# 12                                               4267
# 13                                               2021
# 14                                               1637
# 15                                               1136
# 16                                               1136
# 17                                               1136
# 18                                               1136
# 19                                               1730
# 20                                                994
# 21                                                  0
#
# Event log column property Percentage of undefined entries
# 0                                                    0.88
# 1                                                    0.00
# 2                                                    0.00
# 3                                                    0.33
# 4                                                    1.19
# 5                                                    0.43
# 6                                                    0.47
# 7                                                    1.53
# 8                                                    0.88
# 9                                                    0.72
# 10                                                   0.46
# 11                                                   0.46
# 12                                                   1.22
# 13                                                   0.58
# 14                                                   0.47
# 15                                                   0.33
# 16                                                   0.33
# 17                                                   0.33
# 18                                                   0.33
# 19                                                   0.49
# 20                                                   0.28
# 21                                                   0.00

# %%
#Now we will out put this csv in the analysis folder

if not os.path.exists('analysis'):
    os.mkdir('analysis')
overview_table.to_csv(f'analysis/overview_{event_log_name}.csv')

(f'Written: datatype table to analysis/overview_{event_log_name}.csv')
# Out:
# 'Written: datatype table to analysis/overview_BPI_C_2019_3_final_synthetic.csv'

# %% [markdown]
# <h2> Exploring the dataset's longest case </h2>
# This code piece identifies the longest case in an event log table and creates a separate dataframe containing only those events.
# Using the groupby() and size() functions, the code groups the events in the event log table by their case IDs and counts the number of occurrences in each case. This method returns a Pandas Series object containing the event count for each case ID.
# The argmax() function is then used to determine the index of the case with the most events. The case ID is then accessed using the index property of the Series object, passing the index acquired in the previous step as an input.
# Then, a new dataframe containing only the events of the longest case is generated by filtering the event log table using the caseID column and retaining only the rows that match the case ID of the longest case. The generated dataframe is then sorted ascending by the 'event time' column.
# The filtered dataframe is then saved as a CSV file in the "analysis" folder, with the name "longest case in event log name.csv." The file name is then converted into Neo4j commands that could be used to model the graph in a separate Neo4j database, revealing the event activity sequences in a directly follows graph.

# %%
#This is an exploratory code snippet checking for the longest case to model the graph in a deperate database to reveal the event activity sequences in a directly follows graph
case_sizes = event_log_table.groupby(['caseID']).size()
#use of argmax() instead of max()
index_of_longest_case = case_sizes.argmax()
caseID_of_longest_case = case_sizes.index[index_of_longest_case] 


# Without the .copy() suffix, we get: A value is trying to be set on a copy of a slice from a DataFrame
case_rows = event_log_table[event_log_table['caseID'] == caseID_of_longest_case].copy()
case_rows.sort_values(by='event time', ascending=True, inplace=True)
case_rows.to_csv(f'analysis/longest_case_in_{event_log_name}.csv')

# a csv table is created in the analysis file which is then transformed into Neo4j commands

# %% [markdown]
# # End of Script 1 to generate the Meta-DataFrame
# Author: Kyle Smith <br>
# Script: For Masterthesis <br>
# University: University of Camerino & University of Applied Sciences Northwestern Switzerland

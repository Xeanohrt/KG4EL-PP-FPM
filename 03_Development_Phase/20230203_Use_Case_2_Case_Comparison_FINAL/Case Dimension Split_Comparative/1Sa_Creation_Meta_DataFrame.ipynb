# %% [markdown]
# # First Script: Creating the Meta-DataFrame
# In this script the author analyzes each column of the synthetic BPI_C 2019 event logs.

# %%
#import libraries
import json
import os
import pandas as pd
import numpy
import re

# %%
event_log_name = 'BPIC_Synthetic_Split_1' #addd the name of the event log - change for each event log
event_log_file_path = f'event_logs/{event_log_name}.csv' #string interpolation, one has to create a folder called 'event_logs' to import the event log.csv
print(event_log_file_path) # review the path
# Out:
# event_logs/BPIC_Synthetic_Split_1.csv

# %%
#import the event log
event_log_table = pd.read_csv(event_log_file_path) #optionally this can be added; header = 0, encoding = 'ISO-8859-1') if encoding issues arise
event_log_table.head(20) #view the first 20 rows
# Out:
#         eventID  case Spend area text    case Company case Document Type  \
# 0   0.000000e+00         CAPEX & SOCS  companyID_0000  EC Purchase order
# 1   6.000000e+00         CAPEX & SOCS  companyID_0000  EC Purchase order
# 2   3.000000e+00         CAPEX & SOCS  companyID_0000  EC Purchase order
# 3   2.000000e+00         CAPEX & SOCS  companyID_0000  EC Purchase order
# 4   1.000000e+00         CAPEX & SOCS  companyID_0000  EC Purchase order
# 5   4.000000e+00         CAPEX & SOCS  companyID_0000  EC Purchase order
# 6   5.000000e+00         CAPEX & SOCS  companyID_0000  EC Purchase order
# 7   7.000000e+00         CAPEX & SOCS  companyID_0000  EC Purchase order
# 8   8.000000e+00         CAPEX & SOCS  companyID_0000  EC Purchase order
# 9   9.000000e+00         CAPEX & SOCS  companyID_0000  EC Purchase order
# 10  1.000000e+01         CAPEX & SOCS  companyID_0000  EC Purchase order
# 11  1.100000e+01         CAPEX & SOCS  companyID_0000  EC Purchase order
# 12  4.294967e+09            Marketing  companyID_0000  EC Purchase order
# 13  4.294967e+09            Marketing  companyID_0000  EC Purchase order
# 14  4.294967e+09            Marketing  companyID_0000  EC Purchase order
# 15  4.294967e+09            Marketing  companyID_0000  EC Purchase order
# 16  4.294967e+09            Marketing  companyID_0000  EC Purchase order
# 17  4.294967e+09            Marketing  companyID_0000  EC Purchase order
# 18  4.294967e+09            Marketing  companyID_0000  EC Purchase order
# 19  4.294967e+09            Marketing  companyID_0000  EC Purchase order
#
#       case Sub spend area text  case Purchasing Document  \
# 0          Facility Management                2000000000
# 1          Facility Management                2000000000
# 2          Facility Management                2000000000
# 3          Facility Management                2000000000
# 4          Facility Management                2000000000
# 5          Facility Management                2000000000
# 6          Facility Management                2000000000
# 7          Facility Management                2000000000
# 8          Facility Management                2000000000
# 9          Facility Management                2000000000
# 10         Facility Management                2000000000
# 11         Facility Management                2000000000
# 12  Marketing Support Services                2000000001
# 13  Marketing Support Services                2000000001
# 14  Marketing Support Services                2000000001
# 15  Marketing Support Services                2000000001
# 16  Marketing Support Services                2000000001
# 17  Marketing Support Services                2000000001
# 18  Marketing Support Services                2000000001
# 19  Marketing Support Services                2000000001
#
#    case Purch. Doc. Category name    case Vendor case Item Type  \
# 0                  Purchase order  vendorID_0000       Standard
# 1                  Purchase order  vendorID_0000       Standard
# 2                  Purchase order  vendorID_0000       Standard
# 3                  Purchase order  vendorID_0000       Standard
# 4                  Purchase order  vendorID_0000       Standard
# 5                  Purchase order  vendorID_0000       Standard
# 6                  Purchase order  vendorID_0000       Standard
# 7                  Purchase order  vendorID_0000       Standard
# 8                  Purchase order  vendorID_0000       Standard
# 9                  Purchase order  vendorID_0000       Standard
# 10                 Purchase order  vendorID_0000       Standard
# 11                 Purchase order  vendorID_0000       Standard
# 12                 Purchase order  vendorID_0001        Service
# 13                 Purchase order  vendorID_0001        Service
# 14                 Purchase order  vendorID_0001        Service
# 15                 Purchase order  vendorID_0001        Service
# 16                 Purchase order  vendorID_0001        Service
# 17                 Purchase order  vendorID_0001        Service
# 18                 Purchase order  vendorID_0001        Service
# 19                 Purchase order  vendorID_0001        Service
#
#                 case Item Category  ... case GR-Based Inv. Verif. case Item  \
# 0   3-way match, invoice before GR  ...                     False         1
# 1   3-way match, invoice before GR  ...                     False         1
# 2   3-way match, invoice before GR  ...                     False         1
# 3   3-way match, invoice before GR  ...                     False         1
# 4   3-way match, invoice before GR  ...                     False         1
# 5   3-way match, invoice before GR  ...                     False         1
# 6   3-way match, invoice before GR  ...                     False         1
# 7   3-way match, invoice before GR  ...                     False         1
# 8   3-way match, invoice before GR  ...                     False         1
# 9   3-way match, invoice before GR  ...                     False         1
# 10  3-way match, invoice before GR  ...                     False         1
# 11  3-way match, invoice before GR  ...                     False         1
# 12   3-way match, invoice after GR  ...                      True         1
# 13   3-way match, invoice after GR  ...                      True         1
# 14   3-way match, invoice after GR  ...                      True         1
# 15   3-way match, invoice after GR  ...                      True         1
# 16   3-way match, invoice after GR  ...                      True         1
# 17   3-way match, invoice after GR  ...                      True         1
# 18   3-way match, invoice after GR  ...                      True         1
# 19   3-way match, invoice after GR  ...                      True         1
#
#    case concept:name  case Goods Receipt  event User event org:resource  \
# 0   2000000000_00001                True    batch_00           batch_00
# 1   2000000000_00001                True    batch_00           batch_00
# 2   2000000000_00001                True    batch_00           batch_00
# 3   2000000000_00001                True    batch_00           batch_00
# 4   2000000000_00001                True    batch_00           batch_00
# 5   2000000000_00001                True    batch_00           batch_00
# 6   2000000000_00001                True    batch_00           batch_00
# 7   2000000000_00001                True    user_000           user_000
# 8   2000000000_00001                True        NONE               NONE
# 9   2000000000_00001                True    user_000           user_000
# 10  2000000000_00001                True    user_001           user_001
# 11  2000000000_00001                True    user_002           user_002
# 12  2000000001_00001                True    batch_00           batch_00
# 13  2000000001_00001                True    batch_00           batch_00
# 14  2000000001_00001                True    batch_00           batch_00
# 15  2000000001_00001                True    batch_00           batch_00
# 16  2000000001_00001                True    batch_00           batch_00
# 17  2000000001_00001                True    batch_00           batch_00
# 18  2000000001_00001                True    user_000           user_000
# 19  2000000001_00001                True    batch_00           batch_00
#
#                      event concept:name event Cumulative net worth (EUR)  \
# 0                          SRM: Created                              298
# 1           SRM: Change was Transmitted                              298
# 2               SRM: Document Completed                              298
# 3                SRM: Awaiting Approval                              298
# 4                         SRM: Complete                              298
# 5   SRM: In Transfer to Execution Syst.                              298
# 6                          SRM: Ordered                              298
# 7            Create Purchase Order Item                              298
# 8                Vendor creates invoice                              298
# 9                  Record Goods Receipt                              298
# 10               Record Invoice Receipt                              298
# 11                        Clear Invoice                              298
# 12                         SRM: Created                              557
# 13              SRM: Document Completed                              557
# 14               SRM: Awaiting Approval                              557
# 15                         SRM: Ordered                              557
# 16  SRM: In Transfer to Execution Syst.                              557
# 17          SRM: Change was Transmitted                              557
# 18           Create Purchase Order Item                              557
# 19                        SRM: Complete                              557
#
#        event time:timestamp        caseID
# 0   02-01-2018 13:53:00.000  2000000000 1
# 1   02-01-2018 14:53:00.000  2000000000 1
# 2   02-01-2018 14:53:00.000  2000000000 1
# 3   02-01-2018 14:53:00.000  2000000000 1
# 4   02-01-2018 14:53:00.000  2000000000 1
# 5   02-01-2018 14:53:00.000  2000000000 1
# 6   02-01-2018 14:53:00.000  2000000000 1
# 7   02-01-2018 14:53:00.000  2000000000 1
# 8   02-01-2018 23:59:00.000  2000000000 1
# 9   06-03-2018 07:44:00.000  2000000000 1
# 10  06-03-2018 08:53:00.000  2000000000 1
# 11  29-03-2018 15:06:00.000  2000000000 1
# 12  03-01-2018 09:49:00.000  2000000001 1
# 13  03-01-2018 10:49:00.000  2000000001 1
# 14  03-01-2018 10:49:00.000  2000000001 1
# 15  03-01-2018 10:49:00.000  2000000001 1
# 16  03-01-2018 10:49:00.000  2000000001 1
# 17  03-01-2018 10:49:00.000  2000000001 1
# 18  03-01-2018 10:49:00.000  2000000001 1
# 19  03-01-2018 10:49:00.000  2000000001 1
#
# [20 rows x 23 columns]

# %%
#review changes on the last column
event_log_table
# Out:
#             eventID  case Spend area text    case Company case Document Type  \
# 0       0.000000e+00         CAPEX & SOCS  companyID_0000  EC Purchase order
# 1       6.000000e+00         CAPEX & SOCS  companyID_0000  EC Purchase order
# 2       3.000000e+00         CAPEX & SOCS  companyID_0000  EC Purchase order
# 3       2.000000e+00         CAPEX & SOCS  companyID_0000  EC Purchase order
# 4       1.000000e+00         CAPEX & SOCS  companyID_0000  EC Purchase order
# ...              ...                  ...             ...                ...
# 349519  2.270000e+14            Logistics  companyID_0000        Standard PO
# 349520  2.270000e+14            Logistics  companyID_0000        Standard PO
# 349521  2.270000e+14            Logistics  companyID_0000        Standard PO
# 349522  2.270000e+14            Logistics  companyID_0000        Standard PO
# 349523  2.270000e+14            Logistics  companyID_0000        Standard PO
#
#        case Sub spend area text  case Purchasing Document  \
# 0           Facility Management                2000000000
# 1           Facility Management                2000000000
# 2           Facility Management                2000000000
# 3           Facility Management                2000000000
# 4           Facility Management                2000000000
# ...                         ...                       ...
# 349519              Road Packed                4507016139
# 349520              Road Packed                4507016139
# 349521              Road Packed                4507016139
# 349522              Road Packed                4507016139
# 349523              Road Packed                4507016139
#
#        case Purch. Doc. Category name    case Vendor case Item Type  \
# 0                      Purchase order  vendorID_0000       Standard
# 1                      Purchase order  vendorID_0000       Standard
# 2                      Purchase order  vendorID_0000       Standard
# 3                      Purchase order  vendorID_0000       Standard
# 4                      Purchase order  vendorID_0000       Standard
# ...                               ...            ...            ...
# 349519                 Purchase order  vendorID_0472        Service
# 349520                 Purchase order  vendorID_0472        Service
# 349521                 Purchase order  vendorID_0472        Service
# 349522                 Purchase order  vendorID_0472        Service
# 349523                 Purchase order  vendorID_0472        Service
#
#                     case Item Category  ... case GR-Based Inv. Verif.  \
# 0       3-way match, invoice before GR  ...                     False
# 1       3-way match, invoice before GR  ...                     False
# 2       3-way match, invoice before GR  ...                     False
# 3       3-way match, invoice before GR  ...                     False
# 4       3-way match, invoice before GR  ...                     False
# ...                                ...  ...                       ...
# 349519   3-way match, invoice after GR  ...                      True
# 349520   3-way match, invoice after GR  ...                      True
# 349521   3-way match, invoice after GR  ...                      True
# 349522   3-way match, invoice after GR  ...                      True
# 349523   3-way match, invoice after GR  ...                      True
#
#        case Item case concept:name  case Goods Receipt  event User  \
# 0              1  2000000000_00001                True    batch_00
# 1              1  2000000000_00001                True    batch_00
# 2              1  2000000000_00001                True    batch_00
# 3              1  2000000000_00001                True    batch_00
# 4              1  2000000000_00001                True    batch_00
# ...          ...               ...                 ...         ...
# 349519         1  4507016139_00001                True    batch_07
# 349520         1  4507016139_00001                True        NONE
# 349521         1  4507016139_00001                True        NONE
# 349522         1  4507016139_00001                True        NONE
# 349523         1  4507016139_00001                True        NONE
#
#        event org:resource           event concept:name  \
# 0                batch_00                 SRM: Created
# 1                batch_00  SRM: Change was Transmitted
# 2                batch_00      SRM: Document Completed
# 3                batch_00       SRM: Awaiting Approval
# 4                batch_00                SRM: Complete
# ...                   ...                          ...
# 349519           batch_07         Record Goods Receipt
# 349520               NONE   Record Service Entry Sheet
# 349521               NONE   Record Service Entry Sheet
# 349522               NONE   Record Service Entry Sheet
# 349523               NONE   Record Service Entry Sheet
#
#        event Cumulative net worth (EUR)     event time:timestamp        caseID
# 0                                   298  02-01-2018 13:53:00.000  2000000000 1
# 1                                   298  02-01-2018 14:53:00.000  2000000000 1
# 2                                   298  02-01-2018 14:53:00.000  2000000000 1
# 3                                   298  02-01-2018 14:53:00.000  2000000000 1
# 4                                   298  02-01-2018 14:53:00.000  2000000000 1
# ...                                 ...                      ...           ...
# 349519                              650  14-03-2018 02:10:00.000  4507016139 1
# 349520                               72  14-03-2018 02:10:00.000  4507016139 1
# 349521                               72  14-03-2018 02:10:00.000  4507016139 1
# 349522                               72  14-03-2018 02:11:00.000  4507016139 1
# 349523                               72  14-03-2018 02:11:00.000  4507016139 1
#
# [349524 rows x 23 columns]

# %%
event_log_table.columns
# Out:
# Index(['eventID ', 'case Spend area text', 'case Company',
#        'case Document Type', 'case Sub spend area text',
#        'case Purchasing Document', 'case Purch. Doc. Category name',
#        'case Vendor', 'case Item Type', 'case Item Category',
#        'case Spend classification text', 'case Source', 'case Name',
#        'case GR-Based Inv. Verif.', 'case Item', 'case concept:name',
#        'case Goods Receipt', 'event User', 'event org:resource',
#        'event concept:name', 'event Cumulative net worth (EUR)',
#        'event time:timestamp', 'caseID'],
#       dtype='object')

# %%
#Review all og the event log columns, to decide which ones are mandatory and which ones are additional

log_columns = event_log_table.columns
log_columns # this variable is important for the Meta-DataFrame generation
# Out:
# Index(['eventID ', 'case Spend area text', 'case Company',
#        'case Document Type', 'case Sub spend area text',
#        'case Purchasing Document', 'case Purch. Doc. Category name',
#        'case Vendor', 'case Item Type', 'case Item Category',
#        'case Spend classification text', 'case Source', 'case Name',
#        'case GR-Based Inv. Verif.', 'case Item', 'case concept:name',
#        'case Goods Receipt', 'event User', 'event org:resource',
#        'event concept:name', 'event Cumulative net worth (EUR)',
#        'event time:timestamp', 'caseID'],
#       dtype='object')

# %%
# This has to be tailored to each event log
#caseID is created from 'case Purchasing Document' and 'case Item', define the mandatory columns based on domain knowledge analysis

mandatory_columns = ['caseID', 'event time:timestamp', 'event concept:name', 'eventID ']

#Create an object/dictionary and corresponding key:value pairs to add the semantic titles which the csv titles represent in a variable  which are relevant for the Meta-DataFrame
titles = {
  'caseID': 'Case ID',
  'event concept:name': 'Activity',
  'eventID ': 'Event ID',
  'event time:timestamp': 'Timestamp',
}

print(mandatory_columns)
# Out:
# ['caseID', 'event time:timestamp', 'event concept:name', 'eventID ']

# %%
#Review titles object which are relevant for the Meta-DataFrame
titles
# Out:
# {'caseID': 'Case ID',
#  'event concept:name': 'Activity',
#  'eventID ': 'Event ID',
#  'event time:timestamp': 'Timestamp'}

# %%
#Review the datatypes for datatype harmonization
event_log_table.dtypes
# Out:
# eventID                             float64
# case Spend area text                 object
# case Company                         object
# case Document Type                   object
# case Sub spend area text             object
# case Purchasing Document              int64
# case Purch. Doc. Category name       object
# case Vendor                          object
# case Item Type                       object
# case Item Category                   object
# case Spend classification text       object
# case Source                          object
# case Name                            object
# case GR-Based Inv. Verif.              bool
# case Item                             int64
# case concept:name                    object
# case Goods Receipt                     bool
# event User                           object
# event org:resource                   object
# event concept:name                   object
# event Cumulative net worth (EUR)      int64
# event time:timestamp                 object
# caseID                               object
# dtype: object

# %%
#This step is optional to minimize the work needed in harmonization

#Translate object data types of timestamp data into a datetime64[ns] data type for the timestamp. This is a unique datatype from pandas.
timestamp_objects = event_log_table['event time:timestamp'] #declare timestamp to a variable
event_log_table['event time:timestamp']=pd.to_datetime(timestamp_objects)

#Review changes made
#event_log_table['event time:timestamp'].dtypes
event_log_table.dtypes
# Out:
# eventID                                    float64
# case Spend area text                        object
# case Company                                object
# case Document Type                          object
# case Sub spend area text                    object
# case Purchasing Document                     int64
# case Purch. Doc. Category name              object
# case Vendor                                 object
# case Item Type                              object
# case Item Category                          object
# case Spend classification text              object
# case Source                                 object
# case Name                                   object
# case GR-Based Inv. Verif.                     bool
# case Item                                    int64
# case concept:name                           object
# case Goods Receipt                            bool
# event User                                  object
# event org:resource                          object
# event concept:name                          object
# event Cumulative net worth (EUR)             int64
# event time:timestamp                datetime64[ns]
# caseID                                      object
# dtype: object

# %%
#This step is optional to minimize the work needed in harmonization 

#Translate object data types of object data types (which contains different possible formats) to a clear string data type format
#for loops where used as they enable somewhat automated transformations 
# = for assigning values
# == operator is used to test equality
for log_column in log_columns:
    if event_log_table[log_column].dtype == 'object': #check if the column has an object data type
        event_log_table[log_column] = event_log_table[log_column].astype('string') #change it to a string

#Review changes
#event_log_table['event time:timestamp'].dtypes
event_log_table.dtypes
# Out:
# eventID                                    float64
# case Spend area text                        string
# case Company                                string
# case Document Type                          string
# case Sub spend area text                    string
# case Purchasing Document                     int64
# case Purch. Doc. Category name              string
# case Vendor                                 string
# case Item Type                              string
# case Item Category                          string
# case Spend classification text              string
# case Source                                 string
# case Name                                   string
# case GR-Based Inv. Verif.                     bool
# case Item                                    int64
# case concept:name                           string
# case Goods Receipt                            bool
# event User                                  string
# event org:resource                          string
# event concept:name                          string
# event Cumulative net worth (EUR)             int64
# event time:timestamp                datetime64[ns]
# caseID                                      string
# dtype: object

# %%
# Reorder the columns of the event log table.
# Checking the log columns list contains each item on the mandatory columns list with the assert statement raises an 'AssertionError' if any of the elements are missing. 
# With the delete method and the == operator, the items are removed in the mandatory columns list from the log columns list.
# Then  using the + operator to combine the mandatory columns list and the log columns list (which has been turned into a list using the tolist method). By doing so, a fresh list of columns in # the desired order is created. Using the [] operator to select only the columns in the newly created list, subsetting the event log table DataFrame. By doing this, the columns in the new #DataFrame are created in the desired order.

for mandatory_column in mandatory_columns:
  assert mandatory_column in log_columns 
  log_columns = log_columns.delete(log_columns == mandatory_column)
log_columns = mandatory_columns + log_columns.tolist()

event_log_table = event_log_table[log_columns]
event_log_table #the for loop above resultes in a move of the mandatory columns to the left side (changes order)
# Out:
#               caseID event time:timestamp           event concept:name  \
# 0       2000000000 1  2018-02-01 13:53:00                 SRM: Created
# 1       2000000000 1  2018-02-01 14:53:00  SRM: Change was Transmitted
# 2       2000000000 1  2018-02-01 14:53:00      SRM: Document Completed
# 3       2000000000 1  2018-02-01 14:53:00       SRM: Awaiting Approval
# 4       2000000000 1  2018-02-01 14:53:00                SRM: Complete
# ...              ...                  ...                          ...
# 349519  4507016139 1  2018-03-14 02:10:00         Record Goods Receipt
# 349520  4507016139 1  2018-03-14 02:10:00   Record Service Entry Sheet
# 349521  4507016139 1  2018-03-14 02:10:00   Record Service Entry Sheet
# 349522  4507016139 1  2018-03-14 02:11:00   Record Service Entry Sheet
# 349523  4507016139 1  2018-03-14 02:11:00   Record Service Entry Sheet
#
#             eventID  case Spend area text    case Company case Document Type  \
# 0       0.000000e+00         CAPEX & SOCS  companyID_0000  EC Purchase order
# 1       6.000000e+00         CAPEX & SOCS  companyID_0000  EC Purchase order
# 2       3.000000e+00         CAPEX & SOCS  companyID_0000  EC Purchase order
# 3       2.000000e+00         CAPEX & SOCS  companyID_0000  EC Purchase order
# 4       1.000000e+00         CAPEX & SOCS  companyID_0000  EC Purchase order
# ...              ...                  ...             ...                ...
# 349519  2.270000e+14            Logistics  companyID_0000        Standard PO
# 349520  2.270000e+14            Logistics  companyID_0000        Standard PO
# 349521  2.270000e+14            Logistics  companyID_0000        Standard PO
# 349522  2.270000e+14            Logistics  companyID_0000        Standard PO
# 349523  2.270000e+14            Logistics  companyID_0000        Standard PO
#
#        case Sub spend area text  case Purchasing Document  \
# 0           Facility Management                2000000000
# 1           Facility Management                2000000000
# 2           Facility Management                2000000000
# 3           Facility Management                2000000000
# 4           Facility Management                2000000000
# ...                         ...                       ...
# 349519              Road Packed                4507016139
# 349520              Road Packed                4507016139
# 349521              Road Packed                4507016139
# 349522              Road Packed                4507016139
# 349523              Road Packed                4507016139
#
#        case Purch. Doc. Category name  ... case Spend classification text  \
# 0                      Purchase order  ...                            NPR
# 1                      Purchase order  ...                            NPR
# 2                      Purchase order  ...                            NPR
# 3                      Purchase order  ...                            NPR
# 4                      Purchase order  ...                            NPR
# ...                               ...  ...                            ...
# 349519                 Purchase order  ...                            NPR
# 349520                 Purchase order  ...                            NPR
# 349521                 Purchase order  ...                            NPR
# 349522                 Purchase order  ...                            NPR
# 349523                 Purchase order  ...                            NPR
#
#                 case Source    case Name case GR-Based Inv. Verif. case Item  \
# 0       sourceSystemID_0000  vendor_0000                     False         1
# 1       sourceSystemID_0000  vendor_0000                     False         1
# 2       sourceSystemID_0000  vendor_0000                     False         1
# 3       sourceSystemID_0000  vendor_0000                     False         1
# 4       sourceSystemID_0000  vendor_0000                     False         1
# ...                     ...          ...                       ...       ...
# 349519  sourceSystemID_0000  vendor_0457                      True         1
# 349520  sourceSystemID_0000  vendor_0457                      True         1
# 349521  sourceSystemID_0000  vendor_0457                      True         1
# 349522  sourceSystemID_0000  vendor_0457                      True         1
# 349523  sourceSystemID_0000  vendor_0457                      True         1
#
#        case concept:name  case Goods Receipt  event User event org:resource  \
# 0       2000000000_00001                True    batch_00           batch_00
# 1       2000000000_00001                True    batch_00           batch_00
# 2       2000000000_00001                True    batch_00           batch_00
# 3       2000000000_00001                True    batch_00           batch_00
# 4       2000000000_00001                True    batch_00           batch_00
# ...                  ...                 ...         ...                ...
# 349519  4507016139_00001                True    batch_07           batch_07
# 349520  4507016139_00001                True        NONE               NONE
# 349521  4507016139_00001                True        NONE               NONE
# 349522  4507016139_00001                True        NONE               NONE
# 349523  4507016139_00001                True        NONE               NONE
#
#         event Cumulative net worth (EUR)
# 0                                    298
# 1                                    298
# 2                                    298
# 3                                    298
# 4                                    298
# ...                                  ...
# 349519                               650
# 349520                                72
# 349521                                72
# 349522                                72
# 349523                                72
#
# [349524 rows x 23 columns]

# %% [markdown]
# Here we are going to reset the index and reorder the event log with a new index
#
# Setting the inplace parameter to True and using the reset index method to reset the DataFrame's index.
# This adds a new column to the DataFrame containing the old index values and resets the index to a range of sequential integers beginning at 0.
# Using the rename method and the inplace parameter set to True, rename the column containing the previous index values.
# A dictionary that maps the old column name "index" to the new column name "EventIndex" makes up the columns parameter.
# Using the set index method and the inplace parameter set to True, the DataFrame's index is changed to the 'EventIndex' column.
# This will remove the "EventIndex" column from the data and make it the new index of the DataFrame.

# %%
# Number every single event in the event log.
# Every single event is represented by a line in the event log file.
event_log_table.reset_index(inplace=True)
event_log_table.rename(columns={'index': 'EventIndex'}, inplace=True)
event_log_table.set_index('EventIndex', inplace=True)

#review changes
event_log_table
# Out:
# /var/folders/vz/snd73j8d2mj817493bt9ykfc0000gn/T/ipykernel_53696/2322881527.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   event_log_table.rename(columns={'index': 'EventIndex'}, inplace=True)
#                   caseID event time:timestamp           event concept:name  \
# EventIndex
# 0           2000000000 1  2018-02-01 13:53:00                 SRM: Created
# 1           2000000000 1  2018-02-01 14:53:00  SRM: Change was Transmitted
# 2           2000000000 1  2018-02-01 14:53:00      SRM: Document Completed
# 3           2000000000 1  2018-02-01 14:53:00       SRM: Awaiting Approval
# 4           2000000000 1  2018-02-01 14:53:00                SRM: Complete
# ...                  ...                  ...                          ...
# 349519      4507016139 1  2018-03-14 02:10:00         Record Goods Receipt
# 349520      4507016139 1  2018-03-14 02:10:00   Record Service Entry Sheet
# 349521      4507016139 1  2018-03-14 02:10:00   Record Service Entry Sheet
# 349522      4507016139 1  2018-03-14 02:11:00   Record Service Entry Sheet
# 349523      4507016139 1  2018-03-14 02:11:00   Record Service Entry Sheet
#
#                 eventID  case Spend area text    case Company  \
# EventIndex
# 0           0.000000e+00         CAPEX & SOCS  companyID_0000
# 1           6.000000e+00         CAPEX & SOCS  companyID_0000
# 2           3.000000e+00         CAPEX & SOCS  companyID_0000
# 3           2.000000e+00         CAPEX & SOCS  companyID_0000
# 4           1.000000e+00         CAPEX & SOCS  companyID_0000
# ...                  ...                  ...             ...
# 349519      2.270000e+14            Logistics  companyID_0000
# 349520      2.270000e+14            Logistics  companyID_0000
# 349521      2.270000e+14            Logistics  companyID_0000
# 349522      2.270000e+14            Logistics  companyID_0000
# 349523      2.270000e+14            Logistics  companyID_0000
#
#            case Document Type case Sub spend area text  \
# EventIndex
# 0           EC Purchase order      Facility Management
# 1           EC Purchase order      Facility Management
# 2           EC Purchase order      Facility Management
# 3           EC Purchase order      Facility Management
# 4           EC Purchase order      Facility Management
# ...                       ...                      ...
# 349519            Standard PO              Road Packed
# 349520            Standard PO              Road Packed
# 349521            Standard PO              Road Packed
# 349522            Standard PO              Road Packed
# 349523            Standard PO              Road Packed
#
#             case Purchasing Document case Purch. Doc. Category name  ...  \
# EventIndex                                                           ...
# 0                         2000000000                 Purchase order  ...
# 1                         2000000000                 Purchase order  ...
# 2                         2000000000                 Purchase order  ...
# 3                         2000000000                 Purchase order  ...
# 4                         2000000000                 Purchase order  ...
# ...                              ...                            ...  ...
# 349519                    4507016139                 Purchase order  ...
# 349520                    4507016139                 Purchase order  ...
# 349521                    4507016139                 Purchase order  ...
# 349522                    4507016139                 Purchase order  ...
# 349523                    4507016139                 Purchase order  ...
#
#            case Spend classification text          case Source    case Name  \
# EventIndex
# 0                                     NPR  sourceSystemID_0000  vendor_0000
# 1                                     NPR  sourceSystemID_0000  vendor_0000
# 2                                     NPR  sourceSystemID_0000  vendor_0000
# 3                                     NPR  sourceSystemID_0000  vendor_0000
# 4                                     NPR  sourceSystemID_0000  vendor_0000
# ...                                   ...                  ...          ...
# 349519                                NPR  sourceSystemID_0000  vendor_0457
# 349520                                NPR  sourceSystemID_0000  vendor_0457
# 349521                                NPR  sourceSystemID_0000  vendor_0457
# 349522                                NPR  sourceSystemID_0000  vendor_0457
# 349523                                NPR  sourceSystemID_0000  vendor_0457
#
#            case GR-Based Inv. Verif. case Item case concept:name  \
# EventIndex
# 0                              False         1  2000000000_00001
# 1                              False         1  2000000000_00001
# 2                              False         1  2000000000_00001
# 3                              False         1  2000000000_00001
# 4                              False         1  2000000000_00001
# ...                              ...       ...               ...
# 349519                          True         1  4507016139_00001
# 349520                          True         1  4507016139_00001
# 349521                          True         1  4507016139_00001
# 349522                          True         1  4507016139_00001
# 349523                          True         1  4507016139_00001
#
#             case Goods Receipt  event User event org:resource  \
# EventIndex
# 0                         True    batch_00           batch_00
# 1                         True    batch_00           batch_00
# 2                         True    batch_00           batch_00
# 3                         True    batch_00           batch_00
# 4                         True    batch_00           batch_00
# ...                        ...         ...                ...
# 349519                    True    batch_07           batch_07
# 349520                    True        NONE               NONE
# 349521                    True        NONE               NONE
# 349522                    True        NONE               NONE
# 349523                    True        NONE               NONE
#
#             event Cumulative net worth (EUR)
# EventIndex
# 0                                        298
# 1                                        298
# 2                                        298
# 3                                        298
# 4                                        298
# ...                                      ...
# 349519                                   650
# 349520                                    72
# 349521                                    72
# 349522                                    72
# 349523                                    72
#
# [349524 rows x 23 columns]

# %%
#defining a new dictionary  overview_columns with log columns as the elements
content_overview_columns = [(log_column, ['Supplier1_Comparative_Mining']) for log_column in log_columns]
extra_overview_columns = [('Event log column property', ['Supplier1_Comparative_Mining'])]
overview_columns = dict(extra_overview_columns + content_overview_columns)
overview_table = pd.DataFrame(overview_columns)

# To add a vertically indented name to the index in the console output.
overview_table.set_index('Event log column property', inplace=True)
overview_columns
# Out:
# {'Event log column property': ['Supplier1_Comparative_Mining'],
#  'caseID': ['Supplier1_Comparative_Mining'],
#  'event time:timestamp': ['Supplier1_Comparative_Mining'],
#  'event concept:name': ['Supplier1_Comparative_Mining'],
#  'eventID ': ['Supplier1_Comparative_Mining'],
#  'case Spend area text': ['Supplier1_Comparative_Mining'],
#  'case Company': ['Supplier1_Comparative_Mining'],
#  'case Document Type': ['Supplier1_Comparative_Mining'],
#  'case Sub spend area text': ['Supplier1_Comparative_Mining'],
#  'case Purchasing Document': ['Supplier1_Comparative_Mining'],
#  'case Purch. Doc. Category name': ['Supplier1_Comparative_Mining'],
#  'case Vendor': ['Supplier1_Comparative_Mining'],
#  'case Item Type': ['Supplier1_Comparative_Mining'],
#  'case Item Category': ['Supplier1_Comparative_Mining'],
#  'case Spend classification text': ['Supplier1_Comparative_Mining'],
#  'case Source': ['Supplier1_Comparative_Mining'],
#  'case Name': ['Supplier1_Comparative_Mining'],
#  'case GR-Based Inv. Verif.': ['Supplier1_Comparative_Mining'],
#  'case Item': ['Supplier1_Comparative_Mining'],
#  'case concept:name': ['Supplier1_Comparative_Mining'],
#  'case Goods Receipt': ['Supplier1_Comparative_Mining'],
#  'event User': ['Supplier1_Comparative_Mining'],
#  'event org:resource': ['Supplier1_Comparative_Mining'],
#  'event Cumulative net worth (EUR)': ['Supplier1_Comparative_Mining']}

# %%
#view the new overview_table to construct the Meta-DataFrame
overview_table
# Out:
#                                                     caseID  \
# Event log column property
# Supplier1_Comparative_Mining  Supplier1_Comparative_Mining
#
#                                       event time:timestamp  \
# Event log column property
# Supplier1_Comparative_Mining  Supplier1_Comparative_Mining
#
#                                         event concept:name  \
# Event log column property
# Supplier1_Comparative_Mining  Supplier1_Comparative_Mining
#
#                                                   eventID   \
# Event log column property
# Supplier1_Comparative_Mining  Supplier1_Comparative_Mining
#
#                                       case Spend area text  \
# Event log column property
# Supplier1_Comparative_Mining  Supplier1_Comparative_Mining
#
#                                               case Company  \
# Event log column property
# Supplier1_Comparative_Mining  Supplier1_Comparative_Mining
#
#                                         case Document Type  \
# Event log column property
# Supplier1_Comparative_Mining  Supplier1_Comparative_Mining
#
#                                   case Sub spend area text  \
# Event log column property
# Supplier1_Comparative_Mining  Supplier1_Comparative_Mining
#
#                                   case Purchasing Document  \
# Event log column property
# Supplier1_Comparative_Mining  Supplier1_Comparative_Mining
#
#                              case Purch. Doc. Category name  ...  \
# Event log column property                                    ...
# Supplier1_Comparative_Mining   Supplier1_Comparative_Mining  ...
#
#                              case Spend classification text  \
# Event log column property
# Supplier1_Comparative_Mining   Supplier1_Comparative_Mining
#
#                                                case Source  \
# Event log column property
# Supplier1_Comparative_Mining  Supplier1_Comparative_Mining
#
#                                                  case Name  \
# Event log column property
# Supplier1_Comparative_Mining  Supplier1_Comparative_Mining
#
#                                  case GR-Based Inv. Verif.  \
# Event log column property
# Supplier1_Comparative_Mining  Supplier1_Comparative_Mining
#
#                                                  case Item  \
# Event log column property
# Supplier1_Comparative_Mining  Supplier1_Comparative_Mining
#
#                                          case concept:name  \
# Event log column property
# Supplier1_Comparative_Mining  Supplier1_Comparative_Mining
#
#                                         case Goods Receipt  \
# Event log column property
# Supplier1_Comparative_Mining  Supplier1_Comparative_Mining
#
#                                                 event User  \
# Event log column property
# Supplier1_Comparative_Mining  Supplier1_Comparative_Mining
#
#                                         event org:resource  \
# Event log column property
# Supplier1_Comparative_Mining  Supplier1_Comparative_Mining
#
#                              event Cumulative net worth (EUR)
# Event log column property
# Supplier1_Comparative_Mining     Supplier1_Comparative_Mining
#
# [1 rows x 23 columns]

# %% [markdown]
# <h2>Multiple variables based on event data proprocessing which are used for the Meta-DataFrame</h2>
#
# The author uses the pandas .loc function which is an indexer in Pandas is used to choose rows and columns from a DataFrame based on labels.
#
# The snippet below is called title property X as it will be added to the overview table (Meta-DataFrame) with the log columns list's elements as keys and the log column itself as a value, if the title associated with the log column is present in the titles dictionary (if it does not exist in the titles dictionary).
#
# Then, a new row with the label "Title" and the values from the title property dictionary is added to the overview table DataFrame. The assignment will add the new row to the DataFrame, and the.loc indexer will be used to select the row by its label.
#
# When this code block is run, a new row with the label "Title" and values representing the names of each log column will appear in the overview table DataFrame (or the log column itself if no title is provided).

# %%
# Overview for property: Titles - For the Meta-DataFrame
# Depending on whether the title for the log column is present in the titles dictionary, the values of the log columns list are either the log column itself or its associated title (if it does not exist in the titles dictionary).
title_property = {}

for log_column in log_columns:
    if log_column in titles:
        title = titles[log_column]
    else:
        title = log_column
    title_property[log_column] = title

# %% [markdown]
# Then, a new row with the label "Title" and the values from the title property dictionary is added to the overview table DataFrame. The assignment will add the new row to the DataFrame, and the.loc indexer will be used to select the row by its label.
# When this code block is run, a new row with the label "Title" and values representing the names of each log column will appear in the overview table DataFrame (or the log column itself if no title is provided).

# %%
overview_table.loc['Title'] = title_property
overview_table.loc['Title']
# Out:
# caseID                                                       Case ID
# event time:timestamp                                       Timestamp
# event concept:name                                          Activity
# eventID                                                     Event ID
# case Spend area text                            case Spend area text
# case Company                                            case Company
# case Document Type                                case Document Type
# case Sub spend area text                    case Sub spend area text
# case Purchasing Document                    case Purchasing Document
# case Purch. Doc. Category name        case Purch. Doc. Category name
# case Vendor                                              case Vendor
# case Item Type                                        case Item Type
# case Item Category                                case Item Category
# case Spend classification text        case Spend classification text
# case Source                                              case Source
# case Name                                                  case Name
# case GR-Based Inv. Verif.                  case GR-Based Inv. Verif.
# case Item                                                  case Item
# case concept:name                                  case concept:name
# case Goods Receipt                                case Goods Receipt
# event User                                                event User
# event org:resource                                event org:resource
# event Cumulative net worth (EUR)    event Cumulative net worth (EUR)
# Name: Title, dtype: object

# %% [markdown]
# <h2>Dictionary {for mandatory and additional attributes}</h2>
#
# This code block generates a new dictionary called importance property whose keys are the items in the list of log columns and whose values are either "Mandatory attribute" or "Additional attribute" depending on whether the log column is included in the mandatory columns list or not.
# Then, a new row with the label "Importance" and values taken from the importance property dictionary is added to the overview table DataFrame. The assignment will add the new row to the DataFrame, and the.loc indexer will be used to select the row by its label.
# When this code block is run, a new row with the label "Importance" and the values "Mandatory attribute" or "Additional attribute" for each log column, depending on whether that column is in the mandatory columns list or not, will appear in the overview table DataFrame.
#
# The concept is used for other data attributes as well

# %%
# Overview property: Label for columns either 'Mandatory attribute' or 'additional_attributes' - For the Meta-DataFrame

importance_property = {}
for log_column in log_columns:
    if log_column in mandatory_columns:
        importance_property[log_column] = 'Mandatory attribute'
    else:
        importance_property[log_column] = 'Additional attribute'

overview_table.loc['Importance'] = importance_property
overview_table.loc['Importance']
# Out:
# caseID                               Mandatory attribute
# event time:timestamp                 Mandatory attribute
# event concept:name                   Mandatory attribute
# eventID                              Mandatory attribute
# case Spend area text                Additional attribute
# case Company                        Additional attribute
# case Document Type                  Additional attribute
# case Sub spend area text            Additional attribute
# case Purchasing Document            Additional attribute
# case Purch. Doc. Category name      Additional attribute
# case Vendor                         Additional attribute
# case Item Type                      Additional attribute
# case Item Category                  Additional attribute
# case Spend classification text      Additional attribute
# case Source                         Additional attribute
# case Name                           Additional attribute
# case GR-Based Inv. Verif.           Additional attribute
# case Item                           Additional attribute
# case concept:name                   Additional attribute
# case Goods Receipt                  Additional attribute
# event User                          Additional attribute
# event org:resource                  Additional attribute
# event Cumulative net worth (EUR)    Additional attribute
# Name: Importance, dtype: object

# %% [markdown]
# The goal of this code snippet is to add a new row to the Meta-Dataframe termed overview table, where the keys are the columns in a list called log columns and the values are strings indicating whether the column is at the "Event level" or the "Case level." The values are determined by examining the column name for the string "event" or "case," respectively.

# %%
# Overview property: The level of the event data attribute in the overview table
level_property = {}
for log_column in log_columns:
  if 'event' in log_column:
    level_property[log_column] = 'Event level'
  if 'case' in log_column:
    level_property[log_column] = 'Case level'

overview_table.loc['Level'] = level_property
overview_table.loc['Level']
# Out:
# caseID                               Case level
# event time:timestamp                Event level
# event concept:name                  Event level
# eventID                             Event level
# case Spend area text                 Case level
# case Company                         Case level
# case Document Type                   Case level
# case Sub spend area text             Case level
# case Purchasing Document             Case level
# case Purch. Doc. Category name       Case level
# case Vendor                          Case level
# case Item Type                       Case level
# case Item Category                   Case level
# case Spend classification text       Case level
# case Source                          Case level
# case Name                            Case level
# case GR-Based Inv. Verif.            Case level
# case Item                            Case level
# case concept:name                    Case level
# case Goods Receipt                   Case level
# event User                          Event level
# event org:resource                  Event level
# event Cumulative net worth (EUR)    Event level
# Name: Level, dtype: object

# %%
# Overview property: Data type
data_type_property = {}
datatypes = event_log_table.dtypes
for log_column in log_columns:
  data_type_property[log_column] = datatypes[log_column]

overview_table.loc['Data type'] = data_type_property

# %% [markdown]
# This snippet adds a new row to the Meta-Dataframe in Pandas, with the keys being the columns in a list called log columns and the values being the data types of the corresponding columns in an event log table DataFrame.

# %%
# Overview property: Data type
data_type_property = {}
datatypes = event_log_table.dtypes
for log_column in log_columns:
    data_type_property[log_column] = datatypes[log_column]

overview_table.loc['Data type'] = data_type_property
overview_table.loc['Data type']
# Out:
# caseID                                      string
# event time:timestamp                datetime64[ns]
# event concept:name                          string
# eventID                                    float64
# case Spend area text                        string
# case Company                                string
# case Document Type                          string
# case Sub spend area text                    string
# case Purchasing Document                     int64
# case Purch. Doc. Category name              string
# case Vendor                                 string
# case Item Type                              string
# case Item Category                          string
# case Spend classification text              string
# case Source                                 string
# case Name                                   string
# case GR-Based Inv. Verif.                     bool
# case Item                                    int64
# case concept:name                           string
# case Goods Receipt                            bool
# event User                                  string
# event org:resource                          string
# event Cumulative net worth (EUR)             int64
# Name: Data type, dtype: object

# %%
# Overview property: Count the number of entries for the Meta-Dataframe
number_of_entries_property = {}
for log_column in log_columns:
    number_of_entries_property[log_column] = len(event_log_table)

overview_table.loc['Number of entries'] = number_of_entries_property
overview_table.loc['Number of entries']
# Out:
# caseID                              349524
# event time:timestamp                349524
# event concept:name                  349524
# eventID                             349524
# case Spend area text                349524
# case Company                        349524
# case Document Type                  349524
# case Sub spend area text            349524
# case Purchasing Document            349524
# case Purch. Doc. Category name      349524
# case Vendor                         349524
# case Item Type                      349524
# case Item Category                  349524
# case Spend classification text      349524
# case Source                         349524
# case Name                           349524
# case GR-Based Inv. Verif.           349524
# case Item                           349524
# case concept:name                   349524
# case Goods Receipt                  349524
# event User                          349524
# event org:resource                  349524
# event Cumulative net worth (EUR)    349524
# Name: Number of entries, dtype: object

# %%
# Overview property: Number of unique entries
number_of_unique_entries_property = {}
for log_column in log_columns:
  count = event_log_table[log_column].value_counts().count()
  number_of_unique_entries_property[log_column] = count

overview_table.loc['Number of unique entries'] = number_of_unique_entries_property
overview_table.loc['Number of unique entries']
# Out:
# caseID                              53103
# event time:timestamp                49269
# event concept:name                     38
# eventID                              2945
# case Spend area text                   19
# case Company                            1
# case Document Type                      3
# case Sub spend area text              122
# case Purchasing Document            16351
# case Purch. Doc. Category name          1
# case Vendor                          1360
# case Item Type                          5
# case Item Category                      3
# case Spend classification text          3
# case Source                             1
# case Name                            1300
# case GR-Based Inv. Verif.               2
# case Item                             273
# case concept:name                   53103
# case Goods Receipt                      1
# event User                            366
# event org:resource                    366
# event Cumulative net worth (EUR)    10653
# Name: Number of unique entries, dtype: object

# %%
#Overview property: List of up to 100 unique entries (to grasp an understanding of how the data looks and it is structured and not just metrics)
unique_entries_property = {}
for log_column in log_columns:
    unique_entries = event_log_table[log_column].unique()
    unique_entries = list(unique_entries)
    unique_entries = unique_entries[:100]
    unique_entries_property[log_column] = unique_entries

overview_table.loc['List up to 100 unique entries to view the structure of the event attributes']= unique_entries_property
unique_entries_property
# Out:
# {'caseID': ['2000000000 1',
#   '2000000001 1',
#   '2000000002 1',
#   '2000000003 1',
#   '2000000003 2',
#   '2000000003 3',
#   '2000000004 1',
#   '2000000005 1',
#   '2000000005 2',
#   '2000000006 1',
#   '2000000007 1',
#   '2000000008 1',
#   '2000000009 1',
#   '2000000010 1',
#   '2000000011 1',
#   '2000000012 1',
#   '2000000013 1',
#   '2000000014 1',
#   '2000000015 1',
#   '2000000016 1',
#   '2000000017 1',
#   '2000000018 1',
#   '2000000019 1',
#   '2000000020 1',
#   '2000000021 1',
#   '2000000022 1',
#   '2000000023 1',
#   '2000000024 1',
#   '2000000025 1',
#   '2000000026 1',
#   '2000000026 2',
#   '2000000027 1',
#   '2000000028 1',
#   '2000000029 1',
#   '2000000029 2',
#   '2000000029 3',
#   '2000000030 1',
#   '2000000031 1',
#   '2000000032 1',
#   '2000000033 1',
#   '2000000034 1',
#   '2000000035 1',
#   '2000000036 1',
#   '2000000037 1',
#   '2000000037 2',
#   '2000000037 3',
#   '2000000038 1',
#   '2000000039 1',
#   '2000000039 2',
#   '2000000040 1',
#   '2000000041 1',
#   '2000000042 1',
#   '2000000043 1',
#   '2000000044 1',
#   '2000000045 1',
#   '2000000045 2',
#   '2000000046 1',
#   '2000000047 1',
#   '2000000048 1',
#   '2000000049 1',
#   '2000000050 1',
#   '2000000051 1',
#   '2000000052 1',
#   '2000000053 1',
#   '2000000054 1',
#   '2000000054 2',
#   '2000000054 3',
#   '2000000054 4',
#   '2000000055 1',
#   '2000000056 1',
#   '2000000057 1',
#   '2000000058 1',
#   '2000000059 1',
#   '2000000060 1',
#   '2000000061 1',
#   '2000000062 1',
#   '2000000063 1',
#   '2000000064 1',
#   '2000000065 1',
#   '2000000066 1',
#   '2000000067 1',
#   '2000000068 1',
#   '2000000069 1',
#   '2000000070 1',
#   '2000000071 1',
#   '2000000072 1',
#   '2000000073 1',
#   '2000000074 1',
#   '2000000075 1',
#   '2000000076 1',
#   '2000000076 2',
#   '2000000076 3',
#   '2000000077 1',
#   '2000000077 2',
#   '2000000078 1',
#   '2000000079 1',
#   '2000000079 2',
#   '2000000079 3',
#   '2000000080 1',
#   '2000000080 2'],
#  'event time:timestamp': [numpy.datetime64('2018-02-01T13:53:00.000000000'),
#   numpy.datetime64('2018-02-01T14:53:00.000000000'),
#   numpy.datetime64('2018-02-01T23:59:00.000000000'),
#   numpy.datetime64('2018-06-03T07:44:00.000000000'),
#   numpy.datetime64('2018-06-03T08:53:00.000000000'),
#   numpy.datetime64('2018-03-29T15:06:00.000000000'),
#   numpy.datetime64('2018-03-01T09:49:00.000000000'),
#   numpy.datetime64('2018-03-01T10:49:00.000000000'),
#   numpy.datetime64('2018-10-01T23:59:00.000000000'),
#   numpy.datetime64('2018-01-16T13:09:00.000000000'),
#   numpy.datetime64('2018-01-16T15:44:00.000000000'),
#   numpy.datetime64('2018-08-03T13:21:00.000000000'),
#   numpy.datetime64('2018-04-01T14:17:00.000000000'),
#   numpy.datetime64('2018-04-01T15:17:00.000000000'),
#   numpy.datetime64('2018-06-02T15:53:00.000000000'),
#   numpy.datetime64('2018-06-02T23:59:00.000000000'),
#   numpy.datetime64('2018-08-02T11:19:00.000000000'),
#   numpy.datetime64('2018-08-16T12:20:00.000000000'),
#   numpy.datetime64('2018-08-16T12:41:00.000000000'),
#   numpy.datetime64('2018-08-16T15:03:00.000000000'),
#   numpy.datetime64('2018-08-01T07:21:00.000000000'),
#   numpy.datetime64('2018-08-01T08:21:00.000000000'),
#   numpy.datetime64('2018-08-01T23:59:00.000000000'),
#   numpy.datetime64('2018-12-01T14:14:00.000000000'),
#   numpy.datetime64('2018-12-02T16:58:00.000000000'),
#   numpy.datetime64('2018-12-01T14:13:00.000000000'),
#   numpy.datetime64('2018-05-03T16:30:00.000000000'),
#   numpy.datetime64('2018-08-01T10:08:00.000000000'),
#   numpy.datetime64('2018-08-01T11:08:00.000000000'),
#   numpy.datetime64('2018-08-01T11:09:00.000000000'),
#   numpy.datetime64('2018-01-19T09:09:00.000000000'),
#   numpy.datetime64('2018-03-04T06:26:00.000000000'),
#   numpy.datetime64('2018-05-04T15:51:00.000000000'),
#   numpy.datetime64('2018-02-08T09:15:00.000000000'),
#   numpy.datetime64('2018-02-08T09:17:00.000000000'),
#   numpy.datetime64('2018-02-08T09:19:00.000000000'),
#   numpy.datetime64('2018-08-01T11:33:00.000000000'),
#   numpy.datetime64('2018-08-01T12:33:00.000000000'),
#   numpy.datetime64('2018-09-01T10:04:00.000000000'),
#   numpy.datetime64('2018-09-01T12:59:00.000000000'),
#   numpy.datetime64('2018-02-23T12:14:00.000000000'),
#   numpy.datetime64('2018-08-01T13:12:00.000000000'),
#   numpy.datetime64('2018-08-01T14:12:00.000000000'),
#   numpy.datetime64('2018-01-17T09:11:00.000000000'),
#   numpy.datetime64('2018-02-21T13:53:00.000000000'),
#   numpy.datetime64('2018-02-21T13:55:00.000000000'),
#   numpy.datetime64('2018-08-03T13:22:00.000000000'),
#   numpy.datetime64('2018-08-01T15:36:00.000000000'),
#   numpy.datetime64('2018-08-01T16:36:00.000000000'),
#   numpy.datetime64('2018-01-15T12:53:00.000000000'),
#   numpy.datetime64('2018-01-17T15:49:00.000000000'),
#   numpy.datetime64('2018-02-22T16:18:00.000000000'),
#   numpy.datetime64('2018-09-01T13:14:00.000000000'),
#   numpy.datetime64('2018-09-01T14:14:00.000000000'),
#   numpy.datetime64('2018-08-03T08:27:00.000000000'),
#   numpy.datetime64('2018-09-03T16:47:00.000000000'),
#   numpy.datetime64('2018-03-15T14:13:00.000000000'),
#   numpy.datetime64('2018-09-01T15:30:00.000000000'),
#   numpy.datetime64('2018-09-01T16:30:00.000000000'),
#   numpy.datetime64('2018-09-01T23:59:00.000000000'),
#   numpy.datetime64('2018-10-01T16:11:00.000000000'),
#   numpy.datetime64('2018-01-16T10:49:00.000000000'),
#   numpy.datetime64('2018-03-29T15:11:00.000000000'),
#   numpy.datetime64('2018-05-09T11:43:00.000000000'),
#   numpy.datetime64('2018-05-09T13:44:00.000000000'),
#   numpy.datetime64('2018-05-09T16:34:00.000000000'),
#   numpy.datetime64('2018-09-01T16:54:00.000000000'),
#   numpy.datetime64('2018-09-01T17:54:00.000000000'),
#   numpy.datetime64('2018-11-01T11:10:00.000000000'),
#   numpy.datetime64('2018-11-04T16:45:00.000000000'),
#   numpy.datetime64('2018-12-04T14:08:00.000000000'),
#   numpy.datetime64('2018-10-01T15:38:00.000000000'),
#   numpy.datetime64('2018-10-01T16:38:00.000000000'),
#   numpy.datetime64('2018-01-29T23:59:00.000000000'),
#   numpy.datetime64('2018-02-26T09:41:00.000000000'),
#   numpy.datetime64('2018-05-03T16:12:00.000000000'),
#   numpy.datetime64('2018-10-01T16:40:00.000000000'),
#   numpy.datetime64('2018-01-16T14:27:00.000000000'),
#   numpy.datetime64('2018-01-22T23:59:00.000000000'),
#   numpy.datetime64('2018-01-24T17:15:00.000000000'),
#   numpy.datetime64('2018-02-15T14:51:00.000000000'),
#   numpy.datetime64('2018-11-01T15:41:00.000000000'),
#   numpy.datetime64('2018-11-01T16:41:00.000000000'),
#   numpy.datetime64('2018-02-16T16:47:00.000000000'),
#   numpy.datetime64('2018-02-19T14:20:00.000000000'),
#   numpy.datetime64('2018-01-03T14:06:00.000000000'),
#   numpy.datetime64('2018-03-29T23:59:00.000000000'),
#   numpy.datetime64('2018-10-04T16:08:00.000000000'),
#   numpy.datetime64('2018-10-04T16:22:00.000000000'),
#   numpy.datetime64('2018-04-19T14:47:00.000000000'),
#   numpy.datetime64('2018-06-25T23:59:00.000000000'),
#   numpy.datetime64('2018-07-24T12:29:00.000000000'),
#   numpy.datetime64('2018-07-25T15:00:00.000000000'),
#   numpy.datetime64('2018-07-26T18:09:00.000000000'),
#   numpy.datetime64('2018-12-01T09:51:00.000000000'),
#   numpy.datetime64('2018-12-01T10:51:00.000000000'),
#   numpy.datetime64('2018-01-25T01:16:00.000000000'),
#   numpy.datetime64('2018-01-30T23:59:00.000000000'),
#   numpy.datetime64('2018-01-31T23:59:00.000000000'),
#   numpy.datetime64('2018-05-02T11:46:00.000000000')],
#  'event concept:name': ['SRM: Created',
#   'SRM: Change was Transmitted',
#   'SRM: Document Completed',
#   'SRM: Awaiting Approval',
#   'SRM: Complete',
#   'SRM: In Transfer to Execution Syst.',
#   'SRM: Ordered',
#   'Create Purchase Order Item',
#   'Vendor creates invoice',
#   'Record Goods Receipt',
#   'Record Invoice Receipt',
#   'Clear Invoice',
#   'Record Service Entry Sheet',
#   'Cancel Goods Receipt',
#   'Vendor creates debit memo',
#   'Cancel Invoice Receipt',
#   'Remove Payment Block',
#   'SRM: Deleted',
#   'Change Price',
#   'Delete Purchase Order Item',
#   'SRM: Transaction Completed',
#   'Change Quantity',
#   'Change Delivery Indicator',
#   'Change Final Invoice Indicator',
#   'SRM: Incomplete',
#   'SRM: Held',
#   'Cancel Subsequent Invoice',
#   'Record Subsequent Invoice',
#   'Receive Order Confirmation',
#   'Reactivate Purchase Order Item',
#   'Update Order Confirmation',
#   'Block Purchase Order Item',
#   'Change Approval for Purchase Order',
#   'Release Purchase Order',
#   'Set Payment Block',
#   'Create Purchase Requisition Item',
#   'Change Storage Location',
#   'Change Currency'],
#  'eventID ': [0.0,
#   6.0,
#   3.0,
#   2.0,
#   1.0,
#   4.0,
#   5.0,
#   7.0,
#   8.0,
#   9.0,
#   10.0,
#   11.0,
#   4294967296.0,
#   4294967299.0,
#   4294967298.0,
#   4294967300.0,
#   4294967301.0,
#   4294967302.0,
#   4294967303.0,
#   4294967297.0,
#   4294967304.0,
#   4294967305.0,
#   4294967306.0,
#   4294967307.0,
#   4294967308.0,
#   8589934592.0,
#   8589934593.0,
#   8589934595.0,
#   8589934597.0,
#   8589934596.0,
#   8589934594.0,
#   8589934599.0,
#   8589934598.0,
#   8589934600.0,
#   8589934601.0,
#   8589934602.0,
#   8589934603.0,
#   8589934604.0,
#   8589934605.0,
#   8589934606.0,
#   8589934607.0,
#   12884901888.0,
#   12884901894.0,
#   12884901892.0,
#   12884901895.0,
#   12884901891.0,
#   12884901889.0,
#   12884901890.0,
#   12884901893.0,
#   12884901896.0,
#   12884901897.0,
#   12884901898.0,
#   12884901899.0,
#   17179869184.0,
#   17179869190.0,
#   17179869189.0,
#   17179869188.0,
#   17179869185.0,
#   17179869187.0,
#   17179869186.0,
#   17179869191.0,
#   17179869192.0,
#   17179869193.0,
#   17179869194.0,
#   17179869195.0,
#   21474836480.0,
#   21474836482.0,
#   21474836483.0,
#   21474836487.0,
#   21474836486.0,
#   21474836485.0,
#   21474836484.0,
#   21474836481.0,
#   21474836488.0,
#   21474836489.0,
#   21474836490.0,
#   21474836491.0,
#   25769803776.0,
#   25769803780.0,
#   25769803781.0,
#   25769803779.0,
#   25769803782.0,
#   25769803783.0,
#   25769803778.0,
#   25769803777.0,
#   25769803784.0,
#   25769803785.0,
#   25769803786.0,
#   25769803787.0,
#   30064771072.0,
#   30064771075.0,
#   30064771074.0,
#   30064771073.0,
#   30064771076.0,
#   30064771078.0,
#   30064771079.0,
#   30064771077.0,
#   30064771081.0,
#   30064771080.0,
#   30064771082.0],
#  'case Spend area text': ['CAPEX & SOCS',
#   'Marketing',
#   'Enterprise Services',
#   'Workforce Services',
#   'Others',
#   'Logistics',
#   <NA>,
#   'Sales',
#   'Real Estate',
#   'Trading & End Products',
#   'Packaging',
#   'Additives',
#   'Specialty Resins',
#   'Solvents',
#   'Pigments & Colorants',
#   'Titanium Dioxides',
#   'Latex & Monomers',
#   'Commodity Resins',
#   'Spend Area Unidentified',
#   'Chemicals & Intermediates'],
#  'case Company': ['companyID_0000'],
#  'case Document Type': ['EC Purchase order', 'Standard PO', 'Framework order'],
#  'case Sub spend area text': ['Facility Management',
#   'Marketing Support Services',
#   'Digital Marketing',
#   'Office Supplies',
#   'HR Services',
#   'Advertising',
#   'ICT Software',
#   'Laboratory Supplies & Services',
#   'MRO (components)',
#   'Third Party Labor',
#   'Design',
#   'Consulting',
#   'Raw Material',
#   'Communications',
#   'Other Logistics Services',
#   'Equipment',
#   'Road Packed',
#   'Express',
#   <NA>,
#   'Travel & expenses',
#   'Technical Services',
#   'Market Research',
#   'ICT Services',
#   'Products for Resale',
#   'Color Collateral',
#   'Real estate brokers or agents',
#   'Process Automation & Instrumentation',
#   'QHSE Services',
#   'Media',
#   'Sales Promotion',
#   'Packaging',
#   'Spectrophotometers',
#   'Trading products (old structure)',
#   'Information Services',
#   'Public Relations',
#   'Business Gifts & Promotional Items',
#   'SOC&S - Other',
#   'Labels',
#   'Plastic Containers & Lids < 30L',
#   'Metal Containers & Lids < 30L',
#   'Extenders',
#   'Alkyd Resins',
#   'Glycol & Ether Solvents',
#   'Defoamers & Antifoams',
#   'Surfactants',
#   'Driers & Antiskinning Agents',
#   'Mixing Machines',
#   'Plastic Film',
#   'Biocides',
#   'Waxes',
#   'Colorants',
#   'Chloride',
#   'Ester Solvents',
#   'Customers',
#   'Opaque Polymers',
#   'Closures',
#   'Light & Heat Stabilizers',
#   'Rheology & Thixotropic Agents',
#   'Plasticizers',
#   'Bags',
#   'Pure Acrylics',
#   'Styrene Acrylics',
#   'Carbon Black Pigments',
#   'Aliphatic Solvents',
#   'Neutralisation Agents',
#   'Vinyl Acetate Ethylenes',
#   'Vinyl Acrylics',
#   'Sea',
#   'Drums',
#   'Aromatic Solvents',
#   'Specialty Resins - Other',
#   'Inorganic Pigments',
#   'Organic Pigments',
#   'Pallets',
#   'Alcohol Solvents',
#   'Polyester Resins - Liquid',
#   'Monomers - Styrene',
#   'Fire Protection Agents',
#   'Warehousing',
#   'Packaging - Other',
#   'Jerry Cans',
#   'Isocyanates',
#   'Commodity Resins Precursors',
#   'Catalysts & Initiators',
#   'Additives - Other',
#   'Corrosion Inhibitors',
#   'Specialty Resins Precursors',
#   'Sulphate',
#   'Acrylic Resins  Liquid',
#   'Ketones Solvents',
#   'Epoxy Resins - Liquid',
#   'Tubes',
#   'Paperboard',
#   'Latexes - Other',
#   'UV Resins',
#   'Intermediate Bulk Containers (IBC)',
#   'Polyurethane Resins',
#   'Polyamides & Polyamines',
#   'Effect Pigments',
#   'Polyvinyl Acetates'],
#  'case Purchasing Document': [2000000000,
#   2000000001,
#   2000000002,
#   2000000003,
#   2000000004,
#   2000000005,
#   2000000006,
#   2000000007,
#   2000000008,
#   2000000009,
#   2000000010,
#   2000000011,
#   2000000012,
#   2000000013,
#   2000000014,
#   2000000015,
#   2000000016,
#   2000000017,
#   2000000018,
#   2000000019,
#   2000000020,
#   2000000021,
#   2000000022,
#   2000000023,
#   2000000024,
#   2000000025,
#   2000000026,
#   2000000027,
#   2000000028,
#   2000000029,
#   2000000030,
#   2000000031,
#   2000000032,
#   2000000033,
#   2000000034,
#   2000000035,
#   2000000036,
#   2000000037,
#   2000000038,
#   2000000039,
#   2000000040,
#   2000000041,
#   2000000042,
#   2000000043,
#   2000000044,
#   2000000045,
#   2000000046,
#   2000000047,
#   2000000048,
#   2000000049,
#   2000000050,
#   2000000051,
#   2000000052,
#   2000000053,
#   2000000054,
#   2000000055,
#   2000000056,
#   2000000057,
#   2000000058,
#   2000000059,
#   2000000060,
#   2000000061,
#   2000000062,
#   2000000063,
#   2000000064,
#   2000000065,
#   2000000066,
#   2000000067,
#   2000000068,
#   2000000069,
#   2000000070,
#   2000000071,
#   2000000072,
#   2000000073,
#   2000000074,
#   2000000075,
#   2000000076,
#   2000000077,
#   2000000078,
#   2000000079,
#   2000000080,
#   2000000081,
#   2000000082,
#   2000000083,
#   2000000084,
#   2000000085,
#   2000000086,
#   2000000087,
#   2000000088,
#   2000000089,
#   2000000090,
#   2000000091,
#   2000000092,
#   2000000093,
#   2000000094,
#   2000000095,
#   2000000096,
#   2000000097,
#   2000000098,
#   2000000099],
#  'case Purch. Doc. Category name': ['Purchase order'],
#  'case Vendor': ['vendorID_0000',
#   'vendorID_0001',
#   'vendorID_0002',
#   'vendorID_0003',
#   'vendorID_0004',
#   'vendorID_0005',
#   'vendorID_0006',
#   'vendorID_0007',
#   'vendorID_0008',
#   'vendorID_0009',
#   'vendorID_0010',
#   'vendorID_0011',
#   'vendorID_0012',
#   'vendorID_0013',
#   'vendorID_0014',
#   'vendorID_0015',
#   'vendorID_0016',
#   'vendorID_0017',
#   'vendorID_0018',
#   'vendorID_0019',
#   'vendorID_0020',
#   'vendorID_0021',
#   'vendorID_0022',
#   'vendorID_0023',
#   'vendorID_0024',
#   'vendorID_0025',
#   'vendorID_0026',
#   'vendorID_0027',
#   'vendorID_0028',
#   'vendorID_0029',
#   'vendorID_0030',
#   'vendorID_0031',
#   'vendorID_0032',
#   'vendorID_0033',
#   'vendorID_0034',
#   'vendorID_0035',
#   'vendorID_0036',
#   'vendorID_0037',
#   'vendorID_0038',
#   'vendorID_0039',
#   'vendorID_0040',
#   'vendorID_0041',
#   'vendorID_0042',
#   'vendorID_0043',
#   'vendorID_0044',
#   'vendorID_0045',
#   'vendorID_0046',
#   'vendorID_0047',
#   'vendorID_0048',
#   'vendorID_0049',
#   'vendorID_0050',
#   'vendorID_0051',
#   'vendorID_0052',
#   'vendorID_0053',
#   'vendorID_0054',
#   'vendorID_0055',
#   'vendorID_0056',
#   'vendorID_0057',
#   'vendorID_0058',
#   'vendorID_0059',
#   'vendorID_0060',
#   'vendorID_0061',
#   'vendorID_0062',
#   'vendorID_0063',
#   'vendorID_0064',
#   'vendorID_0065',
#   'vendorID_0066',
#   'vendorID_0067',
#   'vendorID_0068',
#   'vendorID_0069',
#   'vendorID_0070',
#   'vendorID_0071',
#   'vendorID_0072',
#   'vendorID_0073',
#   'vendorID_0074',
#   'vendorID_0075',
#   'vendorID_0076',
#   'vendorID_0077',
#   'vendorID_0078',
#   'vendorID_0079',
#   'vendorID_0080',
#   'vendorID_0081',
#   'vendorID_0082',
#   'vendorID_0083',
#   'vendorID_0084',
#   'vendorID_0085',
#   'vendorID_0086',
#   'vendorID_0087',
#   'vendorID_0088',
#   'vendorID_0089',
#   'vendorID_0090',
#   'vendorID_0091',
#   'vendorID_0092',
#   'vendorID_0093',
#   'vendorID_0094',
#   'vendorID_0095',
#   'vendorID_0096',
#   'vendorID_0097',
#   'vendorID_0098',
#   'vendorID_0099'],
#  'case Item Type': ['Standard',
#   'Service',
#   'Consignment',
#   'Subcontracting',
#   'Third-party'],
#  'case Item Category': ['3-way match, invoice before GR',
#   '3-way match, invoice after GR',
#   'Consignment'],
#  'case Spend classification text': ['NPR', 'OTHER', <NA>, 'PR'],
#  'case Source': ['sourceSystemID_0000'],
#  'case Name': ['vendor_0000',
#   'vendor_0001',
#   'vendor_0002',
#   'vendor_0003',
#   'vendor_0004',
#   'vendor_0005',
#   'vendor_0006',
#   'vendor_0007',
#   'vendor_0008',
#   'vendor_0009',
#   'vendor_0010',
#   'vendor_0011',
#   'vendor_0012',
#   'vendor_0013',
#   'vendor_0014',
#   'vendor_0015',
#   'vendor_0016',
#   'vendor_0017',
#   'vendor_0018',
#   'vendor_0019',
#   'vendor_0020',
#   'vendor_0021',
#   'vendor_0022',
#   'vendor_0023',
#   'vendor_0024',
#   'vendor_0025',
#   'vendor_0026',
#   'vendor_0027',
#   'vendor_0028',
#   'vendor_0029',
#   'vendor_0030',
#   'vendor_0031',
#   'vendor_0032',
#   'vendor_0033',
#   'vendor_0034',
#   'vendor_0035',
#   'vendor_0036',
#   'vendor_0037',
#   'vendor_0038',
#   'vendor_0039',
#   'vendor_0040',
#   'vendor_0041',
#   'vendor_0042',
#   'vendor_0043',
#   'vendor_0044',
#   'vendor_0045',
#   'vendor_0046',
#   'vendor_0047',
#   'vendor_0048',
#   'vendor_0049',
#   'vendor_0050',
#   'vendor_0051',
#   'vendor_0052',
#   'vendor_0053',
#   'vendor_0054',
#   'vendor_0055',
#   'vendor_0056',
#   'vendor_0057',
#   'vendor_0058',
#   'vendor_0059',
#   'vendor_0060',
#   'vendor_0061',
#   'vendor_0062',
#   'vendor_0063',
#   'vendor_0064',
#   'vendor_0065',
#   'vendor_0066',
#   'vendor_0067',
#   'vendor_0068',
#   'vendor_0069',
#   'vendor_0070',
#   'vendor_0071',
#   'vendor_0072',
#   'vendor_0073',
#   'vendor_0074',
#   'vendor_0075',
#   'vendor_0076',
#   'vendor_0077',
#   'vendor_0078',
#   'vendor_0079',
#   'vendor_0080',
#   'vendor_0081',
#   'vendor_0082',
#   'vendor_0083',
#   'vendor_0084',
#   'vendor_0085',
#   'vendor_0086',
#   'vendor_0087',
#   'vendor_0088',
#   'vendor_0089',
#   'vendor_0090',
#   'vendor_0091',
#   'vendor_0092',
#   'vendor_0093',
#   'vendor_0094',
#   'vendor_0095',
#   'vendor_0096',
#   'vendor_0097',
#   'vendor_0098',
#   'vendor_0099'],
#  'case GR-Based Inv. Verif.': [False, True],
#  'case Item': [1,
#   2,
#   3,
#   4,
#   5,
#   6,
#   10,
#   11,
#   7,
#   8,
#   9,
#   20,
#   30,
#   40,
#   100,
#   50,
#   60,
#   70,
#   80,
#   90,
#   110,
#   120,
#   130,
#   140,
#   150,
#   160,
#   170,
#   180,
#   190,
#   200,
#   210,
#   220,
#   230,
#   240,
#   250,
#   260,
#   270,
#   280,
#   290,
#   300,
#   310,
#   320,
#   330,
#   340,
#   350,
#   360,
#   370,
#   380,
#   390,
#   400,
#   410,
#   420,
#   430,
#   440,
#   450,
#   460,
#   470,
#   480,
#   490,
#   500,
#   510,
#   520,
#   530,
#   540,
#   550,
#   560,
#   570,
#   580,
#   590,
#   600,
#   610,
#   620,
#   630,
#   640,
#   650,
#   660,
#   670,
#   680,
#   690,
#   700,
#   710,
#   720,
#   730,
#   740,
#   750,
#   760,
#   770,
#   780,
#   790,
#   800,
#   810,
#   820,
#   830,
#   840,
#   850,
#   860,
#   870,
#   880,
#   890,
#   900],
#  'case concept:name': ['2000000000_00001',
#   '2000000001_00001',
#   '2000000002_00001',
#   '2000000003_00001',
#   '2000000003_00002',
#   '2000000003_00003',
#   '2000000004_00001',
#   '2000000005_00001',
#   '2000000005_00002',
#   '2000000006_00001',
#   '2000000007_00001',
#   '2000000008_00001',
#   '2000000009_00001',
#   '2000000010_00001',
#   '2000000011_00001',
#   '2000000012_00001',
#   '2000000013_00001',
#   '2000000014_00001',
#   '2000000015_00001',
#   '2000000016_00001',
#   '2000000017_00001',
#   '2000000018_00001',
#   '2000000019_00001',
#   '2000000020_00001',
#   '2000000021_00001',
#   '2000000022_00001',
#   '2000000023_00001',
#   '2000000024_00001',
#   '2000000025_00001',
#   '2000000026_00001',
#   '2000000026_00002',
#   '2000000027_00001',
#   '2000000028_00001',
#   '2000000029_00001',
#   '2000000029_00002',
#   '2000000029_00003',
#   '2000000030_00001',
#   '2000000031_00001',
#   '2000000032_00001',
#   '2000000033_00001',
#   '2000000034_00001',
#   '2000000035_00001',
#   '2000000036_00001',
#   '2000000037_00001',
#   '2000000037_00002',
#   '2000000037_00003',
#   '2000000038_00001',
#   '2000000039_00001',
#   '2000000039_00002',
#   '2000000040_00001',
#   '2000000041_00001',
#   '2000000042_00001',
#   '2000000043_00001',
#   '2000000044_00001',
#   '2000000045_00001',
#   '2000000045_00002',
#   '2000000046_00001',
#   '2000000047_00001',
#   '2000000048_00001',
#   '2000000049_00001',
#   '2000000050_00001',
#   '2000000051_00001',
#   '2000000052_00001',
#   '2000000053_00001',
#   '2000000054_00001',
#   '2000000054_00002',
#   '2000000054_00003',
#   '2000000054_00004',
#   '2000000055_00001',
#   '2000000056_00001',
#   '2000000057_00001',
#   '2000000058_00001',
#   '2000000059_00001',
#   '2000000060_00001',
#   '2000000061_00001',
#   '2000000062_00001',
#   '2000000063_00001',
#   '2000000064_00001',
#   '2000000065_00001',
#   '2000000066_00001',
#   '2000000067_00001',
#   '2000000068_00001',
#   '2000000069_00001',
#   '2000000070_00001',
#   '2000000071_00001',
#   '2000000072_00001',
#   '2000000073_00001',
#   '2000000074_00001',
#   '2000000075_00001',
#   '2000000076_00001',
#   '2000000076_00002',
#   '2000000076_00003',
#   '2000000077_00001',
#   '2000000077_00002',
#   '2000000078_00001',
#   '2000000079_00001',
#   '2000000079_00002',
#   '2000000079_00003',
#   '2000000080_00001',
#   '2000000080_00002'],
#  'case Goods Receipt': [True],
#  'event User': ['batch_00',
#   'user_000',
#   'NONE',
#   'user_001',
#   'user_002',
#   'user_004',
#   'user_005',
#   'user_006',
#   'user_007',
#   'user_008',
#   'user_011',
#   'user_009',
#   'user_012',
#   'user_013',
#   'user_014',
#   'user_015',
#   'user_018',
#   'user_016',
#   'user_019',
#   'user_010',
#   'batch_01',
#   'user_022',
#   'user_023',
#   'user_020',
#   'user_024',
#   'user_025',
#   'user_026',
#   'batch_02',
#   'user_028',
#   'user_112',
#   'user_339',
#   'user_083',
#   'user_340',
#   'user_341',
#   'user_196',
#   'batch_03',
#   'user_029',
#   'user_030',
#   'batch_04',
#   'user_031',
#   'user_032',
#   'user_033',
#   'user_034',
#   'user_035',
#   'user_036',
#   'user_037',
#   'user_038',
#   'user_039',
#   'user_040',
#   'user_041',
#   'user_042',
#   'user_043',
#   'user_044',
#   'user_045',
#   'user_046',
#   'user_049',
#   'user_047',
#   'user_048',
#   'user_050',
#   'user_051',
#   'batch_05',
#   'user_052',
#   'user_053',
#   'user_054',
#   'user_055',
#   'user_056',
#   'user_057',
#   'user_058',
#   'user_059',
#   'user_060',
#   'user_061',
#   'user_062',
#   'user_063',
#   'user_064',
#   'user_065',
#   'user_066',
#   'user_067',
#   'user_068',
#   'user_069',
#   'user_070',
#   'user_071',
#   'user_072',
#   'batch_06',
#   'user_074',
#   'user_075',
#   'user_076',
#   'user_077',
#   'user_078',
#   'user_079',
#   'user_080',
#   'user_081',
#   'user_082',
#   'user_084',
#   'user_085',
#   'user_086',
#   'user_087',
#   'user_088',
#   'user_089',
#   'user_090',
#   'user_091'],
#  'event org:resource': ['batch_00',
#   'user_000',
#   'NONE',
#   'user_001',
#   'user_002',
#   'user_004',
#   'user_005',
#   'user_006',
#   'user_007',
#   'user_008',
#   'user_011',
#   'user_009',
#   'user_012',
#   'user_013',
#   'user_014',
#   'user_015',
#   'user_018',
#   'user_016',
#   'user_019',
#   'user_010',
#   'batch_01',
#   'user_022',
#   'user_023',
#   'user_020',
#   'user_024',
#   'user_025',
#   'user_026',
#   'batch_02',
#   'user_028',
#   'user_112',
#   'user_339',
#   'user_083',
#   'user_340',
#   'user_341',
#   'user_196',
#   'batch_03',
#   'user_029',
#   'user_030',
#   'batch_04',
#   'user_031',
#   'user_032',
#   'user_033',
#   'user_034',
#   'user_035',
#   'user_036',
#   'user_037',
#   'user_038',
#   'user_039',
#   'user_040',
#   'user_041',
#   'user_042',
#   'user_043',
#   'user_044',
#   'user_045',
#   'user_046',
#   'user_049',
#   'user_047',
#   'user_048',
#   'user_050',
#   'user_051',
#   'batch_05',
#   'user_052',
#   'user_053',
#   'user_054',
#   'user_055',
#   'user_056',
#   'user_057',
#   'user_058',
#   'user_059',
#   'user_060',
#   'user_061',
#   'user_062',
#   'user_063',
#   'user_064',
#   'user_065',
#   'user_066',
#   'user_067',
#   'user_068',
#   'user_069',
#   'user_070',
#   'user_071',
#   'user_072',
#   'batch_06',
#   'user_074',
#   'user_075',
#   'user_076',
#   'user_077',
#   'user_078',
#   'user_079',
#   'user_080',
#   'user_081',
#   'user_082',
#   'user_084',
#   'user_085',
#   'user_086',
#   'user_087',
#   'user_088',
#   'user_089',
#   'user_090',
#   'user_091'],
#  'event Cumulative net worth (EUR)': [298,
#   557,
#   76210,
#   28,
#   37,
#   44,
#   166,
#   433,
#   86,
#   37819,
#   3227,
#   18186,
#   1039,
#   1668264,
#   112583,
#   320,
#   857,
#   17414,
#   457836,
#   405009,
#   372390,
#   950029,
#   502814,
#   155884,
#   277128,
#   4312806,
#   22251,
#   58196,
#   1368,
#   74,
#   45,
#   6754,
#   83,
#   19,
#   5,
#   549,
#   1098,
#   22,
#   106,
#   12852,
#   3065,
#   6903,
#   938,
#   34,
#   63,
#   57,
#   428,
#   127,
#   3464,
#   260,
#   64,
#   181,
#   646,
#   49,
#   173,
#   649519,
#   828,
#   412,
#   2726,
#   33,
#   2165,
#   43,
#   179,
#   23,
#   526,
#   459,
#   433012,
#   41569,
#   339481,
#   190525,
#   356802,
#   304840,
#   207846,
#   138564,
#   259807,
#   294448,
#   381051,
#   495366,
#   242487,
#   346410,
#   132,
#   147,
#   51,
#   159,
#   21,
#   5897,
#   141,
#   113,
#   121,
#   362,
#   77,
#   60,
#   710,
#   124,
#   98,
#   88,
#   65,
#   418,
#   41,
#   40]}

# %%
# Overview property: Length of the list of up to 100 unique entries
num_displayed_unique_entries_property = {}
for log_column in log_columns:
  unique_entries = event_log_table[log_column].unique()
  unique_entries = list(unique_entries)
  unique_entries = unique_entries[:100]
  num_displayed_unique_entries_property[log_column] = len(unique_entries)

overview_table.loc['Length of the list of up to 100 unique entries'] = num_displayed_unique_entries_property
num_displayed_unique_entries_property
# Out:
# {'caseID': 100,
#  'event time:timestamp': 100,
#  'event concept:name': 38,
#  'eventID ': 100,
#  'case Spend area text': 20,
#  'case Company': 1,
#  'case Document Type': 3,
#  'case Sub spend area text': 100,
#  'case Purchasing Document': 100,
#  'case Purch. Doc. Category name': 1,
#  'case Vendor': 100,
#  'case Item Type': 5,
#  'case Item Category': 3,
#  'case Spend classification text': 4,
#  'case Source': 1,
#  'case Name': 100,
#  'case GR-Based Inv. Verif.': 2,
#  'case Item': 100,
#  'case concept:name': 100,
#  'case Goods Receipt': 1,
#  'event User': 100,
#  'event org:resource': 100,
#  'event Cumulative net worth (EUR)': 100}

# %%
# Inspect the overview table
overview_table
# Out:
#                                                                                                caseID  \
# Event log column property
# Supplier1_Comparative_Mining                                             Supplier1_Comparative_Mining
# Title                                                                                         Case ID
# Importance                                                                        Mandatory attribute
# Level                                                                                      Case level
# Data type                                                                                      string
# Number of entries                                                                              349524
# Number of unique entries                                                                        53103
# List up to 100 unique entries to view the struc...  [2000000000 1, 2000000001 1, 2000000002 1, 200...
# Length of the list of up to 100 unique entries                                                    100
#
#                                                                                  event time:timestamp  \
# Event log column property
# Supplier1_Comparative_Mining                                             Supplier1_Comparative_Mining
# Title                                                                                       Timestamp
# Importance                                                                        Mandatory attribute
# Level                                                                                     Event level
# Data type                                                                              datetime64[ns]
# Number of entries                                                                              349524
# Number of unique entries                                                                        49269
# List up to 100 unique entries to view the struc...  [2018-02-01T13:53:00.000000000, 2018-02-01T14:...
# Length of the list of up to 100 unique entries                                                    100
#
#                                                                                    event concept:name  \
# Event log column property
# Supplier1_Comparative_Mining                                             Supplier1_Comparative_Mining
# Title                                                                                        Activity
# Importance                                                                        Mandatory attribute
# Level                                                                                     Event level
# Data type                                                                                      string
# Number of entries                                                                              349524
# Number of unique entries                                                                           38
# List up to 100 unique entries to view the struc...  [SRM: Created, SRM: Change was Transmitted, SR...
# Length of the list of up to 100 unique entries                                                     38
#
#                                                                                              eventID   \
# Event log column property
# Supplier1_Comparative_Mining                                             Supplier1_Comparative_Mining
# Title                                                                                        Event ID
# Importance                                                                        Mandatory attribute
# Level                                                                                     Event level
# Data type                                                                                     float64
# Number of entries                                                                              349524
# Number of unique entries                                                                         2945
# List up to 100 unique entries to view the struc...  [0.0, 6.0, 3.0, 2.0, 1.0, 4.0, 5.0, 7.0, 8.0, ...
# Length of the list of up to 100 unique entries                                                    100
#
#                                                                                  case Spend area text  \
# Event log column property
# Supplier1_Comparative_Mining                                             Supplier1_Comparative_Mining
# Title                                                                            case Spend area text
# Importance                                                                       Additional attribute
# Level                                                                                      Case level
# Data type                                                                                      string
# Number of entries                                                                              349524
# Number of unique entries                                                                           19
# List up to 100 unique entries to view the struc...  [CAPEX & SOCS, Marketing, Enterprise Services,...
# Length of the list of up to 100 unique entries                                                     20
#
#                                                                     case Company  \
# Event log column property
# Supplier1_Comparative_Mining                        Supplier1_Comparative_Mining
# Title                                                               case Company
# Importance                                                  Additional attribute
# Level                                                                 Case level
# Data type                                                                 string
# Number of entries                                                         349524
# Number of unique entries                                                       1
# List up to 100 unique entries to view the struc...              [companyID_0000]
# Length of the list of up to 100 unique entries                                 1
#
#                                                                                    case Document Type  \
# Event log column property
# Supplier1_Comparative_Mining                                             Supplier1_Comparative_Mining
# Title                                                                              case Document Type
# Importance                                                                       Additional attribute
# Level                                                                                      Case level
# Data type                                                                                      string
# Number of entries                                                                              349524
# Number of unique entries                                                                            3
# List up to 100 unique entries to view the struc...  [EC Purchase order, Standard PO, Framework order]
# Length of the list of up to 100 unique entries                                                      3
#
#                                                                              case Sub spend area text  \
# Event log column property
# Supplier1_Comparative_Mining                                             Supplier1_Comparative_Mining
# Title                                                                        case Sub spend area text
# Importance                                                                       Additional attribute
# Level                                                                                      Case level
# Data type                                                                                      string
# Number of entries                                                                              349524
# Number of unique entries                                                                          122
# List up to 100 unique entries to view the struc...  [Facility Management, Marketing Support Servic...
# Length of the list of up to 100 unique entries                                                    100
#
#                                                                              case Purchasing Document  \
# Event log column property
# Supplier1_Comparative_Mining                                             Supplier1_Comparative_Mining
# Title                                                                        case Purchasing Document
# Importance                                                                       Additional attribute
# Level                                                                                      Case level
# Data type                                                                                       int64
# Number of entries                                                                              349524
# Number of unique entries                                                                        16351
# List up to 100 unique entries to view the struc...  [2000000000, 2000000001, 2000000002, 200000000...
# Length of the list of up to 100 unique entries                                                    100
#
#                                                     case Purch. Doc. Category name  \
# Event log column property
# Supplier1_Comparative_Mining                          Supplier1_Comparative_Mining
# Title                                               case Purch. Doc. Category name
# Importance                                                    Additional attribute
# Level                                                                   Case level
# Data type                                                                   string
# Number of entries                                                           349524
# Number of unique entries                                                         1
# List up to 100 unique entries to view the struc...                [Purchase order]
# Length of the list of up to 100 unique entries                                   1
#
#                                                     ...  \
# Event log column property                           ...
# Supplier1_Comparative_Mining                        ...
# Title                                               ...
# Importance                                          ...
# Level                                               ...
# Data type                                           ...
# Number of entries                                   ...
# Number of unique entries                            ...
# List up to 100 unique entries to view the struc...  ...
# Length of the list of up to 100 unique entries      ...
#
#                                                     case Spend classification text  \
# Event log column property
# Supplier1_Comparative_Mining                          Supplier1_Comparative_Mining
# Title                                               case Spend classification text
# Importance                                                    Additional attribute
# Level                                                                   Case level
# Data type                                                                   string
# Number of entries                                                           349524
# Number of unique entries                                                         3
# List up to 100 unique entries to view the struc...          [NPR, OTHER, <NA>, PR]
# Length of the list of up to 100 unique entries                                   4
#
#                                                                      case Source  \
# Event log column property
# Supplier1_Comparative_Mining                        Supplier1_Comparative_Mining
# Title                                                                case Source
# Importance                                                  Additional attribute
# Level                                                                 Case level
# Data type                                                                 string
# Number of entries                                                         349524
# Number of unique entries                                                       1
# List up to 100 unique entries to view the struc...         [sourceSystemID_0000]
# Length of the list of up to 100 unique entries                                 1
#
#                                                                                             case Name  \
# Event log column property
# Supplier1_Comparative_Mining                                             Supplier1_Comparative_Mining
# Title                                                                                       case Name
# Importance                                                                       Additional attribute
# Level                                                                                      Case level
# Data type                                                                                      string
# Number of entries                                                                              349524
# Number of unique entries                                                                         1300
# List up to 100 unique entries to view the struc...  [vendor_0000, vendor_0001, vendor_0002, vendor...
# Length of the list of up to 100 unique entries                                                    100
#
#                                                        case GR-Based Inv. Verif.  \
# Event log column property
# Supplier1_Comparative_Mining                        Supplier1_Comparative_Mining
# Title                                                  case GR-Based Inv. Verif.
# Importance                                                  Additional attribute
# Level                                                                 Case level
# Data type                                                                   bool
# Number of entries                                                         349524
# Number of unique entries                                                       2
# List up to 100 unique entries to view the struc...                 [False, True]
# Length of the list of up to 100 unique entries                                 2
#
#                                                                                             case Item  \
# Event log column property
# Supplier1_Comparative_Mining                                             Supplier1_Comparative_Mining
# Title                                                                                       case Item
# Importance                                                                       Additional attribute
# Level                                                                                      Case level
# Data type                                                                                       int64
# Number of entries                                                                              349524
# Number of unique entries                                                                          273
# List up to 100 unique entries to view the struc...  [1, 2, 3, 4, 5, 6, 10, 11, 7, 8, 9, 20, 30, 40...
# Length of the list of up to 100 unique entries                                                    100
#
#                                                                                     case concept:name  \
# Event log column property
# Supplier1_Comparative_Mining                                             Supplier1_Comparative_Mining
# Title                                                                               case concept:name
# Importance                                                                       Additional attribute
# Level                                                                                      Case level
# Data type                                                                                      string
# Number of entries                                                                              349524
# Number of unique entries                                                                        53103
# List up to 100 unique entries to view the struc...  [2000000000_00001, 2000000001_00001, 200000000...
# Length of the list of up to 100 unique entries                                                    100
#
#                                                               case Goods Receipt  \
# Event log column property
# Supplier1_Comparative_Mining                        Supplier1_Comparative_Mining
# Title                                                         case Goods Receipt
# Importance                                                  Additional attribute
# Level                                                                 Case level
# Data type                                                                   bool
# Number of entries                                                         349524
# Number of unique entries                                                       1
# List up to 100 unique entries to view the struc...                        [True]
# Length of the list of up to 100 unique entries                                 1
#
#                                                                                            event User  \
# Event log column property
# Supplier1_Comparative_Mining                                             Supplier1_Comparative_Mining
# Title                                                                                      event User
# Importance                                                                       Additional attribute
# Level                                                                                     Event level
# Data type                                                                                      string
# Number of entries                                                                              349524
# Number of unique entries                                                                          366
# List up to 100 unique entries to view the struc...  [batch_00, user_000, NONE, user_001, user_002,...
# Length of the list of up to 100 unique entries                                                    100
#
#                                                                                    event org:resource  \
# Event log column property
# Supplier1_Comparative_Mining                                             Supplier1_Comparative_Mining
# Title                                                                              event org:resource
# Importance                                                                       Additional attribute
# Level                                                                                     Event level
# Data type                                                                                      string
# Number of entries                                                                              349524
# Number of unique entries                                                                          366
# List up to 100 unique entries to view the struc...  [batch_00, user_000, NONE, user_001, user_002,...
# Length of the list of up to 100 unique entries                                                    100
#
#                                                                      event Cumulative net worth (EUR)
# Event log column property
# Supplier1_Comparative_Mining                                             Supplier1_Comparative_Mining
# Title                                                                event Cumulative net worth (EUR)
# Importance                                                                       Additional attribute
# Level                                                                                     Event level
# Data type                                                                                       int64
# Number of entries                                                                              349524
# Number of unique entries                                                                        10653
# List up to 100 unique entries to view the struc...  [298, 557, 76210, 28, 37, 44, 166, 433, 86, 37...
# Length of the list of up to 100 unique entries                                                    100
#
# [9 rows x 23 columns]

# %%
# Overview property: Number of duplicate entries
number_of_duplicate_entries_property = {}
for log_column in log_columns:
  number_of_duplicate_entries_property[log_column] = number_of_entries_property[log_column] - number_of_unique_entries_property[log_column]

overview_table.loc['Number of duplicate entries'] = number_of_duplicate_entries_property
overview_table.loc['Number of duplicate entries']
# Out:
# caseID                              296421
# event time:timestamp                300255
# event concept:name                  349486
# eventID                             346579
# case Spend area text                349505
# case Company                        349523
# case Document Type                  349521
# case Sub spend area text            349402
# case Purchasing Document            333173
# case Purch. Doc. Category name      349523
# case Vendor                         348164
# case Item Type                      349519
# case Item Category                  349521
# case Spend classification text      349521
# case Source                         349523
# case Name                           348224
# case GR-Based Inv. Verif.           349522
# case Item                           349251
# case concept:name                   296421
# case Goods Receipt                  349523
# event User                          349158
# event org:resource                  349158
# event Cumulative net worth (EUR)    338871
# Name: Number of duplicate entries, dtype: object

# %%
# Overview property: Number of undefined entries
number_of_undefined_entries_property = {}
nan_info = event_log_table.isna().sum()
for log_column in log_columns:
    number_of_undefined_entries_property[log_column] = nan_info[log_column]

overview_table.loc['Number of undefined entries'] = number_of_undefined_entries_property
number_of_undefined_entries_property
# Out:
# {'caseID': 0,
#  'event time:timestamp': 0,
#  'event concept:name': 0,
#  'eventID ': 0,
#  'case Spend area text': 2626,
#  'case Company': 0,
#  'case Document Type': 0,
#  'case Sub spend area text': 2626,
#  'case Purchasing Document': 0,
#  'case Purch. Doc. Category name': 0,
#  'case Vendor': 0,
#  'case Item Type': 0,
#  'case Item Category': 0,
#  'case Spend classification text': 2626,
#  'case Source': 0,
#  'case Name': 0,
#  'case GR-Based Inv. Verif.': 0,
#  'case Item': 0,
#  'case concept:name': 0,
#  'case Goods Receipt': 0,
#  'event User': 0,
#  'event org:resource': 0,
#  'event Cumulative net worth (EUR)': 0}

# %%
# Overview propperty: Number of undefined entries in percentages
percentage_of_undefined_entries_property = {}
nan_info = event_log_table.isna().sum()
for log_column in log_columns:
    percentage = nan_info[log_column]/len(event_log_table)*100 #len calculates the length of a variable
    percentage = f'{percentage:.2f}'
    percentage_of_undefined_entries_property[log_column] = percentage

overview_table.loc['Percentage of undefined entries'] = percentage_of_undefined_entries_property
percentage_of_undefined_entries_property
# Out:
# {'caseID': '0.00',
#  'event time:timestamp': '0.00',
#  'event concept:name': '0.00',
#  'eventID ': '0.00',
#  'case Spend area text': '0.75',
#  'case Company': '0.00',
#  'case Document Type': '0.00',
#  'case Sub spend area text': '0.75',
#  'case Purchasing Document': '0.00',
#  'case Purch. Doc. Category name': '0.00',
#  'case Vendor': '0.00',
#  'case Item Type': '0.00',
#  'case Item Category': '0.00',
#  'case Spend classification text': '0.75',
#  'case Source': '0.00',
#  'case Name': '0.00',
#  'case GR-Based Inv. Verif.': '0.00',
#  'case Item': '0.00',
#  'case concept:name': '0.00',
#  'case Goods Receipt': '0.00',
#  'event User': '0.00',
#  'event org:resource': '0.00',
#  'event Cumulative net worth (EUR)': '0.00'}

# %%
overview_table
# Out:
#                                                                                                caseID  \
# Event log column property
# Supplier1_Comparative_Mining                                             Supplier1_Comparative_Mining
# Title                                                                                         Case ID
# Importance                                                                        Mandatory attribute
# Level                                                                                      Case level
# Data type                                                                                      string
# Number of entries                                                                              349524
# Number of unique entries                                                                        53103
# List up to 100 unique entries to view the struc...  [2000000000 1, 2000000001 1, 2000000002 1, 200...
# Length of the list of up to 100 unique entries                                                    100
# Number of duplicate entries                                                                    296421
# Number of undefined entries                                                                         0
# Percentage of undefined entries                                                                  0.00
#
#                                                                                  event time:timestamp  \
# Event log column property
# Supplier1_Comparative_Mining                                             Supplier1_Comparative_Mining
# Title                                                                                       Timestamp
# Importance                                                                        Mandatory attribute
# Level                                                                                     Event level
# Data type                                                                              datetime64[ns]
# Number of entries                                                                              349524
# Number of unique entries                                                                        49269
# List up to 100 unique entries to view the struc...  [2018-02-01T13:53:00.000000000, 2018-02-01T14:...
# Length of the list of up to 100 unique entries                                                    100
# Number of duplicate entries                                                                    300255
# Number of undefined entries                                                                         0
# Percentage of undefined entries                                                                  0.00
#
#                                                                                    event concept:name  \
# Event log column property
# Supplier1_Comparative_Mining                                             Supplier1_Comparative_Mining
# Title                                                                                        Activity
# Importance                                                                        Mandatory attribute
# Level                                                                                     Event level
# Data type                                                                                      string
# Number of entries                                                                              349524
# Number of unique entries                                                                           38
# List up to 100 unique entries to view the struc...  [SRM: Created, SRM: Change was Transmitted, SR...
# Length of the list of up to 100 unique entries                                                     38
# Number of duplicate entries                                                                    349486
# Number of undefined entries                                                                         0
# Percentage of undefined entries                                                                  0.00
#
#                                                                                              eventID   \
# Event log column property
# Supplier1_Comparative_Mining                                             Supplier1_Comparative_Mining
# Title                                                                                        Event ID
# Importance                                                                        Mandatory attribute
# Level                                                                                     Event level
# Data type                                                                                     float64
# Number of entries                                                                              349524
# Number of unique entries                                                                         2945
# List up to 100 unique entries to view the struc...  [0.0, 6.0, 3.0, 2.0, 1.0, 4.0, 5.0, 7.0, 8.0, ...
# Length of the list of up to 100 unique entries                                                    100
# Number of duplicate entries                                                                    346579
# Number of undefined entries                                                                         0
# Percentage of undefined entries                                                                  0.00
#
#                                                                                  case Spend area text  \
# Event log column property
# Supplier1_Comparative_Mining                                             Supplier1_Comparative_Mining
# Title                                                                            case Spend area text
# Importance                                                                       Additional attribute
# Level                                                                                      Case level
# Data type                                                                                      string
# Number of entries                                                                              349524
# Number of unique entries                                                                           19
# List up to 100 unique entries to view the struc...  [CAPEX & SOCS, Marketing, Enterprise Services,...
# Length of the list of up to 100 unique entries                                                     20
# Number of duplicate entries                                                                    349505
# Number of undefined entries                                                                      2626
# Percentage of undefined entries                                                                  0.75
#
#                                                                     case Company  \
# Event log column property
# Supplier1_Comparative_Mining                        Supplier1_Comparative_Mining
# Title                                                               case Company
# Importance                                                  Additional attribute
# Level                                                                 Case level
# Data type                                                                 string
# Number of entries                                                         349524
# Number of unique entries                                                       1
# List up to 100 unique entries to view the struc...              [companyID_0000]
# Length of the list of up to 100 unique entries                                 1
# Number of duplicate entries                                               349523
# Number of undefined entries                                                    0
# Percentage of undefined entries                                             0.00
#
#                                                                                    case Document Type  \
# Event log column property
# Supplier1_Comparative_Mining                                             Supplier1_Comparative_Mining
# Title                                                                              case Document Type
# Importance                                                                       Additional attribute
# Level                                                                                      Case level
# Data type                                                                                      string
# Number of entries                                                                              349524
# Number of unique entries                                                                            3
# List up to 100 unique entries to view the struc...  [EC Purchase order, Standard PO, Framework order]
# Length of the list of up to 100 unique entries                                                      3
# Number of duplicate entries                                                                    349521
# Number of undefined entries                                                                         0
# Percentage of undefined entries                                                                  0.00
#
#                                                                              case Sub spend area text  \
# Event log column property
# Supplier1_Comparative_Mining                                             Supplier1_Comparative_Mining
# Title                                                                        case Sub spend area text
# Importance                                                                       Additional attribute
# Level                                                                                      Case level
# Data type                                                                                      string
# Number of entries                                                                              349524
# Number of unique entries                                                                          122
# List up to 100 unique entries to view the struc...  [Facility Management, Marketing Support Servic...
# Length of the list of up to 100 unique entries                                                    100
# Number of duplicate entries                                                                    349402
# Number of undefined entries                                                                      2626
# Percentage of undefined entries                                                                  0.75
#
#                                                                              case Purchasing Document  \
# Event log column property
# Supplier1_Comparative_Mining                                             Supplier1_Comparative_Mining
# Title                                                                        case Purchasing Document
# Importance                                                                       Additional attribute
# Level                                                                                      Case level
# Data type                                                                                       int64
# Number of entries                                                                              349524
# Number of unique entries                                                                        16351
# List up to 100 unique entries to view the struc...  [2000000000, 2000000001, 2000000002, 200000000...
# Length of the list of up to 100 unique entries                                                    100
# Number of duplicate entries                                                                    333173
# Number of undefined entries                                                                         0
# Percentage of undefined entries                                                                  0.00
#
#                                                     case Purch. Doc. Category name  \
# Event log column property
# Supplier1_Comparative_Mining                          Supplier1_Comparative_Mining
# Title                                               case Purch. Doc. Category name
# Importance                                                    Additional attribute
# Level                                                                   Case level
# Data type                                                                   string
# Number of entries                                                           349524
# Number of unique entries                                                         1
# List up to 100 unique entries to view the struc...                [Purchase order]
# Length of the list of up to 100 unique entries                                   1
# Number of duplicate entries                                                 349523
# Number of undefined entries                                                      0
# Percentage of undefined entries                                               0.00
#
#                                                     ...  \
# Event log column property                           ...
# Supplier1_Comparative_Mining                        ...
# Title                                               ...
# Importance                                          ...
# Level                                               ...
# Data type                                           ...
# Number of entries                                   ...
# Number of unique entries                            ...
# List up to 100 unique entries to view the struc...  ...
# Length of the list of up to 100 unique entries      ...
# Number of duplicate entries                         ...
# Number of undefined entries                         ...
# Percentage of undefined entries                     ...
#
#                                                     case Spend classification text  \
# Event log column property
# Supplier1_Comparative_Mining                          Supplier1_Comparative_Mining
# Title                                               case Spend classification text
# Importance                                                    Additional attribute
# Level                                                                   Case level
# Data type                                                                   string
# Number of entries                                                           349524
# Number of unique entries                                                         3
# List up to 100 unique entries to view the struc...          [NPR, OTHER, <NA>, PR]
# Length of the list of up to 100 unique entries                                   4
# Number of duplicate entries                                                 349521
# Number of undefined entries                                                   2626
# Percentage of undefined entries                                               0.75
#
#                                                                      case Source  \
# Event log column property
# Supplier1_Comparative_Mining                        Supplier1_Comparative_Mining
# Title                                                                case Source
# Importance                                                  Additional attribute
# Level                                                                 Case level
# Data type                                                                 string
# Number of entries                                                         349524
# Number of unique entries                                                       1
# List up to 100 unique entries to view the struc...         [sourceSystemID_0000]
# Length of the list of up to 100 unique entries                                 1
# Number of duplicate entries                                               349523
# Number of undefined entries                                                    0
# Percentage of undefined entries                                             0.00
#
#                                                                                             case Name  \
# Event log column property
# Supplier1_Comparative_Mining                                             Supplier1_Comparative_Mining
# Title                                                                                       case Name
# Importance                                                                       Additional attribute
# Level                                                                                      Case level
# Data type                                                                                      string
# Number of entries                                                                              349524
# Number of unique entries                                                                         1300
# List up to 100 unique entries to view the struc...  [vendor_0000, vendor_0001, vendor_0002, vendor...
# Length of the list of up to 100 unique entries                                                    100
# Number of duplicate entries                                                                    348224
# Number of undefined entries                                                                         0
# Percentage of undefined entries                                                                  0.00
#
#                                                        case GR-Based Inv. Verif.  \
# Event log column property
# Supplier1_Comparative_Mining                        Supplier1_Comparative_Mining
# Title                                                  case GR-Based Inv. Verif.
# Importance                                                  Additional attribute
# Level                                                                 Case level
# Data type                                                                   bool
# Number of entries                                                         349524
# Number of unique entries                                                       2
# List up to 100 unique entries to view the struc...                 [False, True]
# Length of the list of up to 100 unique entries                                 2
# Number of duplicate entries                                               349522
# Number of undefined entries                                                    0
# Percentage of undefined entries                                             0.00
#
#                                                                                             case Item  \
# Event log column property
# Supplier1_Comparative_Mining                                             Supplier1_Comparative_Mining
# Title                                                                                       case Item
# Importance                                                                       Additional attribute
# Level                                                                                      Case level
# Data type                                                                                       int64
# Number of entries                                                                              349524
# Number of unique entries                                                                          273
# List up to 100 unique entries to view the struc...  [1, 2, 3, 4, 5, 6, 10, 11, 7, 8, 9, 20, 30, 40...
# Length of the list of up to 100 unique entries                                                    100
# Number of duplicate entries                                                                    349251
# Number of undefined entries                                                                         0
# Percentage of undefined entries                                                                  0.00
#
#                                                                                     case concept:name  \
# Event log column property
# Supplier1_Comparative_Mining                                             Supplier1_Comparative_Mining
# Title                                                                               case concept:name
# Importance                                                                       Additional attribute
# Level                                                                                      Case level
# Data type                                                                                      string
# Number of entries                                                                              349524
# Number of unique entries                                                                        53103
# List up to 100 unique entries to view the struc...  [2000000000_00001, 2000000001_00001, 200000000...
# Length of the list of up to 100 unique entries                                                    100
# Number of duplicate entries                                                                    296421
# Number of undefined entries                                                                         0
# Percentage of undefined entries                                                                  0.00
#
#                                                               case Goods Receipt  \
# Event log column property
# Supplier1_Comparative_Mining                        Supplier1_Comparative_Mining
# Title                                                         case Goods Receipt
# Importance                                                  Additional attribute
# Level                                                                 Case level
# Data type                                                                   bool
# Number of entries                                                         349524
# Number of unique entries                                                       1
# List up to 100 unique entries to view the struc...                        [True]
# Length of the list of up to 100 unique entries                                 1
# Number of duplicate entries                                               349523
# Number of undefined entries                                                    0
# Percentage of undefined entries                                             0.00
#
#                                                                                            event User  \
# Event log column property
# Supplier1_Comparative_Mining                                             Supplier1_Comparative_Mining
# Title                                                                                      event User
# Importance                                                                       Additional attribute
# Level                                                                                     Event level
# Data type                                                                                      string
# Number of entries                                                                              349524
# Number of unique entries                                                                          366
# List up to 100 unique entries to view the struc...  [batch_00, user_000, NONE, user_001, user_002,...
# Length of the list of up to 100 unique entries                                                    100
# Number of duplicate entries                                                                    349158
# Number of undefined entries                                                                         0
# Percentage of undefined entries                                                                  0.00
#
#                                                                                    event org:resource  \
# Event log column property
# Supplier1_Comparative_Mining                                             Supplier1_Comparative_Mining
# Title                                                                              event org:resource
# Importance                                                                       Additional attribute
# Level                                                                                     Event level
# Data type                                                                                      string
# Number of entries                                                                              349524
# Number of unique entries                                                                          366
# List up to 100 unique entries to view the struc...  [batch_00, user_000, NONE, user_001, user_002,...
# Length of the list of up to 100 unique entries                                                    100
# Number of duplicate entries                                                                    349158
# Number of undefined entries                                                                         0
# Percentage of undefined entries                                                                  0.00
#
#                                                                      event Cumulative net worth (EUR)
# Event log column property
# Supplier1_Comparative_Mining                                             Supplier1_Comparative_Mining
# Title                                                                event Cumulative net worth (EUR)
# Importance                                                                       Additional attribute
# Level                                                                                     Event level
# Data type                                                                                       int64
# Number of entries                                                                              349524
# Number of unique entries                                                                        10653
# List up to 100 unique entries to view the struc...  [298, 557, 76210, 28, 37, 44, 166, 433, 86, 37...
# Length of the list of up to 100 unique entries                                                    100
# Number of duplicate entries                                                                    338871
# Number of undefined entries                                                                         0
# Percentage of undefined entries                                                                  0.00
#
# [12 rows x 23 columns]

# %%
# Switching the index of the Meta-DataFrame and table structure
# The current layout of the Meta-Dataframe is transformed, that the columns become the rows, and the rows become the columns.
overview_table = overview_table.T
overview_table.reset_index(inplace = True)
overview_table.rename(columns={'index': 'Property'}, inplace = True)
overview_table
# Out:
# Event log column property                          Property  \
# 0                                                    caseID
# 1                                      event time:timestamp
# 2                                        event concept:name
# 3                                                  eventID
# 4                                      case Spend area text
# 5                                              case Company
# 6                                        case Document Type
# 7                                  case Sub spend area text
# 8                                  case Purchasing Document
# 9                            case Purch. Doc. Category name
# 10                                              case Vendor
# 11                                           case Item Type
# 12                                       case Item Category
# 13                           case Spend classification text
# 14                                              case Source
# 15                                                case Name
# 16                                case GR-Based Inv. Verif.
# 17                                                case Item
# 18                                        case concept:name
# 19                                       case Goods Receipt
# 20                                               event User
# 21                                       event org:resource
# 22                         event Cumulative net worth (EUR)
#
# Event log column property  Supplier1_Comparative_Mining  \
# 0                          Supplier1_Comparative_Mining
# 1                          Supplier1_Comparative_Mining
# 2                          Supplier1_Comparative_Mining
# 3                          Supplier1_Comparative_Mining
# 4                          Supplier1_Comparative_Mining
# 5                          Supplier1_Comparative_Mining
# 6                          Supplier1_Comparative_Mining
# 7                          Supplier1_Comparative_Mining
# 8                          Supplier1_Comparative_Mining
# 9                          Supplier1_Comparative_Mining
# 10                         Supplier1_Comparative_Mining
# 11                         Supplier1_Comparative_Mining
# 12                         Supplier1_Comparative_Mining
# 13                         Supplier1_Comparative_Mining
# 14                         Supplier1_Comparative_Mining
# 15                         Supplier1_Comparative_Mining
# 16                         Supplier1_Comparative_Mining
# 17                         Supplier1_Comparative_Mining
# 18                         Supplier1_Comparative_Mining
# 19                         Supplier1_Comparative_Mining
# 20                         Supplier1_Comparative_Mining
# 21                         Supplier1_Comparative_Mining
# 22                         Supplier1_Comparative_Mining
#
# Event log column property                             Title  \
# 0                                                   Case ID
# 1                                                 Timestamp
# 2                                                  Activity
# 3                                                  Event ID
# 4                                      case Spend area text
# 5                                              case Company
# 6                                        case Document Type
# 7                                  case Sub spend area text
# 8                                  case Purchasing Document
# 9                            case Purch. Doc. Category name
# 10                                              case Vendor
# 11                                           case Item Type
# 12                                       case Item Category
# 13                           case Spend classification text
# 14                                              case Source
# 15                                                case Name
# 16                                case GR-Based Inv. Verif.
# 17                                                case Item
# 18                                        case concept:name
# 19                                       case Goods Receipt
# 20                                               event User
# 21                                       event org:resource
# 22                         event Cumulative net worth (EUR)
#
# Event log column property            Importance        Level       Data type  \
# 0                           Mandatory attribute   Case level          string
# 1                           Mandatory attribute  Event level  datetime64[ns]
# 2                           Mandatory attribute  Event level          string
# 3                           Mandatory attribute  Event level         float64
# 4                          Additional attribute   Case level          string
# 5                          Additional attribute   Case level          string
# 6                          Additional attribute   Case level          string
# 7                          Additional attribute   Case level          string
# 8                          Additional attribute   Case level           int64
# 9                          Additional attribute   Case level          string
# 10                         Additional attribute   Case level          string
# 11                         Additional attribute   Case level          string
# 12                         Additional attribute   Case level          string
# 13                         Additional attribute   Case level          string
# 14                         Additional attribute   Case level          string
# 15                         Additional attribute   Case level          string
# 16                         Additional attribute   Case level            bool
# 17                         Additional attribute   Case level           int64
# 18                         Additional attribute   Case level          string
# 19                         Additional attribute   Case level            bool
# 20                         Additional attribute  Event level          string
# 21                         Additional attribute  Event level          string
# 22                         Additional attribute  Event level           int64
#
# Event log column property Number of entries Number of unique entries  \
# 0                                    349524                    53103
# 1                                    349524                    49269
# 2                                    349524                       38
# 3                                    349524                     2945
# 4                                    349524                       19
# 5                                    349524                        1
# 6                                    349524                        3
# 7                                    349524                      122
# 8                                    349524                    16351
# 9                                    349524                        1
# 10                                   349524                     1360
# 11                                   349524                        5
# 12                                   349524                        3
# 13                                   349524                        3
# 14                                   349524                        1
# 15                                   349524                     1300
# 16                                   349524                        2
# 17                                   349524                      273
# 18                                   349524                    53103
# 19                                   349524                        1
# 20                                   349524                      366
# 21                                   349524                      366
# 22                                   349524                    10653
#
# Event log column property List up to 100 unique entries to view the structure of the event attributes  \
# 0                          [2000000000 1, 2000000001 1, 2000000002 1, 200...
# 1                          [2018-02-01T13:53:00.000000000, 2018-02-01T14:...
# 2                          [SRM: Created, SRM: Change was Transmitted, SR...
# 3                          [0.0, 6.0, 3.0, 2.0, 1.0, 4.0, 5.0, 7.0, 8.0, ...
# 4                          [CAPEX & SOCS, Marketing, Enterprise Services,...
# 5                                                           [companyID_0000]
# 6                          [EC Purchase order, Standard PO, Framework order]
# 7                          [Facility Management, Marketing Support Servic...
# 8                          [2000000000, 2000000001, 2000000002, 200000000...
# 9                                                           [Purchase order]
# 10                         [vendorID_0000, vendorID_0001, vendorID_0002, ...
# 11                         [Standard, Service, Consignment, Subcontractin...
# 12                         [3-way match, invoice before GR, 3-way match, ...
# 13                                                    [NPR, OTHER, <NA>, PR]
# 14                                                     [sourceSystemID_0000]
# 15                         [vendor_0000, vendor_0001, vendor_0002, vendor...
# 16                                                             [False, True]
# 17                         [1, 2, 3, 4, 5, 6, 10, 11, 7, 8, 9, 20, 30, 40...
# 18                         [2000000000_00001, 2000000001_00001, 200000000...
# 19                                                                    [True]
# 20                         [batch_00, user_000, NONE, user_001, user_002,...
# 21                         [batch_00, user_000, NONE, user_001, user_002,...
# 22                         [298, 557, 76210, 28, 37, 44, 166, 433, 86, 37...
#
# Event log column property Length of the list of up to 100 unique entries  \
# 0                                                                    100
# 1                                                                    100
# 2                                                                     38
# 3                                                                    100
# 4                                                                     20
# 5                                                                      1
# 6                                                                      3
# 7                                                                    100
# 8                                                                    100
# 9                                                                      1
# 10                                                                   100
# 11                                                                     5
# 12                                                                     3
# 13                                                                     4
# 14                                                                     1
# 15                                                                   100
# 16                                                                     2
# 17                                                                   100
# 18                                                                   100
# 19                                                                     1
# 20                                                                   100
# 21                                                                   100
# 22                                                                   100
#
# Event log column property Number of duplicate entries  \
# 0                                              296421
# 1                                              300255
# 2                                              349486
# 3                                              346579
# 4                                              349505
# 5                                              349523
# 6                                              349521
# 7                                              349402
# 8                                              333173
# 9                                              349523
# 10                                             348164
# 11                                             349519
# 12                                             349521
# 13                                             349521
# 14                                             349523
# 15                                             348224
# 16                                             349522
# 17                                             349251
# 18                                             296421
# 19                                             349523
# 20                                             349158
# 21                                             349158
# 22                                             338871
#
# Event log column property Number of undefined entries  \
# 0                                                   0
# 1                                                   0
# 2                                                   0
# 3                                                   0
# 4                                                2626
# 5                                                   0
# 6                                                   0
# 7                                                2626
# 8                                                   0
# 9                                                   0
# 10                                                  0
# 11                                                  0
# 12                                                  0
# 13                                               2626
# 14                                                  0
# 15                                                  0
# 16                                                  0
# 17                                                  0
# 18                                                  0
# 19                                                  0
# 20                                                  0
# 21                                                  0
# 22                                                  0
#
# Event log column property Percentage of undefined entries
# 0                                                    0.00
# 1                                                    0.00
# 2                                                    0.00
# 3                                                    0.00
# 4                                                    0.75
# 5                                                    0.00
# 6                                                    0.00
# 7                                                    0.75
# 8                                                    0.00
# 9                                                    0.00
# 10                                                   0.00
# 11                                                   0.00
# 12                                                   0.00
# 13                                                   0.75
# 14                                                   0.00
# 15                                                   0.00
# 16                                                   0.00
# 17                                                   0.00
# 18                                                   0.00
# 19                                                   0.00
# 20                                                   0.00
# 21                                                   0.00
# 22                                                   0.00

# %%
#This is an exploratory code snippet checking for the longest case to model the graph in a deperate database to reveal the event activity sequences in a directly follows graph
case_sizes = event_log_table.groupby(['caseID']).size()
#use of argmax() instead of max()
index_of_longest_case = case_sizes.argmax()
caseID_of_longest_case = case_sizes.index[index_of_longest_case] 

# Without the .copy() suffix, we get: A value is trying to be set on a copy of a slice from a DataFrame
case_rows = event_log_table[event_log_table['caseID'] == caseID_of_longest_case].copy()
case_rows.sort_values(by='event time:timestamp', ascending=True, inplace=True)
case_rows.to_csv(f'analysis/longest_case_in_{event_log_name}.csv')

# a csv table is created in the analysis file which is then transformed into Neo4j commands 
if not os.path.exists('analysis'):
    os.mkdir('analysis')
overview_table.to_csv(f'analysis/overview_{event_log_name}.csv')

(f'Written: datatype table to analysis/overview_{event_log_name}.csv')
# Out:
# 'Written: datatype table to analysis/overview_BPIC_Synthetic_Split_1.csv'

# %% [markdown]
# # End of Script 1 to generate the Meta-DataFrame
# Author: Kyle Smith <br>
# Script: For Masterthesis <br>
# University: University of Camerino & University of Applied Sciences Northwestern Switzerland

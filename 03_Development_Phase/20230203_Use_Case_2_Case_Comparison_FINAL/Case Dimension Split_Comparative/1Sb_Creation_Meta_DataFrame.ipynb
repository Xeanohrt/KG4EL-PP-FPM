# %% [markdown]
# # First Script: Creating the Meta-DataFrame
# In this script the author analyzes each column of the synthetic BPI_C 2019 event logs.

# %%
#import libraries
import json
import os
import pandas as pd
import numpy
import re

# %%
event_log_name = 'BPIC_Synthetic_Split_2' #addd the name of the event log - change for each event log
event_log_file_path = f'event_logs/{event_log_name}.csv' #string interpolation, one has to create a folder called 'event_logs' to import the event log.csv
print(event_log_file_path) # review the path
# Out:
# event_logs/BPIC_Synthetic_Split_2.csv

# %%
#import the event log
event_log_table = pd.read_csv(event_log_file_path) #optionally this can be added; header = 0, encoding = 'ISO-8859-1') if encoding issues arise
event_log_table.head(20) #view the first 20 rows
# Out:
# /var/folders/vz/snd73j8d2mj817493bt9ykfc0000gn/T/ipykernel_63845/3280910462.py:2: DtypeWarning: Columns (14) have mixed types. Specify dtype option on import or set low_memory=False.
#   event_log_table = pd.read_csv(event_log_file_path) #optionally this can be added; header = 0, encoding = 'ISO-8859-1') if encoding issues arise
#         eventID  case Spend area text case Document Type  \
# 0   2.270000e+14            Logistics        Standard PO
# 1   2.270000e+14            Logistics        Standard PO
# 2   2.270000e+14            Logistics        Standard PO
# 3   2.270000e+14            Logistics        Standard PO
# 4   2.270000e+14            Logistics        Standard PO
# 5   2.270000e+14            Logistics        Standard PO
# 6   2.270000e+14            Logistics        Standard PO
# 7   2.270000e+14            Logistics        Standard PO
# 8   2.270000e+14            Logistics        Standard PO
# 9   2.270000e+14            Logistics        Standard PO
# 10  2.270000e+14            Logistics        Standard PO
# 11  2.270000e+14            Logistics        Standard PO
# 12  2.270000e+14            Logistics        Standard PO
# 13  2.270000e+14            Logistics        Standard PO
# 14  2.270000e+14            Logistics        Standard PO
# 15  2.270000e+14            Logistics        Standard PO
# 16  2.270000e+14            Logistics        Standard PO
# 17  2.270000e+14            Logistics        Standard PO
# 18  2.270000e+14            Logistics        Standard PO
# 19  2.270000e+14            Logistics        Standard PO
#
#    case Sub spend area text case Purch. Doc. Category name    case Vendor  \
# 0               Road Packed                 Purchase order  vendorID_0472
# 1               Road Packed                 Purchase order  vendorID_0472
# 2               Road Packed                 Purchase order  vendorID_0472
# 3               Road Packed                 Purchase order  vendorID_0472
# 4               Road Packed                 Purchase order  vendorID_0472
# 5               Road Packed                 Purchase order  vendorID_0472
# 6               Road Packed                 Purchase order  vendorID_0472
# 7               Road Packed                 Purchase order  vendorID_0472
# 8               Road Packed                 Purchase order  vendorID_0472
# 9               Road Packed                 Purchase order  vendorID_0472
# 10              Road Packed                 Purchase order  vendorID_0472
# 11              Road Packed                 Purchase order  vendorID_0472
# 12              Road Packed                 Purchase order  vendorID_0472
# 13              Road Packed                 Purchase order  vendorID_0472
# 14              Road Packed                 Purchase order  vendorID_0472
# 15              Road Packed                 Purchase order  vendorID_0472
# 16              Road Packed                 Purchase order  vendorID_0472
# 17              Road Packed                 Purchase order  vendorID_0472
# 18              Road Packed                 Purchase order  vendorID_0472
# 19              Road Packed                            NaN  vendorID_0472
#
#    case Item Type                 case Item Category  \
# 0         Service  Three way match, invoice after GR
# 1         Service  Three way match, invoice after GR
# 2         Service  Three way match, invoice after GR
# 3         Service  Three way match, invoice after GR
# 4         Service  Three way match, invoice after GR
# 5         Service  Three way match, invoice after GR
# 6         Service  Three way match, invoice after GR
# 7         Service  Three way match, invoice after GR
# 8         Service  Three way match, invoice after GR
# 9         Service  Three way match, invoice after GR
# 10        Service  Three way match, invoice after GR
# 11        Service  Three way match, invoice after GR
# 12        Service  Three way match, invoice after GR
# 13        Service  Three way match, invoice after GR
# 14        Service  Three way match, invoice after GR
# 15        Service  Three way match, invoice after GR
# 16        Service  Three way match, invoice after GR
# 17        Service  Three way match, invoice after GR
# 18        Service  Three way match, invoice after GR
# 19        Service  Three way match, invoice after GR
#
#    case Spend classification text          case Source  ...  \
# 0                             NPR  sourceSystemID_0000  ...
# 1                             NPR  sourceSystemID_0000  ...
# 2                             NPR  sourceSystemID_0000  ...
# 3                             NPR  sourceSystemID_0000  ...
# 4                             NPR  sourceSystemID_0000  ...
# 5                             NPR  sourceSystemID_0000  ...
# 6                             NPR  sourceSystemID_0000  ...
# 7                             NPR  sourceSystemID_0000  ...
# 8                             NPR  sourceSystemID_0000  ...
# 9                             NPR  sourceSystemID_0000  ...
# 10                            NPR  sourceSystemID_0000  ...
# 11                            NPR  sourceSystemID_0000  ...
# 12                            NPR  sourceSystemID_0000  ...
# 13                            NPR  sourceSystemID_0000  ...
# 14                            NPR  sourceSystemID_0000  ...
# 15                            NPR  sourceSystemID_0000  ...
# 16                            NPR  sourceSystemID_0000  ...
# 17                            NPR  sourceSystemID_0000  ...
# 18                            NPR  sourceSystemID_0000  ...
# 19                            NPR  sourceSystemID_0000  ...
#
#    case GR-Based Inv. Verif.  case Item  case concept:name case Goods Receipt  \
# 0                          1          1   4507016139_00001               True
# 1                          1          1   4507016139_00001               True
# 2                          1          1   4507016139_00001               True
# 3                          1          1   4507016139_00001               True
# 4                          1          1   4507016139_00001               True
# 5                          1          1   4507016139_00001               True
# 6                          1          1   4507016139_00001               True
# 7                          1          1   4507016139_00001               True
# 8                          1          1   4507016139_00001               True
# 9                          1          1   4507016139_00001               True
# 10                         1          1   4507016139_00001               True
# 11                         1          1   4507016139_00001               True
# 12                         1          1   4507016139_00001               True
# 13                         1          1   4507016139_00001               True
# 14                         1          1   4507016139_00001               True
# 15                         1          1   4507016139_00001               True
# 16                         1          1   4507016139_00001               True
# 17                         1          1   4507016139_00001               True
# 18                         1          1   4507016139_00001               True
# 19                         1          1   4507016139_00001               True
#
#    event User event org:resource          event concept:name  \
# 0         NaN                NaN  Record Service Entry Sheet
# 1    batch_07           batch_07        Record Goods Receipt
# 2    batch_07           batch_07        Record Goods Receipt
# 3    batch_07           batch_07        Record Goods Receipt
# 4         NaN                NaN  Record Service Entry Sheet
# 5         NaN                NaN  Record Service Entry Sheet
# 6         NaN                NaN  Record Service Entry Sheet
# 7         NaN                NaN  Record Service Entry Sheet
# 8         NaN                NaN  Record Service Entry Sheet
# 9         NaN                NaN  Record Service Entry Sheet
# 10        NaN                NaN  Record Service Entry Sheet
# 11   batch_07           batch_07        Record Goods Receipt
# 12        NaN                NaN  Record Service Entry Sheet
# 13        NaN                NaN  Record Service Entry Sheet
# 14        NaN                NaN  Record Service Entry Sheet
# 15        NaN                NaN  Record Service Entry Sheet
# 16        NaN                NaN  Record Service Entry Sheet
# 17        NaN                NaN  Record Service Entry Sheet
# 18   batch_07           batch_07        Record Goods Receipt
# 19   batch_07           batch_07        Record Goods Receipt
#
#    event Cumulative net worth (EUR)  event time:timestamp        caseID
# 0                              72.0  Mar 14 2018 03:11:00  4507016139 1
# 1                           30957.0  Mar 14 2018 03:11:00  4507016139 1
# 2                            1157.0  Mar 14 2018 03:11:00  4507016139 1
# 3                            2386.0  Mar 14 2018 03:11:00  4507016139 1
# 4                              72.0  Mar 14 2018 03:11:00  4507016139 1
# 5                              72.0  Mar 14 2018 03:11:00  4507016139 1
# 6                              72.0  Mar 14 2018 03:11:00  4507016139 1
# 7                              72.0  Mar 14 2018 03:11:00  4507016139 1
# 8                              72.0  Mar 14 2018 03:11:00  4507016139 1
# 9                              72.0  Mar 14 2018 03:11:00  4507016139 1
# 10                             72.0  Mar 14 2018 03:11:00  4507016139 1
# 11                          21699.0  Mar 14 2018 03:13:00  4507016139 1
# 12                            144.0  Mar 14 2018 03:13:00  4507016139 1
# 13                             72.0  Mar 14 2018 03:13:00  4507016139 1
# 14                             72.0  Mar 14 2018 03:13:00  4507016139 1
# 15                             72.0  Mar 14 2018 03:14:00  4507016139 1
# 16                             72.0  Mar 14 2018 03:14:00  4507016139 1
# 17                             72.0  Mar 14 2018 03:15:00  4507016139 1
# 18                          19239.0  Mar 14 2018 03:15:00  4507016139 1
# 19                          17937.0  Mar 14 2018 03:16:00  4507016139 1
#
# [20 rows x 21 columns]

# %%
#review changes on the last column
event_log_table
# Out:
#             eventID  case Spend area text case Document Type  \
# 0       2.270000e+14            Logistics        Standard PO
# 1       2.270000e+14            Logistics        Standard PO
# 2       2.270000e+14            Logistics        Standard PO
# 3       2.270000e+14            Logistics        Standard PO
# 4       2.270000e+14            Logistics        Standard PO
# ...              ...                  ...                ...
# 349521  4.690000e+14            Logistics        Standard PO
# 349522  4.690000e+14            Logistics        Standard PO
# 349523  4.690000e+14            Logistics        Standard PO
# 349524  4.690000e+14            Logistics        Standard PO
# 349525  4.690000e+14            Logistics        Standard PO
#
#         case Sub spend area text case Purch. Doc. Category name  \
# 0                    Road Packed                 Purchase order
# 1                    Road Packed                 Purchase order
# 2                    Road Packed                 Purchase order
# 3                    Road Packed                 Purchase order
# 4                    Road Packed                 Purchase order
# ...                          ...                            ...
# 349521  Other Logistics Services                 Purchase order
# 349522  Other Logistics Services                 Purchase order
# 349523  Other Logistics Services                 Purchase order
# 349524  Other Logistics Services                 Purchase order
# 349525  Other Logistics Services                 Purchase order
#
#           case Vendor case Item Type                 case Item Category  \
# 0       vendorID_0472        Service  Three way match, invoice after GR
# 1       vendorID_0472        Service  Three way match, invoice after GR
# 2       vendorID_0472        Service  Three way match, invoice after GR
# 3       vendorID_0472        Service  Three way match, invoice after GR
# 4       vendorID_0472        Service  Three way match, invoice after GR
# ...               ...            ...                                ...
# 349521  vendorID_0230        Service  Three way match, invoice after GR
# 349522  vendorID_0230        Service  Three way match, invoice after GR
# 349523  vendorID_0230        Service  Three way match, invoice after GR
# 349524  vendorID_0230        Service  Three way match, invoice after GR
# 349525  vendorID_0230        Service  Three way match, invoice after GR
#
#        case Spend classification text          case Source  ...  \
# 0                                 NPR  sourceSystemID_0000  ...
# 1                                 NPR  sourceSystemID_0000  ...
# 2                                 NPR  sourceSystemID_0000  ...
# 3                                 NPR  sourceSystemID_0000  ...
# 4                                 NPR  sourceSystemID_0000  ...
# ...                               ...                  ...  ...
# 349521                            NPR  sourceSystemID_0000  ...
# 349522                            NPR  sourceSystemID_0000  ...
# 349523                            NPR  sourceSystemID_0000  ...
# 349524                            NPR  sourceSystemID_0000  ...
# 349525                            NPR  sourceSystemID_0000  ...
#
#        case GR-Based Inv. Verif.  case Item  case concept:name  \
# 0                              1          1   4507016139_00001
# 1                              1          1   4507016139_00001
# 2                              1          1   4507016139_00001
# 3                              1          1   4507016139_00001
# 4                              1          1   4507016139_00001
# ...                          ...        ...                ...
# 349521                         1          1   4507032138_00001
# 349522                         1          1   4507032138_00001
# 349523                         1          1   4507032138_00001
# 349524                         1          1   4507032138_00001
# 349525                         1          1   4507032138_00001
#
#        case Goods Receipt event User event org:resource  \
# 0                    True        NaN                NaN
# 1                    True   batch_07           batch_07
# 2                    True   batch_07           batch_07
# 3                    True   batch_07           batch_07
# 4                    True        NaN                NaN
# ...                   ...        ...                ...
# 349521               True        NaN                NaN
# 349522               True        NaN                NaN
# 349523               True        NaN                NaN
# 349524               True        NaN                NaN
# 349525               True        NaN                NaN
#
#                 event concept:name event Cumulative net worth (EUR)  \
# 0       Record Service Entry Sheet                             72.0
# 1             Record Goods Receipt                          30957.0
# 2             Record Goods Receipt                           1157.0
# 3             Record Goods Receipt                           2386.0
# 4       Record Service Entry Sheet                             72.0
# ...                            ...                              ...
# 349521  Record Service Entry Sheet                             13.0
# 349522  Record Service Entry Sheet                             13.0
# 349523  Record Service Entry Sheet                             13.0
# 349524  Record Service Entry Sheet                             13.0
# 349525  Record Service Entry Sheet                             13.0
#
#         event time:timestamp        caseID
# 0       Mar 14 2018 03:11:00  4507016139 1
# 1       Mar 14 2018 03:11:00  4507016139 1
# 2       Mar 14 2018 03:11:00  4507016139 1
# 3       Mar 14 2018 03:11:00  4507016139 1
# 4       Mar 14 2018 03:11:00  4507016139 1
# ...                      ...           ...
# 349521  May 29 2018 00:53:00  4507032138 1
# 349522  May 29 2018 00:53:00  4507032138 1
# 349523  May 29 2018 00:53:00  4507032138 1
# 349524  May 29 2018 00:53:00  4507032138 1
# 349525  May 29 2018 00:53:00  4507032138 1
#
# [349526 rows x 21 columns]

# %%
#Review all og the event log columns, to decide which ones are mandatory and which ones are additional

log_columns = event_log_table.columns
log_columns # this variable is important for the Meta-DataFrame generation
# Out:
# Index(['eventID ', 'case Spend area text', 'case Document Type',
#        'case Sub spend area text', 'case Purch. Doc. Category name',
#        'case Vendor', 'case Item Type', 'case Item Category',
#        'case Spend classification text', 'case Source', 'case Name',
#        'case GR-Based Inv. Verif.', 'case Item', 'case concept:name',
#        'case Goods Receipt', 'event User', 'event org:resource',
#        'event concept:name', 'event Cumulative net worth (EUR)',
#        'event time:timestamp', 'caseID'],
#       dtype='object')

# %%
# This has to be tailored to each event log
#caseID is created from 'C_Purchasing Document' and 'case Item', define the mandatory columns based on domain knowledge analysis

mandatory_columns = ['caseID', 'event time:timestamp', 'event concept:name', 'eventID ']

#Create an object/dictionary and corresponding key:value pairs to add the semantic titles which the csv titles represent in a variable  which are relevant for the Meta-DataFrame
titles = {
  'caseID': 'Case ID',
  'event concept:name': 'Activity',
  'event_ID ': 'Event ID',
  'event time:timestamp': 'Timestamp',
}

print(mandatory_columns)
# Out:
# ['caseID', 'event time:timestamp', 'event concept:name', 'eventID ']

# %%
#Review titles object which are relevant for the Meta-DataFrame
titles
# Out:
# {'caseID': 'Case ID',
#  'event concept:name': 'Activity',
#  'event_ID ': 'Event ID',
#  'event time:timestamp': 'Timestamp'}

# %%
#Review the datatypes for datatype harmonization
event_log_table.dtypes
# Out:
# eventID                             float64
# case Spend area text                 object
# case Document Type                   object
# case Sub spend area text             object
# case Purch. Doc. Category name       object
# case Vendor                          object
# case Item Type                       object
# case Item Category                   object
# case Spend classification text       object
# case Source                          object
# case Name                            object
# case GR-Based Inv. Verif.             int64
# case Item                             int64
# case concept:name                    object
# case Goods Receipt                   object
# event User                           object
# event org:resource                   object
# event concept:name                   object
# event Cumulative net worth (EUR)    float64
# event time:timestamp                 object
# caseID                               object
# dtype: object

# %%
#This step is optional to minimize the work needed in harmonization

#Translate object data types of timestamp data into a datetime64[ns] data type for the timestamp. This is a unique datatype from pandas.
timestamp_objects = event_log_table['event time:timestamp'] #declare timestamp to a variable
event_log_table['event time:timestamp']=pd.to_datetime(timestamp_objects)

#Review changes made
#event_log_table['event time:timestamp'].dtypes
event_log_table.dtypes
# Out:
# eventID                                    float64
# case Spend area text                        object
# case Document Type                          object
# case Sub spend area text                    object
# case Purch. Doc. Category name              object
# case Vendor                                 object
# case Item Type                              object
# case Item Category                          object
# case Spend classification text              object
# case Source                                 object
# case Name                                   object
# case GR-Based Inv. Verif.                    int64
# case Item                                    int64
# case concept:name                           object
# case Goods Receipt                          object
# event User                                  object
# event org:resource                          object
# event concept:name                          object
# event Cumulative net worth (EUR)           float64
# event time:timestamp                datetime64[ns]
# caseID                                      object
# dtype: object

# %%
#This step is optional to minimize the work needed in harmonization 

#Translate object data types of object data types (which contains different possible formats) to a clear string data type format
#for loops where used as they enable somewhat automated transformations 
# = for assigning values
# == operator is used to test equality
for log_column in log_columns:
    if event_log_table[log_column].dtype == 'object': #check if the column has an object data type
        event_log_table[log_column] = event_log_table[log_column].astype('string') #change it to a string

#Review changes
#event_log_table['timestamp'].dtypes
event_log_table.dtypes
# Out:
# eventID                                    float64
# case Spend area text                        string
# case Document Type                          string
# case Sub spend area text                    string
# case Purch. Doc. Category name              string
# case Vendor                                 string
# case Item Type                              string
# case Item Category                          string
# case Spend classification text              string
# case Source                                 string
# case Name                                   string
# case GR-Based Inv. Verif.                    int64
# case Item                                    int64
# case concept:name                           string
# case Goods Receipt                          string
# event User                                  string
# event org:resource                          string
# event concept:name                          string
# event Cumulative net worth (EUR)           float64
# event time:timestamp                datetime64[ns]
# caseID                                      string
# dtype: object

# %%
# Reorder the columns of the event log table.
# Checking the log columns list contains each item on the mandatory columns list with the assert statement raises an 'AssertionError' if any of the elements are missing. 
# With the delete method and the == operator, the items are removed in the mandatory columns list from the log columns list.
# Then  using the + operator to combine the mandatory columns list and the log columns list (which has been turned into a list using the tolist method). By doing so, a fresh list of columns in # the desired order is created. Using the [] operator to select only the columns in the newly created list, subsetting the event log table DataFrame. By doing this, the columns in the new #DataFrame are created in the desired order.

for mandatory_column in mandatory_columns:
  assert mandatory_column in log_columns 
  log_columns = log_columns.delete(log_columns == mandatory_column)
log_columns = mandatory_columns + log_columns.tolist()

event_log_table = event_log_table[log_columns]
event_log_table #the for loop above resultes in a move of the mandatory columns to the left side (changes order)
# Out:
#               caseID event time:timestamp          event concept:name  \
# 0       4507016139 1  2018-03-14 03:11:00  Record Service Entry Sheet
# 1       4507016139 1  2018-03-14 03:11:00        Record Goods Receipt
# 2       4507016139 1  2018-03-14 03:11:00        Record Goods Receipt
# 3       4507016139 1  2018-03-14 03:11:00        Record Goods Receipt
# 4       4507016139 1  2018-03-14 03:11:00  Record Service Entry Sheet
# ...              ...                  ...                         ...
# 349521  4507032138 1  2018-05-29 00:53:00  Record Service Entry Sheet
# 349522  4507032138 1  2018-05-29 00:53:00  Record Service Entry Sheet
# 349523  4507032138 1  2018-05-29 00:53:00  Record Service Entry Sheet
# 349524  4507032138 1  2018-05-29 00:53:00  Record Service Entry Sheet
# 349525  4507032138 1  2018-05-29 00:53:00  Record Service Entry Sheet
#
#             eventID  case Spend area text case Document Type  \
# 0       2.270000e+14            Logistics        Standard PO
# 1       2.270000e+14            Logistics        Standard PO
# 2       2.270000e+14            Logistics        Standard PO
# 3       2.270000e+14            Logistics        Standard PO
# 4       2.270000e+14            Logistics        Standard PO
# ...              ...                  ...                ...
# 349521  4.690000e+14            Logistics        Standard PO
# 349522  4.690000e+14            Logistics        Standard PO
# 349523  4.690000e+14            Logistics        Standard PO
# 349524  4.690000e+14            Logistics        Standard PO
# 349525  4.690000e+14            Logistics        Standard PO
#
#         case Sub spend area text case Purch. Doc. Category name  \
# 0                    Road Packed                 Purchase order
# 1                    Road Packed                 Purchase order
# 2                    Road Packed                 Purchase order
# 3                    Road Packed                 Purchase order
# 4                    Road Packed                 Purchase order
# ...                          ...                            ...
# 349521  Other Logistics Services                 Purchase order
# 349522  Other Logistics Services                 Purchase order
# 349523  Other Logistics Services                 Purchase order
# 349524  Other Logistics Services                 Purchase order
# 349525  Other Logistics Services                 Purchase order
#
#           case Vendor case Item Type  ... case Spend classification text  \
# 0       vendorID_0472        Service  ...                            NPR
# 1       vendorID_0472        Service  ...                            NPR
# 2       vendorID_0472        Service  ...                            NPR
# 3       vendorID_0472        Service  ...                            NPR
# 4       vendorID_0472        Service  ...                            NPR
# ...               ...            ...  ...                            ...
# 349521  vendorID_0230        Service  ...                            NPR
# 349522  vendorID_0230        Service  ...                            NPR
# 349523  vendorID_0230        Service  ...                            NPR
# 349524  vendorID_0230        Service  ...                            NPR
# 349525  vendorID_0230        Service  ...                            NPR
#
#                 case Source    case Name case GR-Based Inv. Verif.  case Item  \
# 0       sourceSystemID_0000  vendor_0457                         1          1
# 1       sourceSystemID_0000  vendor_0457                         1          1
# 2       sourceSystemID_0000  vendor_0457                         1          1
# 3       sourceSystemID_0000  vendor_0457                         1          1
# 4       sourceSystemID_0000  vendor_0457                         1          1
# ...                     ...          ...                       ...        ...
# 349521  sourceSystemID_0000  vendor_0225                         1          1
# 349522  sourceSystemID_0000  vendor_0225                         1          1
# 349523  sourceSystemID_0000  vendor_0225                         1          1
# 349524  sourceSystemID_0000  vendor_0225                         1          1
# 349525  sourceSystemID_0000  vendor_0225                         1          1
#
#         case concept:name case Goods Receipt event User event org:resource  \
# 0        4507016139_00001               True       <NA>               <NA>
# 1        4507016139_00001               True   batch_07           batch_07
# 2        4507016139_00001               True   batch_07           batch_07
# 3        4507016139_00001               True   batch_07           batch_07
# 4        4507016139_00001               True       <NA>               <NA>
# ...                   ...                ...        ...                ...
# 349521   4507032138_00001               True       <NA>               <NA>
# 349522   4507032138_00001               True       <NA>               <NA>
# 349523   4507032138_00001               True       <NA>               <NA>
# 349524   4507032138_00001               True       <NA>               <NA>
# 349525   4507032138_00001               True       <NA>               <NA>
#
#        event Cumulative net worth (EUR)
# 0                                  72.0
# 1                               30957.0
# 2                                1157.0
# 3                                2386.0
# 4                                  72.0
# ...                                 ...
# 349521                             13.0
# 349522                             13.0
# 349523                             13.0
# 349524                             13.0
# 349525                             13.0
#
# [349526 rows x 21 columns]

# %% [markdown]
# Here we are going to reset the index and reorder the event log with a new index
#
# Setting the inplace parameter to True and using the reset index method to reset the DataFrame's index.
# This adds a new column to the DataFrame containing the old index values and resets the index to a range of sequential integers beginning at 0.
# Using the rename method and the inplace parameter set to True, rename the column containing the previous index values.
# A dictionary that maps the old column name "index" to the new column name "EventIndex" makes up the columns parameter.
# Using the set index method and the inplace parameter set to True, the DataFrame's index is changed to the 'EventIndex' column.
# This will remove the "EventIndex" column from the data and make it the new index of the DataFrame.

# %%
# Number every single event in the event log.
# Every single event is represented by a line in the event log file.
event_log_table.reset_index(inplace=True)
event_log_table.rename(columns={'index': 'EventIndex'}, inplace=True)
event_log_table.set_index('EventIndex', inplace=True)

#review changes
event_log_table
# Out:
# /var/folders/vz/snd73j8d2mj817493bt9ykfc0000gn/T/ipykernel_63845/2322881527.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   event_log_table.rename(columns={'index': 'EventIndex'}, inplace=True)
#                   caseID event time:timestamp          event concept:name  \
# EventIndex
# 0           4507016139 1  2018-03-14 03:11:00  Record Service Entry Sheet
# 1           4507016139 1  2018-03-14 03:11:00        Record Goods Receipt
# 2           4507016139 1  2018-03-14 03:11:00        Record Goods Receipt
# 3           4507016139 1  2018-03-14 03:11:00        Record Goods Receipt
# 4           4507016139 1  2018-03-14 03:11:00  Record Service Entry Sheet
# ...                  ...                  ...                         ...
# 349521      4507032138 1  2018-05-29 00:53:00  Record Service Entry Sheet
# 349522      4507032138 1  2018-05-29 00:53:00  Record Service Entry Sheet
# 349523      4507032138 1  2018-05-29 00:53:00  Record Service Entry Sheet
# 349524      4507032138 1  2018-05-29 00:53:00  Record Service Entry Sheet
# 349525      4507032138 1  2018-05-29 00:53:00  Record Service Entry Sheet
#
#                 eventID  case Spend area text case Document Type  \
# EventIndex
# 0           2.270000e+14            Logistics        Standard PO
# 1           2.270000e+14            Logistics        Standard PO
# 2           2.270000e+14            Logistics        Standard PO
# 3           2.270000e+14            Logistics        Standard PO
# 4           2.270000e+14            Logistics        Standard PO
# ...                  ...                  ...                ...
# 349521      4.690000e+14            Logistics        Standard PO
# 349522      4.690000e+14            Logistics        Standard PO
# 349523      4.690000e+14            Logistics        Standard PO
# 349524      4.690000e+14            Logistics        Standard PO
# 349525      4.690000e+14            Logistics        Standard PO
#
#             case Sub spend area text case Purch. Doc. Category name  \
# EventIndex
# 0                        Road Packed                 Purchase order
# 1                        Road Packed                 Purchase order
# 2                        Road Packed                 Purchase order
# 3                        Road Packed                 Purchase order
# 4                        Road Packed                 Purchase order
# ...                              ...                            ...
# 349521      Other Logistics Services                 Purchase order
# 349522      Other Logistics Services                 Purchase order
# 349523      Other Logistics Services                 Purchase order
# 349524      Other Logistics Services                 Purchase order
# 349525      Other Logistics Services                 Purchase order
#
#               case Vendor case Item Type  ... case Spend classification text  \
# EventIndex                                ...
# 0           vendorID_0472        Service  ...                            NPR
# 1           vendorID_0472        Service  ...                            NPR
# 2           vendorID_0472        Service  ...                            NPR
# 3           vendorID_0472        Service  ...                            NPR
# 4           vendorID_0472        Service  ...                            NPR
# ...                   ...            ...  ...                            ...
# 349521      vendorID_0230        Service  ...                            NPR
# 349522      vendorID_0230        Service  ...                            NPR
# 349523      vendorID_0230        Service  ...                            NPR
# 349524      vendorID_0230        Service  ...                            NPR
# 349525      vendorID_0230        Service  ...                            NPR
#
#                     case Source    case Name case GR-Based Inv. Verif.  \
# EventIndex
# 0           sourceSystemID_0000  vendor_0457                         1
# 1           sourceSystemID_0000  vendor_0457                         1
# 2           sourceSystemID_0000  vendor_0457                         1
# 3           sourceSystemID_0000  vendor_0457                         1
# 4           sourceSystemID_0000  vendor_0457                         1
# ...                         ...          ...                       ...
# 349521      sourceSystemID_0000  vendor_0225                         1
# 349522      sourceSystemID_0000  vendor_0225                         1
# 349523      sourceSystemID_0000  vendor_0225                         1
# 349524      sourceSystemID_0000  vendor_0225                         1
# 349525      sourceSystemID_0000  vendor_0225                         1
#
#             case Item  case concept:name case Goods Receipt event User  \
# EventIndex
# 0                   1   4507016139_00001               True       <NA>
# 1                   1   4507016139_00001               True   batch_07
# 2                   1   4507016139_00001               True   batch_07
# 3                   1   4507016139_00001               True   batch_07
# 4                   1   4507016139_00001               True       <NA>
# ...               ...                ...                ...        ...
# 349521              1   4507032138_00001               True       <NA>
# 349522              1   4507032138_00001               True       <NA>
# 349523              1   4507032138_00001               True       <NA>
# 349524              1   4507032138_00001               True       <NA>
# 349525              1   4507032138_00001               True       <NA>
#
#            event org:resource event Cumulative net worth (EUR)
# EventIndex
# 0                        <NA>                             72.0
# 1                    batch_07                          30957.0
# 2                    batch_07                           1157.0
# 3                    batch_07                           2386.0
# 4                        <NA>                             72.0
# ...                       ...                              ...
# 349521                   <NA>                             13.0
# 349522                   <NA>                             13.0
# 349523                   <NA>                             13.0
# 349524                   <NA>                             13.0
# 349525                   <NA>                             13.0
#
# [349526 rows x 21 columns]

# %%
#defining a new dictionary  overview_columns with log columns as the elements
content_overview_columns = [(log_column, ['Supplier2_Comparative_Mining']) for log_column in log_columns]
extra_overview_columns = [('Event log column property', ['Supplier2_Comparative_Mining'])]
overview_columns = dict(extra_overview_columns + content_overview_columns)
overview_table = pd.DataFrame(overview_columns)

# To add a vertically indented name to the index in the console output.
overview_table.set_index('Event log column property', inplace=True)
overview_columns
# Out:
# {'Event log column property': ['Supplier2_Comparative_Mining'],
#  'caseID': ['Supplier2_Comparative_Mining'],
#  'event time:timestamp': ['Supplier2_Comparative_Mining'],
#  'event concept:name': ['Supplier2_Comparative_Mining'],
#  'eventID ': ['Supplier2_Comparative_Mining'],
#  'case Spend area text': ['Supplier2_Comparative_Mining'],
#  'case Document Type': ['Supplier2_Comparative_Mining'],
#  'case Sub spend area text': ['Supplier2_Comparative_Mining'],
#  'case Purch. Doc. Category name': ['Supplier2_Comparative_Mining'],
#  'case Vendor': ['Supplier2_Comparative_Mining'],
#  'case Item Type': ['Supplier2_Comparative_Mining'],
#  'case Item Category': ['Supplier2_Comparative_Mining'],
#  'case Spend classification text': ['Supplier2_Comparative_Mining'],
#  'case Source': ['Supplier2_Comparative_Mining'],
#  'case Name': ['Supplier2_Comparative_Mining'],
#  'case GR-Based Inv. Verif.': ['Supplier2_Comparative_Mining'],
#  'case Item': ['Supplier2_Comparative_Mining'],
#  'case concept:name': ['Supplier2_Comparative_Mining'],
#  'case Goods Receipt': ['Supplier2_Comparative_Mining'],
#  'event User': ['Supplier2_Comparative_Mining'],
#  'event org:resource': ['Supplier2_Comparative_Mining'],
#  'event Cumulative net worth (EUR)': ['Supplier2_Comparative_Mining']}

# %%
#view the new overview_table to construct the Meta-DataFrame
overview_table
# Out:
#                                                     caseID  \
# Event log column property
# Supplier2_Comparative_Mining  Supplier2_Comparative_Mining
#
#                                       event time:timestamp  \
# Event log column property
# Supplier2_Comparative_Mining  Supplier2_Comparative_Mining
#
#                                         event concept:name  \
# Event log column property
# Supplier2_Comparative_Mining  Supplier2_Comparative_Mining
#
#                                                   eventID   \
# Event log column property
# Supplier2_Comparative_Mining  Supplier2_Comparative_Mining
#
#                                       case Spend area text  \
# Event log column property
# Supplier2_Comparative_Mining  Supplier2_Comparative_Mining
#
#                                         case Document Type  \
# Event log column property
# Supplier2_Comparative_Mining  Supplier2_Comparative_Mining
#
#                                   case Sub spend area text  \
# Event log column property
# Supplier2_Comparative_Mining  Supplier2_Comparative_Mining
#
#                              case Purch. Doc. Category name  \
# Event log column property
# Supplier2_Comparative_Mining   Supplier2_Comparative_Mining
#
#                                                case Vendor  \
# Event log column property
# Supplier2_Comparative_Mining  Supplier2_Comparative_Mining
#
#                                             case Item Type  ...  \
# Event log column property                                   ...
# Supplier2_Comparative_Mining  Supplier2_Comparative_Mining  ...
#
#                              case Spend classification text  \
# Event log column property
# Supplier2_Comparative_Mining   Supplier2_Comparative_Mining
#
#                                                case Source  \
# Event log column property
# Supplier2_Comparative_Mining  Supplier2_Comparative_Mining
#
#                                                  case Name  \
# Event log column property
# Supplier2_Comparative_Mining  Supplier2_Comparative_Mining
#
#                                  case GR-Based Inv. Verif.  \
# Event log column property
# Supplier2_Comparative_Mining  Supplier2_Comparative_Mining
#
#                                                  case Item  \
# Event log column property
# Supplier2_Comparative_Mining  Supplier2_Comparative_Mining
#
#                                          case concept:name  \
# Event log column property
# Supplier2_Comparative_Mining  Supplier2_Comparative_Mining
#
#                                         case Goods Receipt  \
# Event log column property
# Supplier2_Comparative_Mining  Supplier2_Comparative_Mining
#
#                                                 event User  \
# Event log column property
# Supplier2_Comparative_Mining  Supplier2_Comparative_Mining
#
#                                         event org:resource  \
# Event log column property
# Supplier2_Comparative_Mining  Supplier2_Comparative_Mining
#
#                              event Cumulative net worth (EUR)
# Event log column property
# Supplier2_Comparative_Mining     Supplier2_Comparative_Mining
#
# [1 rows x 21 columns]

# %% [markdown]
# <h2>Multiple variables based on event data proprocessing which are used for the Meta-DataFrame</h2>
#
# The author uses the pandas .loc function which is an indexer in Pandas is used to choose rows and columns from a DataFrame based on labels.
#
# The snippet below is called title property X as it will be added to the overview table (Meta-DataFrame) with the log columns list's elements as keys and the log column itself as a value, if the title associated with the log column is present in the titles dictionary (if it does not exist in the titles dictionary).
#
# Then, a new row with the label "Title" and the values from the title property dictionary is added to the overview table DataFrame. The assignment will add the new row to the DataFrame, and the.loc indexer will be used to select the row by its label.
#
# When this code block is run, a new row with the label "Title" and values representing the names of each log column will appear in the overview table DataFrame (or the log column itself if no title is provided).

# %%
# Overview for property: Titles - For the Meta-DataFrame
# Depending on whether the title for the log column is present in the titles dictionary, the values of the log columns list are either the log column itself or its associated title (if it does not exist in the titles dictionary).
title_property = {}

for log_column in log_columns:
    if log_column in titles:
        title = titles[log_column]
    else:
        title = log_column
    title_property[log_column] = title

# %% [markdown]
# Then, a new row with the label "Title" and the values from the title property dictionary is added to the overview table DataFrame. The assignment will add the new row to the DataFrame, and the.loc indexer will be used to select the row by its label.
# When this code block is run, a new row with the label "Title" and values representing the names of each log column will appear in the overview table DataFrame (or the log column itself if no title is provided).

# %%
overview_table.loc['Title'] = title_property
overview_table.loc['Title']
# Out:
# caseID                                                       Case ID
# event time:timestamp                                       Timestamp
# event concept:name                                          Activity
# eventID                                                     eventID
# case Spend area text                            case Spend area text
# case Document Type                                case Document Type
# case Sub spend area text                    case Sub spend area text
# case Purch. Doc. Category name        case Purch. Doc. Category name
# case Vendor                                              case Vendor
# case Item Type                                        case Item Type
# case Item Category                                case Item Category
# case Spend classification text        case Spend classification text
# case Source                                              case Source
# case Name                                                  case Name
# case GR-Based Inv. Verif.                  case GR-Based Inv. Verif.
# case Item                                                  case Item
# case concept:name                                  case concept:name
# case Goods Receipt                                case Goods Receipt
# event User                                                event User
# event org:resource                                event org:resource
# event Cumulative net worth (EUR)    event Cumulative net worth (EUR)
# Name: Title, dtype: object

# %% [markdown]
# <h2>Dictionary {for mandatory and additional attributes}</h2>
#
# This code block generates a new dictionary called importance property whose keys are the items in the list of log columns and whose values are either "Mandatory attribute" or "Additional attribute" depending on whether the log column is included in the mandatory columns list or not.
# Then, a new row with the label "Importance" and values taken from the importance property dictionary is added to the overview table DataFrame. The assignment will add the new row to the DataFrame, and the.loc indexer will be used to select the row by its label.
# When this code block is run, a new row with the label "Importance" and the values "Mandatory attribute" or "Additional attribute" for each log column, depending on whether that column is in the mandatory columns list or not, will appear in the overview table DataFrame.
#
# The concept is used for other data attributes as well

# %%
# Overview property: Label for columns either 'Mandatory attribute' or 'additional_attributes' - For the Meta-DataFrame

importance_property = {}
for log_column in log_columns:
    if log_column in mandatory_columns:
        importance_property[log_column] = 'Mandatory attribute' 
    else:
        importance_property[log_column] = 'Additional attribute'

overview_table.loc['Importance'] = importance_property
overview_table.loc['Importance']
# Out:
# caseID                               Mandatory attribute
# event time:timestamp                 Mandatory attribute
# event concept:name                   Mandatory attribute
# eventID                              Mandatory attribute
# case Spend area text                Additional attribute
# case Document Type                  Additional attribute
# case Sub spend area text            Additional attribute
# case Purch. Doc. Category name      Additional attribute
# case Vendor                         Additional attribute
# case Item Type                      Additional attribute
# case Item Category                  Additional attribute
# case Spend classification text      Additional attribute
# case Source                         Additional attribute
# case Name                           Additional attribute
# case GR-Based Inv. Verif.           Additional attribute
# case Item                           Additional attribute
# case concept:name                   Additional attribute
# case Goods Receipt                  Additional attribute
# event User                          Additional attribute
# event org:resource                  Additional attribute
# event Cumulative net worth (EUR)    Additional attribute
# Name: Importance, dtype: object

# %% [markdown]
# The goal of this code snippet is to add a new row to the Meta-Dataframe termed overview table, where the keys are the columns in a list called log columns and the values are strings indicating whether the column is at the "Event level" or the "Case level." The values are determined by examining the column name for the string "event" or "case," respectively.

# %%
# Overview property: The level of the event data attribute in the overview table
level_property = {}
for log_column in log_columns:
  if 'event' in log_column:
    level_property[log_column] = 'Event level'
  if 'case' in log_column:
    level_property[log_column] = 'Case level'

overview_table.loc['Level'] = level_property
overview_table.loc['Level']

#NaN's can manually be changed in the Meta-DataFrame
# Out:
# caseID                               Case level
# event time:timestamp                Event level
# event concept:name                  Event level
# eventID                             Event level
# case Spend area text                 Case level
# case Document Type                   Case level
# case Sub spend area text             Case level
# case Purch. Doc. Category name       Case level
# case Vendor                          Case level
# case Item Type                       Case level
# case Item Category                   Case level
# case Spend classification text       Case level
# case Source                          Case level
# case Name                            Case level
# case GR-Based Inv. Verif.            Case level
# case Item                            Case level
# case concept:name                    Case level
# case Goods Receipt                   Case level
# event User                          Event level
# event org:resource                  Event level
# event Cumulative net worth (EUR)    Event level
# Name: Level, dtype: object

# %%
# Overview property: Data type
data_type_property = {}
datatypes = event_log_table.dtypes
for log_column in log_columns:
  data_type_property[log_column] = datatypes[log_column]

overview_table.loc['Data type'] = data_type_property

# %% [markdown]
# This snippet adds a new row to the Meta-Dataframe in Pandas, with the keys being the columns in a list called log columns and the values being the data types of the corresponding columns in an event log table DataFrame.

# %%
# Overview property: Data type
data_type_property = {}
datatypes = event_log_table.dtypes
for log_column in log_columns:
    data_type_property[log_column] = datatypes[log_column]

overview_table.loc['Data type'] = data_type_property
overview_table.loc['Data type']
# Out:
# caseID                                      string
# event time:timestamp                datetime64[ns]
# event concept:name                          string
# eventID                                    float64
# case Spend area text                        string
# case Document Type                          string
# case Sub spend area text                    string
# case Purch. Doc. Category name              string
# case Vendor                                 string
# case Item Type                              string
# case Item Category                          string
# case Spend classification text              string
# case Source                                 string
# case Name                                   string
# case GR-Based Inv. Verif.                    int64
# case Item                                    int64
# case concept:name                           string
# case Goods Receipt                          string
# event User                                  string
# event org:resource                          string
# event Cumulative net worth (EUR)           float64
# Name: Data type, dtype: object

# %%
# Overview property: Count the number of entries for the Meta-Dataframe
number_of_entries_property = {}
for log_column in log_columns:
    number_of_entries_property[log_column] = len(event_log_table)

overview_table.loc['Number of entries'] = number_of_entries_property
overview_table.loc['Number of entries']
# Out:
# caseID                              349526
# event time:timestamp                349526
# event concept:name                  349526
# eventID                             349526
# case Spend area text                349526
# case Document Type                  349526
# case Sub spend area text            349526
# case Purch. Doc. Category name      349526
# case Vendor                         349526
# case Item Type                      349526
# case Item Category                  349526
# case Spend classification text      349526
# case Source                         349526
# case Name                           349526
# case GR-Based Inv. Verif.           349526
# case Item                           349526
# case concept:name                   349526
# case Goods Receipt                  349526
# event User                          349526
# event org:resource                  349526
# event Cumulative net worth (EUR)    349526
# Name: Number of entries, dtype: object

# %%
# Overview property: Number of unique entries
number_of_unique_entries_property = {}
for log_column in log_columns:
  count = event_log_table[log_column].value_counts().count()
  number_of_unique_entries_property[log_column] = count

overview_table.loc['Number of unique entries'] = number_of_unique_entries_property
overview_table.loc['Number of unique entries']
# Out:
# caseID                              56127
# event time:timestamp                42173
# event concept:name                     28
# eventID                               243
# case Spend area text                   18
# case Document Type                      2
# case Sub spend area text              109
# case Purch. Doc. Category name          1
# case Vendor                          1109
# case Item Type                          5
# case Item Category                      3
# case Spend classification text          4
# case Source                             1
# case Name                            1050
# case GR-Based Inv. Verif.               2
# case Item                             233
# case concept:name                   53733
# case Goods Receipt                      1
# event User                            333
# event org:resource                    333
# event Cumulative net worth (EUR)    11330
# Name: Number of unique entries, dtype: object

# %%
#Overview property: List of up to 100 unique entries (to grasp an understanding of how the data looks and it is structured and not just metrics)
unique_entries_property = {}
for log_column in log_columns:
    unique_entries = event_log_table[log_column].unique()
    unique_entries = list(unique_entries)
    unique_entries = unique_entries[:100]
    unique_entries_property[log_column] = unique_entries

overview_table.loc['List up to 100 unique entries to view the structure of the event attributes']= unique_entries_property
unique_entries_property
# Out:
# {'caseID': ['4507016139 1',
#   '4507016140 10',
#   '4507016140 20',
#   '4507016140 30',
#   '4507016141 10',
#   '4507016141 100',
#   '4507016141 20',
#   '4507016141 30',
#   '4507016141 40',
#   '4507016141 50',
#   '4507016141 60',
#   '4507016141 70',
#   '4507016141 80',
#   '4507016141 90',
#   '4507016142 10',
#   '4507016143 10',
#   '4507016143 20',
#   '4507016143 30',
#   '4507016143 40',
#   '4507016144 10',
#   '4507016144 20',
#   '4507016144 30',
#   '4507016145 10',
#   '4507016145 20',
#   '4507016145 30',
#   '4507016145 40',
#   '4507016145 50',
#   '4507016146 10',
#   '4507016146 100',
#   '4507016146 110',
#   '4507016146 120',
#   '4507016146 130',
#   '4507016146 140',
#   '4507016146 20',
#   '4507016146 30',
#   '4507016146 40',
#   '4507016146 50',
#   '4507016146 60',
#   '4507016146 70',
#   '4507016146 80',
#   '4507016146 90',
#   '4507016147 10',
#   '4507016147 20',
#   '4507016148 10',
#   '4507016149 10',
#   '4507016149 100',
#   '4507016149 110',
#   '4507016149 120',
#   '4507016149 130',
#   '4507016149 140',
#   '4507016149 150',
#   '4507016149 160',
#   '4507016149 20',
#   '4507016149 30',
#   '4507016149 40',
#   '4507016149 50',
#   '4507016149 60',
#   '4507016149 70',
#   '4507016149 80',
#   '4507016149 90',
#   '4507016150 10',
#   '4507016150 20',
#   '4507016150 30',
#   '4507016150 40',
#   '4507016150 50',
#   '4507016150 60',
#   '4507016150 70',
#   '4507016151 10',
#   '4507016151 100',
#   '4507016151 20',
#   '4507016151 30',
#   '4507016151 40',
#   '4507016151 50',
#   '4507016151 60',
#   '4507016151 70',
#   '4507016151 80',
#   '4507016151 90',
#   '4507016152 10',
#   '4507016152 100',
#   '4507016152 110',
#   '4507016152 120',
#   '4507016152 130',
#   '4507016152 140',
#   '4507016152 150',
#   '4507016152 160',
#   '4507016152 20',
#   '4507016152 30',
#   '4507016152 40',
#   '4507016152 50',
#   '4507016152 60',
#   '4507016152 70',
#   '4507016152 80',
#   '4507016152 90',
#   '4507016153 10',
#   '4507016154 10',
#   '4507016154 20',
#   '4507016155 10',
#   '4507016155 100',
#   '4507016155 110',
#   '4507016155 120'],
#  'event time:timestamp': [numpy.datetime64('2018-03-14T03:11:00.000000000'),
#   numpy.datetime64('2018-03-14T03:13:00.000000000'),
#   numpy.datetime64('2018-03-14T03:14:00.000000000'),
#   numpy.datetime64('2018-03-14T03:15:00.000000000'),
#   numpy.datetime64('2018-03-14T03:16:00.000000000'),
#   numpy.datetime64('2018-03-14T03:17:00.000000000'),
#   numpy.datetime64('2018-03-14T05:33:00.000000000'),
#   numpy.datetime64('2018-03-14T09:03:00.000000000'),
#   numpy.datetime64('2018-03-16T08:35:00.000000000'),
#   numpy.datetime64('2018-03-20T00:59:00.000000000'),
#   numpy.datetime64('2018-03-20T10:13:00.000000000'),
#   numpy.datetime64('2018-04-26T13:14:00.000000000'),
#   numpy.datetime64('2018-03-20T07:05:00.000000000'),
#   numpy.datetime64('NaT'),
#   numpy.datetime64('2018-03-28T01:59:00.000000000'),
#   numpy.datetime64('2018-04-03T14:30:00.000000000'),
#   numpy.datetime64('2018-04-23T11:34:00.000000000'),
#   numpy.datetime64('2018-05-09T09:17:00.000000000'),
#   numpy.datetime64('2018-05-24T15:33:00.000000000'),
#   numpy.datetime64('2018-03-16T12:14:00.000000000'),
#   numpy.datetime64('2018-03-16T18:17:00.000000000'),
#   numpy.datetime64('2018-04-06T01:59:00.000000000'),
#   numpy.datetime64('2018-04-10T16:33:00.000000000'),
#   numpy.datetime64('2018-04-11T12:58:00.000000000'),
#   numpy.datetime64('2018-06-07T15:11:00.000000000'),
#   numpy.datetime64('2018-03-16T12:16:00.000000000'),
#   numpy.datetime64('2018-03-22T11:59:00.000000000'),
#   numpy.datetime64('2018-04-07T01:59:00.000000000'),
#   numpy.datetime64('2018-04-09T12:13:00.000000000'),
#   numpy.datetime64('2018-04-10T14:29:00.000000000'),
#   numpy.datetime64('2018-06-07T15:12:00.000000000'),
#   numpy.datetime64('2018-03-16T15:41:00.000000000'),
#   numpy.datetime64('2018-03-16T12:21:00.000000000'),
#   numpy.datetime64('2018-04-05T17:38:00.000000000'),
#   numpy.datetime64('2018-03-27T15:36:00.000000000'),
#   numpy.datetime64('2018-03-30T13:42:00.000000000'),
#   numpy.datetime64('2018-03-27T15:34:00.000000000'),
#   numpy.datetime64('2018-03-23T13:16:00.000000000'),
#   numpy.datetime64('2018-03-28T19:55:00.000000000'),
#   numpy.datetime64('2018-03-21T00:59:00.000000000'),
#   numpy.datetime64('2018-03-21T13:36:00.000000000'),
#   numpy.datetime64('2018-04-04T19:06:00.000000000'),
#   numpy.datetime64('2018-04-26T13:12:00.000000000'),
#   numpy.datetime64('2018-03-22T08:19:00.000000000'),
#   numpy.datetime64('2018-03-16T12:22:00.000000000'),
#   numpy.datetime64('2018-04-01T01:59:00.000000000'),
#   numpy.datetime64('2018-04-03T13:53:00.000000000'),
#   numpy.datetime64('2018-04-05T09:03:00.000000000'),
#   numpy.datetime64('2018-05-09T16:09:00.000000000'),
#   numpy.datetime64('2018-03-16T12:36:00.000000000'),
#   numpy.datetime64('2018-03-16T13:53:00.000000000'),
#   numpy.datetime64('2018-04-05T10:15:00.000000000'),
#   numpy.datetime64('2018-04-10T01:59:00.000000000'),
#   numpy.datetime64('2018-04-10T17:19:00.000000000'),
#   numpy.datetime64('2018-03-16T12:24:00.000000000'),
#   numpy.datetime64('2018-03-17T00:59:00.000000000'),
#   numpy.datetime64('2018-03-19T14:53:00.000000000'),
#   numpy.datetime64('2018-03-22T11:44:00.000000000'),
#   numpy.datetime64('2018-04-26T13:13:00.000000000'),
#   numpy.datetime64('2018-03-16T12:25:00.000000000'),
#   numpy.datetime64('2018-04-05T10:16:00.000000000'),
#   numpy.datetime64('2018-04-10T17:22:00.000000000'),
#   numpy.datetime64('2018-04-11T19:52:00.000000000'),
#   numpy.datetime64('2018-03-16T12:26:00.000000000'),
#   numpy.datetime64('2018-04-18T15:18:00.000000000'),
#   numpy.datetime64('2018-04-19T01:59:00.000000000'),
#   numpy.datetime64('2018-06-04T19:43:00.000000000'),
#   numpy.datetime64('2018-06-28T16:05:00.000000000'),
#   numpy.datetime64('2018-03-16T12:31:00.000000000'),
#   numpy.datetime64('2018-03-24T00:59:00.000000000'),
#   numpy.datetime64('2018-03-26T15:26:00.000000000'),
#   numpy.datetime64('2018-03-29T13:29:00.000000000'),
#   numpy.datetime64('2018-04-12T16:07:00.000000000'),
#   numpy.datetime64('2018-03-26T15:28:00.000000000'),
#   numpy.datetime64('2018-03-16T12:33:00.000000000'),
#   numpy.datetime64('2018-04-09T15:41:00.000000000'),
#   numpy.datetime64('2018-04-10T17:25:00.000000000'),
#   numpy.datetime64('2018-04-11T12:40:00.000000000'),
#   numpy.datetime64('2018-04-12T09:32:00.000000000'),
#   numpy.datetime64('2018-04-12T18:21:00.000000000'),
#   numpy.datetime64('2018-05-24T15:35:00.000000000'),
#   numpy.datetime64('2018-03-16T12:34:00.000000000'),
#   numpy.datetime64('2018-04-03T15:44:00.000000000'),
#   numpy.datetime64('2018-04-12T09:30:00.000000000'),
#   numpy.datetime64('2018-03-16T12:37:00.000000000'),
#   numpy.datetime64('2018-04-20T01:59:00.000000000'),
#   numpy.datetime64('2018-04-23T18:51:00.000000000'),
#   numpy.datetime64('2018-04-27T10:21:00.000000000'),
#   numpy.datetime64('2018-04-28T04:14:00.000000000'),
#   numpy.datetime64('2018-06-28T16:02:00.000000000'),
#   numpy.datetime64('2018-03-16T12:39:00.000000000'),
#   numpy.datetime64('2018-03-19T15:35:00.000000000'),
#   numpy.datetime64('2018-03-21T12:34:00.000000000'),
#   numpy.datetime64('2018-03-20T15:59:00.000000000'),
#   numpy.datetime64('2018-03-28T12:30:00.000000000'),
#   numpy.datetime64('2018-03-20T15:48:00.000000000'),
#   numpy.datetime64('2018-03-20T16:02:00.000000000'),
#   numpy.datetime64('2018-03-16T12:43:00.000000000'),
#   numpy.datetime64('2018-03-21T07:47:00.000000000'),
#   numpy.datetime64('2018-04-06T17:34:00.000000000')],
#  'event concept:name': ['Record Service Entry Sheet',
#   'Record Goods Receipt',
#   'Create Purchase Order Item',
#   'Receive Order Confirmation',
#   'Vendor creates invoice',
#   'Record Invoice Receipt',
#   'Clear Invoice',
#   <NA>,
#   'Remove Payment Block',
#   'Change Quantity',
#   'Price Change',
#   'Delete Purchase Order Item',
#   'Vendor creates debit memo',
#   'Revoke Invoice Receipt',
#   'Change Delivery Indicator',
#   'Block Purchase Order Item',
#   'Reactivate Purchase Order Item',
#   'Change Storage Location',
#   'Revoke Goods Receipt',
#   'Create Purchase Requisition Item',
#   'Update Order Confirmation',
#   'Change Approval for Purchase Order',
#   'Revoke Subsequent Invoice',
#   'Record Subsequent Invoice',
#   'Change payment term',
#   'Change Currency',
#   'Release Purchase Order',
#   'Set Payment Block',
#   'Change Rejection Indicator'],
#  'eventID ': [227000000000000.0,
#   nan,
#   228000000000000.0,
#   229000000000000.0,
#   230000000000000.0,
#   231000000000000.0,
#   232000000000000.0,
#   233000000000000.0,
#   234000000000000.0,
#   235000000000000.0,
#   236000000000000.0,
#   237000000000000.0,
#   238000000000000.0,
#   239000000000000.0,
#   240000000000000.0,
#   241000000000000.0,
#   242000000000000.0,
#   243000000000000.0,
#   244000000000000.0,
#   245000000000000.0,
#   246000000000000.0,
#   247000000000000.0,
#   248000000000000.0,
#   249000000000000.0,
#   250000000000000.0,
#   251000000000000.0,
#   252000000000000.0,
#   253000000000000.0,
#   254000000000000.0,
#   255000000000000.0,
#   256000000000000.0,
#   257000000000000.0,
#   258000000000000.0,
#   259000000000000.0,
#   260000000000000.0,
#   261000000000000.0,
#   262000000000000.0,
#   263000000000000.0,
#   264000000000000.0,
#   265000000000000.0,
#   266000000000000.0,
#   267000000000000.0,
#   268000000000000.0,
#   269000000000000.0,
#   270000000000000.0,
#   271000000000000.0,
#   272000000000000.0,
#   273000000000000.0,
#   274000000000000.0,
#   275000000000000.0,
#   276000000000000.0,
#   277000000000000.0,
#   278000000000000.0,
#   279000000000000.0,
#   280000000000000.0,
#   281000000000000.0,
#   282000000000000.0,
#   283000000000000.0,
#   284000000000000.0,
#   285000000000000.0,
#   286000000000000.0,
#   287000000000000.0,
#   288000000000000.0,
#   289000000000000.0,
#   290000000000000.0,
#   291000000000000.0,
#   292000000000000.0,
#   293000000000000.0,
#   294000000000000.0,
#   295000000000000.0,
#   296000000000000.0,
#   297000000000000.0,
#   298000000000000.0,
#   299000000000000.0,
#   300000000000000.0,
#   301000000000000.0,
#   302000000000000.0,
#   303000000000000.0,
#   304000000000000.0,
#   305000000000000.0,
#   306000000000000.0,
#   307000000000000.0,
#   308000000000000.0,
#   309000000000000.0,
#   310000000000000.0,
#   311000000000000.0,
#   312000000000000.0,
#   313000000000000.0,
#   314000000000000.0,
#   315000000000000.0,
#   316000000000000.0,
#   317000000000000.0,
#   318000000000000.0,
#   319000000000000.0,
#   320000000000000.0,
#   321000000000000.0,
#   322000000000000.0,
#   323000000000000.0,
#   324000000000000.0,
#   325000000000000.0],
#  'case Spend area text': ['Logistics',
#   'Packaging',
#   'Sales',
#   'CAPEX & SOCS',
#   'Latex & Monomers',
#   'Marketing',
#   'Trading & End Products',
#   'Specialty Resins',
#   'Others',
#   'Additives',
#   'Titanium Dioxides',
#   'Pigments & Colorants',
#   'Solvents',
#   'undefined',
#   'Commodity Resins',
#   'Workforce Services',
#   'Spend Area Unidentified',
#   'Enterprise Services',
#   <NA>],
#  'case Document Type': ['Standard PO', 'Framework order', <NA>],
#  'case Sub spend area text': ['Road Packed',
#   'Metal Containers & Lids < 30L',
#   'Labels',
#   'Plastic Containers & Lids < 30L',
#   'Products for Resale',
#   'MRO (components)',
#   'Vinyl Acetate Ethylenes',
#   'Commercial Printing',
#   'Trading products (old structure)',
#   'Isocyanates',
#   'Pure Acrylics',
#   'Polyamides & Polyamines',
#   'Alkyd Resins',
#   'Polyurethane Resins',
#   'Customers',
#   'Styrene Acrylics',
#   'Defoamers & Antifoams',
#   'Packaging - Other',
#   'Biocides',
#   'Rheology & Thixotropic Agents',
#   'Extenders',
#   'Latexes - Other',
#   'Chloride',
#   'Surfactants',
#   'Colorants',
#   'Public Relations',
#   'Glycol & Ether Solvents',
#   'undefined',
#   'Carbon Black Pigments',
#   'Opaque Polymers',
#   'Driers & Antiskinning Agents',
#   'Drums',
#   'Paperboard',
#   'Light & Heat Stabilizers',
#   'Waxes',
#   'Corrosion Inhibitors',
#   'Raw Material',
#   'Laboratory Supplies & Services',
#   'Catalysts & Initiators',
#   'Color Collateral',
#   'Commodity Resins Precursors',
#   'Ester Solvents',
#   'Vinyl Acrylics',
#   'Packaging',
#   'Aliphatic Solvents',
#   'Other Logistics Services',
#   'Sea',
#   'Mixing Machines',
#   'Exhibitions & seminars',
#   'Polyvinyl Acetates',
#   'Facility Management',
#   'Technical Services',
#   'Sulphate',
#   'Neutralisation Agents',
#   'Closures',
#   'Inorganic Pigments',
#   'Warehousing',
#   'Tubes',
#   'Intermediate Bulk Containers (IBC)',
#   'Utilities',
#   'Pallets',
#   'Marketing Support Services',
#   'HR Services',
#   'Plastic Film',
#   'Business Gifts & Promotional Items',
#   'Epoxy Resins - Liquid',
#   'Gasses',
#   'Additives - Other',
#   'Point of Sales',
#   'Spend Area Unidentified',
#   'QHSE Services',
#   'ICT Hardware',
#   'Jerry Cans',
#   'Amino Resins',
#   'Bags',
#   <NA>,
#   'Bottles',
#   'Specialty Resins Precursors',
#   'UV Resins',
#   'Specialty Resins - Other',
#   'Ketones Solvents',
#   'Hybrid Containers',
#   'Process Automation & Instrumentation',
#   'Fire Protection Agents',
#   'Effect Pigments',
#   'Acrylic Resins  Liquid',
#   'Organic Pigments',
#   'Design',
#   'Adhesion Promotors',
#   'Alcohol Solvents',
#   'Sales Promotion',
#   'Plasticizers',
#   'Transport & Hoisting Equipment',
#   'Solvents - Other',
#   'Equipment',
#   'Aromatic Solvents',
#   'Epoxy Resins - Solid',
#   'Polyester Resins - Liquid',
#   'Caseins & Starches',
#   'Spectrophotometers'],
#  'case Purch. Doc. Category name': ['Purchase order', <NA>],
#  'case Vendor': ['vendorID_0472',
#   'vendorID_0106',
#   'vendorID_0103',
#   'vendorID_0104',
#   'vendorID_0105',
#   'vendorID_0284',
#   'vendorID_0115',
#   'vendorID_0114',
#   'vendorID_0755',
#   'vendorID_0236',
#   'vendorID_0237',
#   'vendorID_0756',
#   'vendorID_0121',
#   'vendorID_0239',
#   'vendorID_1135',
#   'vendorID_0671',
#   'vendorID_0716',
#   'vendorID_0672',
#   'vendorID_1120',
#   'vendorID_0271',
#   'vendorID_0120',
#   'vendorID_0468',
#   'vendorID_0245',
#   'vendorID_0246',
#   'vendorID_0302',
#   'vendorID_0937',
#   'vendorID_0381',
#   'vendorID_0110',
#   'vendorID_0138',
#   'vendorID_0251',
#   'vendorID_0145',
#   'vendorID_0489',
#   'vendorID_0135',
#   'vendorID_0167',
#   'vendorID_0224',
#   'vendorID_0264',
#   'vendorID_0879',
#   'vendorID_0280',
#   'vendorID_0433',
#   'vendorID_0127',
#   'vendorID_0244',
#   'vendorID_0243',
#   'vendorID_0300',
#   'vendorID_0113',
#   'vendorID_0283',
#   'vendorID_0133',
#   'vendorID_0242',
#   'vendorID_0130',
#   'vendorID_0442',
#   'vendorID_0844',
#   'vendorID_0448',
#   'vendorID_0107',
#   'vendorID_0372',
#   'vendorID_0152',
#   'vendorID_0963',
#   'vendorID_0060',
#   'vendorID_0136',
#   'vendorID_0126',
#   'vendorID_0608',
#   'vendorID_0220',
#   'vendorID_0184',
#   'vendorID_1142',
#   'vendorID_0144',
#   'vendorID_0146',
#   'vendorID_0143',
#   'vendorID_0917',
#   'vendorID_0139',
#   'vendorID_0287',
#   'vendorID_0524',
#   'vendorID_0730',
#   'vendorID_0417',
#   'vendorID_0422',
#   'vendorID_0192',
#   'vendorID_0277',
#   'vendorID_0457',
#   'vendorID_0299',
#   'vendorID_0166',
#   'vendorID_1328',
#   'vendorID_0278',
#   'vendorID_0303',
#   'vendorID_0506',
#   'vendorID_1329',
#   'vendorID_0197',
#   'vendorID_0444',
#   'vendorID_0620',
#   'vendorID_0151',
#   'vendorID_0615',
#   'vendorID_0932',
#   'vendorID_0321',
#   'vendorID_0579',
#   'vendorID_0323',
#   'vendorID_0168',
#   'vendorID_0583',
#   'vendorID_0312',
#   'vendorID_1106',
#   'vendorID_0128',
#   'vendorID_0804',
#   'vendorID_0117',
#   'vendorID_0326',
#   'vendorID_0618'],
#  'case Item Type': ['Service',
#   'Standard',
#   'Third-party',
#   'Subcontracting',
#   'Consignment',
#   <NA>],
#  'case Item Category': ['Three way match, invoice after GR',
#   'Three way match, invoice before GR',
#   <NA>,
#   'Consignment'],
#  'case Spend classification text': ['NPR', 'PR', 'OTHER', 'undefined', <NA>],
#  'case Source': ['sourceSystemID_0000', <NA>],
#  'case Name': ['vendor_0457',
#   'vendor_0106',
#   'vendor_0103',
#   'vendor_0104',
#   'vendor_0105',
#   'vendor_0276',
#   'vendor_0115',
#   'vendor_0114',
#   'vendor_0720',
#   'vendor_0231',
#   'vendor_0232',
#   'vendor_0721',
#   'vendor_0120',
#   'vendor_0234',
#   'vendor_1079',
#   'vendor_0646',
#   'vendor_0685',
#   'vendor_0647',
#   'vendor_1065',
#   'vendor_0188',
#   'vendor_0119',
#   'vendor_0453',
#   'vendor_0240',
#   'vendor_0241',
#   'vendor_0293',
#   'vendor_0894',
#   'vendor_0370',
#   'vendor_0110',
#   'vendor_0137',
#   'vendor_0062',
#   'vendor_0144',
#   'vendor_0473',
#   'vendor_0134',
#   'vendor_0165',
#   'vendor_0219',
#   'vendor_0257',
#   'vendor_0839',
#   'vendor_0272',
#   'vendor_0421',
#   'vendor_0126',
#   'vendor_0239',
#   'vendor_0238',
#   'vendor_0291',
#   'vendor_0113',
#   'vendor_0275',
#   'vendor_0132',
#   'vendor_0237',
#   'vendor_0129',
#   'vendor_0429',
#   'vendor_0804',
#   'vendor_0435',
#   'vendor_0107',
#   'vendor_0361',
#   'vendor_0150',
#   'vendor_0920',
#   'vendor_0060',
#   'vendor_0135',
#   'vendor_0125',
#   'vendor_0271',
#   'vendor_0216',
#   'vendor_0164',
#   'vendor_1086',
#   'vendor_0143',
#   'vendor_0142',
#   'vendor_0876',
#   'vendor_0138',
#   'vendor_0278',
#   'vendor_0508',
#   'vendor_0475',
#   'vendor_0406',
#   'vendor_0410',
#   'vendor_0189',
#   'vendor_0269',
#   'vendor_0443',
#   'vendor_0290',
#   'vendor_1269',
#   'vendor_0270',
#   'vendor_0294',
#   'vendor_0490',
#   'vendor_1270',
#   'vendor_0194',
#   'vendor_0431',
#   'vendor_0597',
#   'vendor_0149',
#   'vendor_0594',
#   'vendor_0889',
#   'vendor_0312',
#   'vendor_0305',
#   'vendor_0314',
#   'vendor_0166',
#   'vendor_0565',
#   'vendor_0303',
#   'vendor_1052',
#   'vendor_0127',
#   'vendor_0764',
#   'vendor_0116',
#   'vendor_0317',
#   'vendor_0596',
#   'vendor_0722',
#   'vendor_0036'],
#  'case GR-Based Inv. Verif.': [1, 0],
#  'case Item': [1,
#   10,
#   20,
#   30,
#   100,
#   40,
#   50,
#   60,
#   70,
#   80,
#   90,
#   110,
#   120,
#   130,
#   140,
#   150,
#   160,
#   170,
#   180,
#   190,
#   200,
#   210,
#   220,
#   230,
#   240,
#   250,
#   260,
#   270,
#   280,
#   290,
#   300,
#   310,
#   320,
#   330,
#   340,
#   350,
#   360,
#   370,
#   380,
#   390,
#   400,
#   410,
#   420,
#   430,
#   440,
#   450,
#   460,
#   470,
#   1000,
#   1010,
#   1020,
#   1030,
#   1040,
#   1050,
#   1060,
#   1070,
#   1080,
#   1090,
#   1100,
#   480,
#   490,
#   500,
#   510,
#   520,
#   530,
#   540,
#   550,
#   560,
#   570,
#   580,
#   590,
#   600,
#   610,
#   620,
#   630,
#   640,
#   650,
#   660,
#   670,
#   680,
#   690,
#   700,
#   710,
#   720,
#   730,
#   740,
#   750,
#   760,
#   770,
#   780,
#   790,
#   800,
#   810,
#   820,
#   830,
#   840,
#   850,
#   860,
#   870,
#   880],
#  'case concept:name': ['4507016139_00001',
#   '4507016140_00010',
#   '4507016140_00020',
#   '4507016140_00030',
#   <NA>,
#   '4507016900_00050',
#   '4507016901_00010',
#   '4507016902_00010',
#   '4507016902_00020',
#   '4507016902_00030',
#   '4507016902_00040',
#   '4507016902_00050',
#   '4507016903_00010',
#   '4507016903_00100',
#   '4507016903_00110',
#   '4507016903_00120',
#   '4507016903_00130',
#   '4507016903_00020',
#   '4507016903_00030',
#   '4507016903_00040',
#   '4507016903_00050',
#   '4507016903_00060',
#   '4507016903_00070',
#   '4507016903_00080',
#   '4507016903_00090',
#   '4507016904_00010',
#   '4507016904_00020',
#   '4507016905_00010',
#   '4507016905_00020',
#   '4507016905_00030',
#   '4507016906_00010',
#   '4507016907_00010',
#   '4507016907_00020',
#   '4507016907_00030',
#   '4507016908_00010',
#   '4507016909_00010',
#   '4507016909_00020',
#   '4507016910_00010',
#   '4507016910_00100',
#   '4507016910_00020',
#   '4507016910_00030',
#   '4507016910_00040',
#   '4507016910_00050',
#   '4507016910_00060',
#   '4507016910_00070',
#   '4507016910_00080',
#   '4507016910_00090',
#   '4507016911_00010',
#   '4507016912_00010',
#   '4507016912_00020',
#   '4507016913_00010',
#   '4507016914_00010',
#   '4507016915_00010',
#   '4507016915_00020',
#   '4507016915_00030',
#   '4507016916_00010',
#   '4507016917_00010',
#   '4507016917_00020',
#   '4507016917_00030',
#   '4507016918_00010',
#   '4507016918_00020',
#   '4507016918_00030',
#   '4507016919_00010',
#   '4507016919_00020',
#   '4507016920_00010',
#   '4507016920_00020',
#   '4507016921_00010',
#   '4507016921_00020',
#   '4507016921_00030',
#   '4507016921_00040',
#   '4507016921_00050',
#   '4507016921_00060',
#   '4507016921_00070',
#   '4507016922_00010',
#   '4507016923_00010',
#   '4507016924_00010',
#   '4507016925_00010',
#   '4507016925_00100',
#   '4507016925_00110',
#   '4507016925_00120',
#   '4507016925_00130',
#   '4507016925_00140',
#   '4507016925_00020',
#   '4507016925_00030',
#   '4507016925_00040',
#   '4507016925_00050',
#   '4507016925_00060',
#   '4507016925_00070',
#   '4507016925_00080',
#   '4507016925_00090',
#   '4507016926_00010',
#   '4507016926_00100',
#   '4507016926_00110',
#   '4507016926_00120',
#   '4507016926_00130',
#   '4507016926_00140',
#   '4507016926_00150',
#   '4507016926_00160',
#   '4507016926_00170',
#   '4507016926_00020'],
#  'case Goods Receipt': ['True', <NA>],
#  'event User': [<NA>,
#   'batch_07',
#   'batch_03',
#   'user_029',
#   'user_030',
#   'user_019',
#   'user_002',
#   'user_006',
#   'user_061',
#   'user_257',
#   'user_077',
#   'user_052',
#   'user_039',
#   'user_107',
#   'user_020',
#   'user_059',
#   'user_031',
#   'user_045',
#   'user_262',
#   'user_012',
#   'user_212',
#   'user_013',
#   'user_007',
#   'user_141',
#   'user_044',
#   'user_049',
#   'batch_02',
#   'user_147',
#   'batch_06',
#   'user_050',
#   'user_001',
#   'user_274',
#   'user_015',
#   'user_144',
#   'user_128',
#   'user_038',
#   'user_089',
#   'user_177',
#   'user_070',
#   'user_072',
#   'user_040',
#   'user_004',
#   'user_048',
#   'user_139',
#   'batch_00',
#   'user_125',
#   'user_122',
#   'user_023',
#   'user_362',
#   'user_085',
#   'user_186',
#   'user_087',
#   'user_105',
#   'user_082',
#   'user_066',
#   'user_053',
#   'user_084',
#   'user_086',
#   'user_121',
#   'user_079',
#   'user_152',
#   'user_102',
#   'user_078',
#   'user_076',
#   'user_258',
#   'user_088',
#   'user_363',
#   'user_142',
#   'user_126',
#   'user_120',
#   'user_095',
#   'user_096',
#   'user_101',
#   'user_080',
#   'user_094',
#   'batch_08',
#   'user_127',
#   'user_190',
#   'user_081',
#   'user_099',
#   'undefined',
#   'user_154',
#   'user_167',
#   'user_321',
#   'user_037',
#   'user_243',
#   'user_065',
#   'user_364',
#   'user_359',
#   'user_331',
#   'user_158',
#   'user_033',
#   'user_034',
#   'user_071',
#   'user_148',
#   'user_168',
#   'user_064',
#   'user_119',
#   'user_062',
#   'user_056'],
#  'event org:resource': [<NA>,
#   'batch_07',
#   'batch_03',
#   'user_029',
#   'user_030',
#   'user_019',
#   'user_002',
#   'user_006',
#   'user_061',
#   'user_257',
#   'user_077',
#   'user_052',
#   'user_039',
#   'user_107',
#   'user_020',
#   'user_059',
#   'user_031',
#   'user_045',
#   'user_262',
#   'user_012',
#   'user_212',
#   'user_013',
#   'user_007',
#   'user_141',
#   'user_044',
#   'user_049',
#   'batch_02',
#   'user_147',
#   'batch_06',
#   'user_050',
#   'user_001',
#   'user_274',
#   'user_015',
#   'user_144',
#   'user_128',
#   'user_038',
#   'user_089',
#   'user_177',
#   'user_070',
#   'user_072',
#   'user_040',
#   'user_004',
#   'user_048',
#   'user_139',
#   'batch_00',
#   'user_125',
#   'user_122',
#   'user_023',
#   'user_362',
#   'user_085',
#   'user_186',
#   'user_087',
#   'user_105',
#   'user_082',
#   'user_066',
#   'user_053',
#   'user_084',
#   'user_086',
#   'user_121',
#   'user_079',
#   'user_152',
#   'user_102',
#   'user_078',
#   'user_076',
#   'user_258',
#   'user_088',
#   'user_363',
#   'user_142',
#   'user_126',
#   'user_120',
#   'user_095',
#   'user_096',
#   'user_101',
#   'user_080',
#   'user_094',
#   'batch_08',
#   'user_127',
#   'user_190',
#   'user_081',
#   'user_099',
#   'undefined',
#   'user_154',
#   'user_167',
#   'user_321',
#   'user_037',
#   'user_243',
#   'user_065',
#   'user_364',
#   'user_359',
#   'user_331',
#   'user_158',
#   'user_033',
#   'user_034',
#   'user_071',
#   'user_148',
#   'user_168',
#   'user_064',
#   'user_119',
#   'user_062',
#   'user_056'],
#  'event Cumulative net worth (EUR)': [72.0,
#   30957.0,
#   1157.0,
#   2386.0,
#   21699.0,
#   144.0,
#   19239.0,
#   17937.0,
#   2820.0,
#   1900.0,
#   4320.0,
#   2880.0,
#   nan,
#   472.0,
#   397.0,
#   865.0,
#   555.0,
#   249.0,
#   286.0,
#   474.0,
#   0.0,
#   49.0,
#   1505.0,
#   356.0,
#   160.0,
#   205.0,
#   247.0,
#   288.0,
#   302.0,
#   240.0,
#   2165.0,
#   1074.0,
#   1213.0,
#   178.0,
#   89.0,
#   1815.0,
#   154.0,
#   121.0,
#   5736.0,
#   3507.0,
#   119.0,
#   148.0,
#   363.0,
#   1468.0,
#   1257.0,
#   4464.0,
#   177.0,
#   791.0,
#   954.0,
#   77.0,
#   6754.0,
#   16170.0,
#   17310.0,
#   8494.0,
#   129.0,
#   90.0,
#   69.0,
#   123.0,
#   583.0,
#   75.0,
#   5578.0,
#   196.0,
#   1.0,
#   321.0,
#   628.0,
#   551.0,
#   516.0,
#   2597.0,
#   380.0,
#   831.0,
#   1188.0,
#   1357.0,
#   1166.0,
#   417.0,
#   370.0,
#   2321.0,
#   4285.0,
#   546.0,
#   163.0,
#   309.0,
#   2540.0,
#   661.0,
#   429.0,
#   393.0,
#   1010.0,
#   1617.0,
#   593.0,
#   275.0,
#   396.0,
#   168.0,
#   116.0,
#   428.0,
#   395.0,
#   1072.0,
#   1266.0,
#   896.0,
#   494.0,
#   548.0,
#   32154.0,
#   2267.0]}

# %%
# Overview property: Length of the list of up to 100 unique entries
num_displayed_unique_entries_property = {}
for log_column in log_columns:
  unique_entries = event_log_table[log_column].unique()
  unique_entries = list(unique_entries)
  unique_entries = unique_entries[:100]
  num_displayed_unique_entries_property[log_column] = len(unique_entries)

overview_table.loc['Length of the list of up to 100 unique entries'] = num_displayed_unique_entries_property
num_displayed_unique_entries_property
# Out:
# {'caseID': 100,
#  'event time:timestamp': 100,
#  'event concept:name': 29,
#  'eventID ': 100,
#  'case Spend area text': 19,
#  'case Document Type': 3,
#  'case Sub spend area text': 100,
#  'case Purch. Doc. Category name': 2,
#  'case Vendor': 100,
#  'case Item Type': 6,
#  'case Item Category': 4,
#  'case Spend classification text': 5,
#  'case Source': 2,
#  'case Name': 100,
#  'case GR-Based Inv. Verif.': 2,
#  'case Item': 100,
#  'case concept:name': 100,
#  'case Goods Receipt': 2,
#  'event User': 100,
#  'event org:resource': 100,
#  'event Cumulative net worth (EUR)': 100}

# %%
# Inspect the overview table
overview_table
# Out:
#                                                                                                caseID  \
# Event log column property
# Supplier2_Comparative_Mining                                             Supplier2_Comparative_Mining
# Title                                                                                         Case ID
# Importance                                                                        Mandatory attribute
# Level                                                                                      Case level
# Data type                                                                                      string
# Number of entries                                                                              349526
# Number of unique entries                                                                        56127
# List up to 100 unique entries to view the struc...  [4507016139 1, 4507016140 10, 4507016140 20, 4...
# Length of the list of up to 100 unique entries                                                    100
#
#                                                                                  event time:timestamp  \
# Event log column property
# Supplier2_Comparative_Mining                                             Supplier2_Comparative_Mining
# Title                                                                                       Timestamp
# Importance                                                                        Mandatory attribute
# Level                                                                                     Event level
# Data type                                                                              datetime64[ns]
# Number of entries                                                                              349526
# Number of unique entries                                                                        42173
# List up to 100 unique entries to view the struc...  [2018-03-14T03:11:00.000000000, 2018-03-14T03:...
# Length of the list of up to 100 unique entries                                                    100
#
#                                                                                    event concept:name  \
# Event log column property
# Supplier2_Comparative_Mining                                             Supplier2_Comparative_Mining
# Title                                                                                        Activity
# Importance                                                                        Mandatory attribute
# Level                                                                                     Event level
# Data type                                                                                      string
# Number of entries                                                                              349526
# Number of unique entries                                                                           28
# List up to 100 unique entries to view the struc...  [Record Service Entry Sheet, Record Goods Rece...
# Length of the list of up to 100 unique entries                                                     29
#
#                                                                                              eventID   \
# Event log column property
# Supplier2_Comparative_Mining                                             Supplier2_Comparative_Mining
# Title                                                                                        eventID
# Importance                                                                        Mandatory attribute
# Level                                                                                     Event level
# Data type                                                                                     float64
# Number of entries                                                                              349526
# Number of unique entries                                                                          243
# List up to 100 unique entries to view the struc...  [227000000000000.0, nan, 228000000000000.0, 22...
# Length of the list of up to 100 unique entries                                                    100
#
#                                                                                  case Spend area text  \
# Event log column property
# Supplier2_Comparative_Mining                                             Supplier2_Comparative_Mining
# Title                                                                            case Spend area text
# Importance                                                                       Additional attribute
# Level                                                                                      Case level
# Data type                                                                                      string
# Number of entries                                                                              349526
# Number of unique entries                                                                           18
# List up to 100 unique entries to view the struc...  [Logistics, Packaging, Sales, CAPEX & SOCS, La...
# Length of the list of up to 100 unique entries                                                     19
#
#                                                                       case Document Type  \
# Event log column property
# Supplier2_Comparative_Mining                                Supplier2_Comparative_Mining
# Title                                                                 case Document Type
# Importance                                                          Additional attribute
# Level                                                                         Case level
# Data type                                                                         string
# Number of entries                                                                 349526
# Number of unique entries                                                               2
# List up to 100 unique entries to view the struc...  [Standard PO, Framework order, <NA>]
# Length of the list of up to 100 unique entries                                         3
#
#                                                                              case Sub spend area text  \
# Event log column property
# Supplier2_Comparative_Mining                                             Supplier2_Comparative_Mining
# Title                                                                        case Sub spend area text
# Importance                                                                       Additional attribute
# Level                                                                                      Case level
# Data type                                                                                      string
# Number of entries                                                                              349526
# Number of unique entries                                                                          109
# List up to 100 unique entries to view the struc...  [Road Packed, Metal Containers & Lids < 30L, L...
# Length of the list of up to 100 unique entries                                                    100
#
#                                                     case Purch. Doc. Category name  \
# Event log column property
# Supplier2_Comparative_Mining                          Supplier2_Comparative_Mining
# Title                                               case Purch. Doc. Category name
# Importance                                                    Additional attribute
# Level                                                                   Case level
# Data type                                                                   string
# Number of entries                                                           349526
# Number of unique entries                                                         1
# List up to 100 unique entries to view the struc...          [Purchase order, <NA>]
# Length of the list of up to 100 unique entries                                   2
#
#                                                                                           case Vendor  \
# Event log column property
# Supplier2_Comparative_Mining                                             Supplier2_Comparative_Mining
# Title                                                                                     case Vendor
# Importance                                                                       Additional attribute
# Level                                                                                      Case level
# Data type                                                                                      string
# Number of entries                                                                              349526
# Number of unique entries                                                                         1109
# List up to 100 unique entries to view the struc...  [vendorID_0472, vendorID_0106, vendorID_0103, ...
# Length of the list of up to 100 unique entries                                                    100
#
#                                                                                        case Item Type  \
# Event log column property
# Supplier2_Comparative_Mining                                             Supplier2_Comparative_Mining
# Title                                                                                  case Item Type
# Importance                                                                       Additional attribute
# Level                                                                                      Case level
# Data type                                                                                      string
# Number of entries                                                                              349526
# Number of unique entries                                                                            5
# List up to 100 unique entries to view the struc...  [Service, Standard, Third-party, Subcontractin...
# Length of the list of up to 100 unique entries                                                      6
#
#                                                     ...  \
# Event log column property                           ...
# Supplier2_Comparative_Mining                        ...
# Title                                               ...
# Importance                                          ...
# Level                                               ...
# Data type                                           ...
# Number of entries                                   ...
# Number of unique entries                            ...
# List up to 100 unique entries to view the struc...  ...
# Length of the list of up to 100 unique entries      ...
#
#                                                        case Spend classification text  \
# Event log column property
# Supplier2_Comparative_Mining                             Supplier2_Comparative_Mining
# Title                                                  case Spend classification text
# Importance                                                       Additional attribute
# Level                                                                      Case level
# Data type                                                                      string
# Number of entries                                                              349526
# Number of unique entries                                                            4
# List up to 100 unique entries to view the struc...  [NPR, PR, OTHER, undefined, <NA>]
# Length of the list of up to 100 unique entries                                      5
#
#                                                                      case Source  \
# Event log column property
# Supplier2_Comparative_Mining                        Supplier2_Comparative_Mining
# Title                                                                case Source
# Importance                                                  Additional attribute
# Level                                                                 Case level
# Data type                                                                 string
# Number of entries                                                         349526
# Number of unique entries                                                       1
# List up to 100 unique entries to view the struc...   [sourceSystemID_0000, <NA>]
# Length of the list of up to 100 unique entries                                 2
#
#                                                                                             case Name  \
# Event log column property
# Supplier2_Comparative_Mining                                             Supplier2_Comparative_Mining
# Title                                                                                       case Name
# Importance                                                                       Additional attribute
# Level                                                                                      Case level
# Data type                                                                                      string
# Number of entries                                                                              349526
# Number of unique entries                                                                         1050
# List up to 100 unique entries to view the struc...  [vendor_0457, vendor_0106, vendor_0103, vendor...
# Length of the list of up to 100 unique entries                                                    100
#
#                                                        case GR-Based Inv. Verif.  \
# Event log column property
# Supplier2_Comparative_Mining                        Supplier2_Comparative_Mining
# Title                                                  case GR-Based Inv. Verif.
# Importance                                                  Additional attribute
# Level                                                                 Case level
# Data type                                                                  int64
# Number of entries                                                         349526
# Number of unique entries                                                       2
# List up to 100 unique entries to view the struc...                        [1, 0]
# Length of the list of up to 100 unique entries                                 2
#
#                                                                                             case Item  \
# Event log column property
# Supplier2_Comparative_Mining                                             Supplier2_Comparative_Mining
# Title                                                                                       case Item
# Importance                                                                       Additional attribute
# Level                                                                                      Case level
# Data type                                                                                       int64
# Number of entries                                                                              349526
# Number of unique entries                                                                          233
# List up to 100 unique entries to view the struc...  [1, 10, 20, 30, 100, 40, 50, 60, 70, 80, 90, 1...
# Length of the list of up to 100 unique entries                                                    100
#
#                                                                                     case concept:name  \
# Event log column property
# Supplier2_Comparative_Mining                                             Supplier2_Comparative_Mining
# Title                                                                               case concept:name
# Importance                                                                       Additional attribute
# Level                                                                                      Case level
# Data type                                                                                      string
# Number of entries                                                                              349526
# Number of unique entries                                                                        53733
# List up to 100 unique entries to view the struc...  [4507016139_00001, 4507016140_00010, 450701614...
# Length of the list of up to 100 unique entries                                                    100
#
#                                                               case Goods Receipt  \
# Event log column property
# Supplier2_Comparative_Mining                        Supplier2_Comparative_Mining
# Title                                                         case Goods Receipt
# Importance                                                  Additional attribute
# Level                                                                 Case level
# Data type                                                                 string
# Number of entries                                                         349526
# Number of unique entries                                                       1
# List up to 100 unique entries to view the struc...                  [True, <NA>]
# Length of the list of up to 100 unique entries                                 2
#
#                                                                                            event User  \
# Event log column property
# Supplier2_Comparative_Mining                                             Supplier2_Comparative_Mining
# Title                                                                                      event User
# Importance                                                                       Additional attribute
# Level                                                                                     Event level
# Data type                                                                                      string
# Number of entries                                                                              349526
# Number of unique entries                                                                          333
# List up to 100 unique entries to view the struc...  [<NA>, batch_07, batch_03, user_029, user_030,...
# Length of the list of up to 100 unique entries                                                    100
#
#                                                                                    event org:resource  \
# Event log column property
# Supplier2_Comparative_Mining                                             Supplier2_Comparative_Mining
# Title                                                                              event org:resource
# Importance                                                                       Additional attribute
# Level                                                                                     Event level
# Data type                                                                                      string
# Number of entries                                                                              349526
# Number of unique entries                                                                          333
# List up to 100 unique entries to view the struc...  [<NA>, batch_07, batch_03, user_029, user_030,...
# Length of the list of up to 100 unique entries                                                    100
#
#                                                                      event Cumulative net worth (EUR)
# Event log column property
# Supplier2_Comparative_Mining                                             Supplier2_Comparative_Mining
# Title                                                                event Cumulative net worth (EUR)
# Importance                                                                       Additional attribute
# Level                                                                                     Event level
# Data type                                                                                     float64
# Number of entries                                                                              349526
# Number of unique entries                                                                        11330
# List up to 100 unique entries to view the struc...  [72.0, 30957.0, 1157.0, 2386.0, 21699.0, 144.0...
# Length of the list of up to 100 unique entries                                                    100
#
# [9 rows x 21 columns]

# %%
# Overview property: Number of duplicate entries
number_of_duplicate_entries_property = {}
for log_column in log_columns:
  number_of_duplicate_entries_property[log_column] = number_of_entries_property[log_column] - number_of_unique_entries_property[log_column]

overview_table.loc['Number of duplicate entries'] = number_of_duplicate_entries_property
overview_table.loc['Number of duplicate entries']
# Out:
# caseID                              293399
# event time:timestamp                307353
# event concept:name                  349498
# eventID                             349283
# case Spend area text                349508
# case Document Type                  349524
# case Sub spend area text            349417
# case Purch. Doc. Category name      349525
# case Vendor                         348417
# case Item Type                      349521
# case Item Category                  349523
# case Spend classification text      349522
# case Source                         349525
# case Name                           348476
# case GR-Based Inv. Verif.           349524
# case Item                           349293
# case concept:name                   295793
# case Goods Receipt                  349525
# event User                          349193
# event org:resource                  349193
# event Cumulative net worth (EUR)    338196
# Name: Number of duplicate entries, dtype: object

# %%
# Overview property: Number of undefined entries
number_of_undefined_entries_property = {}
nan_info = event_log_table.isna().sum()
for log_column in log_columns:
    number_of_undefined_entries_property[log_column] = nan_info[log_column]

overview_table.loc['Number of undefined entries'] = number_of_undefined_entries_property
number_of_undefined_entries_property
# Out:
# {'caseID': 1495,
#  'event time:timestamp': 16078,
#  'event concept:name': 16078,
#  'eventID ': 133,
#  'case Spend area text': 11,
#  'case Document Type': 11,
#  'case Sub spend area text': 11,
#  'case Purch. Doc. Category name': 438,
#  'case Vendor': 11,
#  'case Item Type': 11,
#  'case Item Category': 784,
#  'case Spend classification text': 11,
#  'case Source': 11,
#  'case Name': 11,
#  'case GR-Based Inv. Verif.': 0,
#  'case Item': 0,
#  'case concept:name': 16078,
#  'case Goods Receipt': 16078,
#  'event User': 103390,
#  'event org:resource': 103390,
#  'event Cumulative net worth (EUR)': 16078}

# %%
# Overview propperty: Number of undefined entries in percentages
percentage_of_undefined_entries_property = {}
nan_info = event_log_table.isna().sum()
for log_column in log_columns:
    percentage = nan_info[log_column]/len(event_log_table)*100 #len calculates the length of a variable
    percentage = f'{percentage:.2f}'
    percentage_of_undefined_entries_property[log_column] = percentage

overview_table.loc['Percentage of undefined entries'] = percentage_of_undefined_entries_property
percentage_of_undefined_entries_property
# Out:
# {'caseID': '0.43',
#  'event time:timestamp': '4.60',
#  'event concept:name': '4.60',
#  'eventID ': '0.04',
#  'case Spend area text': '0.00',
#  'case Document Type': '0.00',
#  'case Sub spend area text': '0.00',
#  'case Purch. Doc. Category name': '0.13',
#  'case Vendor': '0.00',
#  'case Item Type': '0.00',
#  'case Item Category': '0.22',
#  'case Spend classification text': '0.00',
#  'case Source': '0.00',
#  'case Name': '0.00',
#  'case GR-Based Inv. Verif.': '0.00',
#  'case Item': '0.00',
#  'case concept:name': '4.60',
#  'case Goods Receipt': '4.60',
#  'event User': '29.58',
#  'event org:resource': '29.58',
#  'event Cumulative net worth (EUR)': '4.60'}

# %%
overview_table
# Out:
#                                                                                                caseID  \
# Event log column property
# Supplier2_Comparative_Mining                                             Supplier2_Comparative_Mining
# Title                                                                                         Case ID
# Importance                                                                        Mandatory attribute
# Level                                                                                      Case level
# Data type                                                                                      string
# Number of entries                                                                              349526
# Number of unique entries                                                                        56127
# List up to 100 unique entries to view the struc...  [4507016139 1, 4507016140 10, 4507016140 20, 4...
# Length of the list of up to 100 unique entries                                                    100
# Number of duplicate entries                                                                    293399
# Number of undefined entries                                                                      1495
# Percentage of undefined entries                                                                  0.43
#
#                                                                                  event time:timestamp  \
# Event log column property
# Supplier2_Comparative_Mining                                             Supplier2_Comparative_Mining
# Title                                                                                       Timestamp
# Importance                                                                        Mandatory attribute
# Level                                                                                     Event level
# Data type                                                                              datetime64[ns]
# Number of entries                                                                              349526
# Number of unique entries                                                                        42173
# List up to 100 unique entries to view the struc...  [2018-03-14T03:11:00.000000000, 2018-03-14T03:...
# Length of the list of up to 100 unique entries                                                    100
# Number of duplicate entries                                                                    307353
# Number of undefined entries                                                                     16078
# Percentage of undefined entries                                                                  4.60
#
#                                                                                    event concept:name  \
# Event log column property
# Supplier2_Comparative_Mining                                             Supplier2_Comparative_Mining
# Title                                                                                        Activity
# Importance                                                                        Mandatory attribute
# Level                                                                                     Event level
# Data type                                                                                      string
# Number of entries                                                                              349526
# Number of unique entries                                                                           28
# List up to 100 unique entries to view the struc...  [Record Service Entry Sheet, Record Goods Rece...
# Length of the list of up to 100 unique entries                                                     29
# Number of duplicate entries                                                                    349498
# Number of undefined entries                                                                     16078
# Percentage of undefined entries                                                                  4.60
#
#                                                                                              eventID   \
# Event log column property
# Supplier2_Comparative_Mining                                             Supplier2_Comparative_Mining
# Title                                                                                        eventID
# Importance                                                                        Mandatory attribute
# Level                                                                                     Event level
# Data type                                                                                     float64
# Number of entries                                                                              349526
# Number of unique entries                                                                          243
# List up to 100 unique entries to view the struc...  [227000000000000.0, nan, 228000000000000.0, 22...
# Length of the list of up to 100 unique entries                                                    100
# Number of duplicate entries                                                                    349283
# Number of undefined entries                                                                       133
# Percentage of undefined entries                                                                  0.04
#
#                                                                                  case Spend area text  \
# Event log column property
# Supplier2_Comparative_Mining                                             Supplier2_Comparative_Mining
# Title                                                                            case Spend area text
# Importance                                                                       Additional attribute
# Level                                                                                      Case level
# Data type                                                                                      string
# Number of entries                                                                              349526
# Number of unique entries                                                                           18
# List up to 100 unique entries to view the struc...  [Logistics, Packaging, Sales, CAPEX & SOCS, La...
# Length of the list of up to 100 unique entries                                                     19
# Number of duplicate entries                                                                    349508
# Number of undefined entries                                                                        11
# Percentage of undefined entries                                                                  0.00
#
#                                                                       case Document Type  \
# Event log column property
# Supplier2_Comparative_Mining                                Supplier2_Comparative_Mining
# Title                                                                 case Document Type
# Importance                                                          Additional attribute
# Level                                                                         Case level
# Data type                                                                         string
# Number of entries                                                                 349526
# Number of unique entries                                                               2
# List up to 100 unique entries to view the struc...  [Standard PO, Framework order, <NA>]
# Length of the list of up to 100 unique entries                                         3
# Number of duplicate entries                                                       349524
# Number of undefined entries                                                           11
# Percentage of undefined entries                                                     0.00
#
#                                                                              case Sub spend area text  \
# Event log column property
# Supplier2_Comparative_Mining                                             Supplier2_Comparative_Mining
# Title                                                                        case Sub spend area text
# Importance                                                                       Additional attribute
# Level                                                                                      Case level
# Data type                                                                                      string
# Number of entries                                                                              349526
# Number of unique entries                                                                          109
# List up to 100 unique entries to view the struc...  [Road Packed, Metal Containers & Lids < 30L, L...
# Length of the list of up to 100 unique entries                                                    100
# Number of duplicate entries                                                                    349417
# Number of undefined entries                                                                        11
# Percentage of undefined entries                                                                  0.00
#
#                                                     case Purch. Doc. Category name  \
# Event log column property
# Supplier2_Comparative_Mining                          Supplier2_Comparative_Mining
# Title                                               case Purch. Doc. Category name
# Importance                                                    Additional attribute
# Level                                                                   Case level
# Data type                                                                   string
# Number of entries                                                           349526
# Number of unique entries                                                         1
# List up to 100 unique entries to view the struc...          [Purchase order, <NA>]
# Length of the list of up to 100 unique entries                                   2
# Number of duplicate entries                                                 349525
# Number of undefined entries                                                    438
# Percentage of undefined entries                                               0.13
#
#                                                                                           case Vendor  \
# Event log column property
# Supplier2_Comparative_Mining                                             Supplier2_Comparative_Mining
# Title                                                                                     case Vendor
# Importance                                                                       Additional attribute
# Level                                                                                      Case level
# Data type                                                                                      string
# Number of entries                                                                              349526
# Number of unique entries                                                                         1109
# List up to 100 unique entries to view the struc...  [vendorID_0472, vendorID_0106, vendorID_0103, ...
# Length of the list of up to 100 unique entries                                                    100
# Number of duplicate entries                                                                    348417
# Number of undefined entries                                                                        11
# Percentage of undefined entries                                                                  0.00
#
#                                                                                        case Item Type  \
# Event log column property
# Supplier2_Comparative_Mining                                             Supplier2_Comparative_Mining
# Title                                                                                  case Item Type
# Importance                                                                       Additional attribute
# Level                                                                                      Case level
# Data type                                                                                      string
# Number of entries                                                                              349526
# Number of unique entries                                                                            5
# List up to 100 unique entries to view the struc...  [Service, Standard, Third-party, Subcontractin...
# Length of the list of up to 100 unique entries                                                      6
# Number of duplicate entries                                                                    349521
# Number of undefined entries                                                                        11
# Percentage of undefined entries                                                                  0.00
#
#                                                     ...  \
# Event log column property                           ...
# Supplier2_Comparative_Mining                        ...
# Title                                               ...
# Importance                                          ...
# Level                                               ...
# Data type                                           ...
# Number of entries                                   ...
# Number of unique entries                            ...
# List up to 100 unique entries to view the struc...  ...
# Length of the list of up to 100 unique entries      ...
# Number of duplicate entries                         ...
# Number of undefined entries                         ...
# Percentage of undefined entries                     ...
#
#                                                        case Spend classification text  \
# Event log column property
# Supplier2_Comparative_Mining                             Supplier2_Comparative_Mining
# Title                                                  case Spend classification text
# Importance                                                       Additional attribute
# Level                                                                      Case level
# Data type                                                                      string
# Number of entries                                                              349526
# Number of unique entries                                                            4
# List up to 100 unique entries to view the struc...  [NPR, PR, OTHER, undefined, <NA>]
# Length of the list of up to 100 unique entries                                      5
# Number of duplicate entries                                                    349522
# Number of undefined entries                                                        11
# Percentage of undefined entries                                                  0.00
#
#                                                                      case Source  \
# Event log column property
# Supplier2_Comparative_Mining                        Supplier2_Comparative_Mining
# Title                                                                case Source
# Importance                                                  Additional attribute
# Level                                                                 Case level
# Data type                                                                 string
# Number of entries                                                         349526
# Number of unique entries                                                       1
# List up to 100 unique entries to view the struc...   [sourceSystemID_0000, <NA>]
# Length of the list of up to 100 unique entries                                 2
# Number of duplicate entries                                               349525
# Number of undefined entries                                                   11
# Percentage of undefined entries                                             0.00
#
#                                                                                             case Name  \
# Event log column property
# Supplier2_Comparative_Mining                                             Supplier2_Comparative_Mining
# Title                                                                                       case Name
# Importance                                                                       Additional attribute
# Level                                                                                      Case level
# Data type                                                                                      string
# Number of entries                                                                              349526
# Number of unique entries                                                                         1050
# List up to 100 unique entries to view the struc...  [vendor_0457, vendor_0106, vendor_0103, vendor...
# Length of the list of up to 100 unique entries                                                    100
# Number of duplicate entries                                                                    348476
# Number of undefined entries                                                                        11
# Percentage of undefined entries                                                                  0.00
#
#                                                        case GR-Based Inv. Verif.  \
# Event log column property
# Supplier2_Comparative_Mining                        Supplier2_Comparative_Mining
# Title                                                  case GR-Based Inv. Verif.
# Importance                                                  Additional attribute
# Level                                                                 Case level
# Data type                                                                  int64
# Number of entries                                                         349526
# Number of unique entries                                                       2
# List up to 100 unique entries to view the struc...                        [1, 0]
# Length of the list of up to 100 unique entries                                 2
# Number of duplicate entries                                               349524
# Number of undefined entries                                                    0
# Percentage of undefined entries                                             0.00
#
#                                                                                             case Item  \
# Event log column property
# Supplier2_Comparative_Mining                                             Supplier2_Comparative_Mining
# Title                                                                                       case Item
# Importance                                                                       Additional attribute
# Level                                                                                      Case level
# Data type                                                                                       int64
# Number of entries                                                                              349526
# Number of unique entries                                                                          233
# List up to 100 unique entries to view the struc...  [1, 10, 20, 30, 100, 40, 50, 60, 70, 80, 90, 1...
# Length of the list of up to 100 unique entries                                                    100
# Number of duplicate entries                                                                    349293
# Number of undefined entries                                                                         0
# Percentage of undefined entries                                                                  0.00
#
#                                                                                     case concept:name  \
# Event log column property
# Supplier2_Comparative_Mining                                             Supplier2_Comparative_Mining
# Title                                                                               case concept:name
# Importance                                                                       Additional attribute
# Level                                                                                      Case level
# Data type                                                                                      string
# Number of entries                                                                              349526
# Number of unique entries                                                                        53733
# List up to 100 unique entries to view the struc...  [4507016139_00001, 4507016140_00010, 450701614...
# Length of the list of up to 100 unique entries                                                    100
# Number of duplicate entries                                                                    295793
# Number of undefined entries                                                                     16078
# Percentage of undefined entries                                                                  4.60
#
#                                                               case Goods Receipt  \
# Event log column property
# Supplier2_Comparative_Mining                        Supplier2_Comparative_Mining
# Title                                                         case Goods Receipt
# Importance                                                  Additional attribute
# Level                                                                 Case level
# Data type                                                                 string
# Number of entries                                                         349526
# Number of unique entries                                                       1
# List up to 100 unique entries to view the struc...                  [True, <NA>]
# Length of the list of up to 100 unique entries                                 2
# Number of duplicate entries                                               349525
# Number of undefined entries                                                16078
# Percentage of undefined entries                                             4.60
#
#                                                                                            event User  \
# Event log column property
# Supplier2_Comparative_Mining                                             Supplier2_Comparative_Mining
# Title                                                                                      event User
# Importance                                                                       Additional attribute
# Level                                                                                     Event level
# Data type                                                                                      string
# Number of entries                                                                              349526
# Number of unique entries                                                                          333
# List up to 100 unique entries to view the struc...  [<NA>, batch_07, batch_03, user_029, user_030,...
# Length of the list of up to 100 unique entries                                                    100
# Number of duplicate entries                                                                    349193
# Number of undefined entries                                                                    103390
# Percentage of undefined entries                                                                 29.58
#
#                                                                                    event org:resource  \
# Event log column property
# Supplier2_Comparative_Mining                                             Supplier2_Comparative_Mining
# Title                                                                              event org:resource
# Importance                                                                       Additional attribute
# Level                                                                                     Event level
# Data type                                                                                      string
# Number of entries                                                                              349526
# Number of unique entries                                                                          333
# List up to 100 unique entries to view the struc...  [<NA>, batch_07, batch_03, user_029, user_030,...
# Length of the list of up to 100 unique entries                                                    100
# Number of duplicate entries                                                                    349193
# Number of undefined entries                                                                    103390
# Percentage of undefined entries                                                                 29.58
#
#                                                                      event Cumulative net worth (EUR)
# Event log column property
# Supplier2_Comparative_Mining                                             Supplier2_Comparative_Mining
# Title                                                                event Cumulative net worth (EUR)
# Importance                                                                       Additional attribute
# Level                                                                                     Event level
# Data type                                                                                     float64
# Number of entries                                                                              349526
# Number of unique entries                                                                        11330
# List up to 100 unique entries to view the struc...  [72.0, 30957.0, 1157.0, 2386.0, 21699.0, 144.0...
# Length of the list of up to 100 unique entries                                                    100
# Number of duplicate entries                                                                    338196
# Number of undefined entries                                                                     16078
# Percentage of undefined entries                                                                  4.60
#
# [12 rows x 21 columns]

# %%
# Switching the index of the Meta-DataFrame and table structure
# The current layout of the Meta-Dataframe is transformed, that the columns become the rows, and the rows become the columns.
overview_table = overview_table.T
overview_table.reset_index(inplace = True)
overview_table.rename(columns={'index': 'Property'}, inplace = True)
overview_table
# Out:
# Event log column property                          Property  \
# 0                                                    caseID
# 1                                      event time:timestamp
# 2                                        event concept:name
# 3                                                  eventID
# 4                                      case Spend area text
# 5                                        case Document Type
# 6                                  case Sub spend area text
# 7                            case Purch. Doc. Category name
# 8                                               case Vendor
# 9                                            case Item Type
# 10                                       case Item Category
# 11                           case Spend classification text
# 12                                              case Source
# 13                                                case Name
# 14                                case GR-Based Inv. Verif.
# 15                                                case Item
# 16                                        case concept:name
# 17                                       case Goods Receipt
# 18                                               event User
# 19                                       event org:resource
# 20                         event Cumulative net worth (EUR)
#
# Event log column property  Supplier2_Comparative_Mining  \
# 0                          Supplier2_Comparative_Mining
# 1                          Supplier2_Comparative_Mining
# 2                          Supplier2_Comparative_Mining
# 3                          Supplier2_Comparative_Mining
# 4                          Supplier2_Comparative_Mining
# 5                          Supplier2_Comparative_Mining
# 6                          Supplier2_Comparative_Mining
# 7                          Supplier2_Comparative_Mining
# 8                          Supplier2_Comparative_Mining
# 9                          Supplier2_Comparative_Mining
# 10                         Supplier2_Comparative_Mining
# 11                         Supplier2_Comparative_Mining
# 12                         Supplier2_Comparative_Mining
# 13                         Supplier2_Comparative_Mining
# 14                         Supplier2_Comparative_Mining
# 15                         Supplier2_Comparative_Mining
# 16                         Supplier2_Comparative_Mining
# 17                         Supplier2_Comparative_Mining
# 18                         Supplier2_Comparative_Mining
# 19                         Supplier2_Comparative_Mining
# 20                         Supplier2_Comparative_Mining
#
# Event log column property                             Title  \
# 0                                                   Case ID
# 1                                                 Timestamp
# 2                                                  Activity
# 3                                                  eventID
# 4                                      case Spend area text
# 5                                        case Document Type
# 6                                  case Sub spend area text
# 7                            case Purch. Doc. Category name
# 8                                               case Vendor
# 9                                            case Item Type
# 10                                       case Item Category
# 11                           case Spend classification text
# 12                                              case Source
# 13                                                case Name
# 14                                case GR-Based Inv. Verif.
# 15                                                case Item
# 16                                        case concept:name
# 17                                       case Goods Receipt
# 18                                               event User
# 19                                       event org:resource
# 20                         event Cumulative net worth (EUR)
#
# Event log column property            Importance        Level       Data type  \
# 0                           Mandatory attribute   Case level          string
# 1                           Mandatory attribute  Event level  datetime64[ns]
# 2                           Mandatory attribute  Event level          string
# 3                           Mandatory attribute  Event level         float64
# 4                          Additional attribute   Case level          string
# 5                          Additional attribute   Case level          string
# 6                          Additional attribute   Case level          string
# 7                          Additional attribute   Case level          string
# 8                          Additional attribute   Case level          string
# 9                          Additional attribute   Case level          string
# 10                         Additional attribute   Case level          string
# 11                         Additional attribute   Case level          string
# 12                         Additional attribute   Case level          string
# 13                         Additional attribute   Case level          string
# 14                         Additional attribute   Case level           int64
# 15                         Additional attribute   Case level           int64
# 16                         Additional attribute   Case level          string
# 17                         Additional attribute   Case level          string
# 18                         Additional attribute  Event level          string
# 19                         Additional attribute  Event level          string
# 20                         Additional attribute  Event level         float64
#
# Event log column property Number of entries Number of unique entries  \
# 0                                    349526                    56127
# 1                                    349526                    42173
# 2                                    349526                       28
# 3                                    349526                      243
# 4                                    349526                       18
# 5                                    349526                        2
# 6                                    349526                      109
# 7                                    349526                        1
# 8                                    349526                     1109
# 9                                    349526                        5
# 10                                   349526                        3
# 11                                   349526                        4
# 12                                   349526                        1
# 13                                   349526                     1050
# 14                                   349526                        2
# 15                                   349526                      233
# 16                                   349526                    53733
# 17                                   349526                        1
# 18                                   349526                      333
# 19                                   349526                      333
# 20                                   349526                    11330
#
# Event log column property List up to 100 unique entries to view the structure of the event attributes  \
# 0                          [4507016139 1, 4507016140 10, 4507016140 20, 4...
# 1                          [2018-03-14T03:11:00.000000000, 2018-03-14T03:...
# 2                          [Record Service Entry Sheet, Record Goods Rece...
# 3                          [227000000000000.0, nan, 228000000000000.0, 22...
# 4                          [Logistics, Packaging, Sales, CAPEX & SOCS, La...
# 5                                       [Standard PO, Framework order, <NA>]
# 6                          [Road Packed, Metal Containers & Lids < 30L, L...
# 7                                                     [Purchase order, <NA>]
# 8                          [vendorID_0472, vendorID_0106, vendorID_0103, ...
# 9                          [Service, Standard, Third-party, Subcontractin...
# 10                         [Three way match, invoice after GR, Three way ...
# 11                                         [NPR, PR, OTHER, undefined, <NA>]
# 12                                               [sourceSystemID_0000, <NA>]
# 13                         [vendor_0457, vendor_0106, vendor_0103, vendor...
# 14                                                                    [1, 0]
# 15                         [1, 10, 20, 30, 100, 40, 50, 60, 70, 80, 90, 1...
# 16                         [4507016139_00001, 4507016140_00010, 450701614...
# 17                                                              [True, <NA>]
# 18                         [<NA>, batch_07, batch_03, user_029, user_030,...
# 19                         [<NA>, batch_07, batch_03, user_029, user_030,...
# 20                         [72.0, 30957.0, 1157.0, 2386.0, 21699.0, 144.0...
#
# Event log column property Length of the list of up to 100 unique entries  \
# 0                                                                    100
# 1                                                                    100
# 2                                                                     29
# 3                                                                    100
# 4                                                                     19
# 5                                                                      3
# 6                                                                    100
# 7                                                                      2
# 8                                                                    100
# 9                                                                      6
# 10                                                                     4
# 11                                                                     5
# 12                                                                     2
# 13                                                                   100
# 14                                                                     2
# 15                                                                   100
# 16                                                                   100
# 17                                                                     2
# 18                                                                   100
# 19                                                                   100
# 20                                                                   100
#
# Event log column property Number of duplicate entries  \
# 0                                              293399
# 1                                              307353
# 2                                              349498
# 3                                              349283
# 4                                              349508
# 5                                              349524
# 6                                              349417
# 7                                              349525
# 8                                              348417
# 9                                              349521
# 10                                             349523
# 11                                             349522
# 12                                             349525
# 13                                             348476
# 14                                             349524
# 15                                             349293
# 16                                             295793
# 17                                             349525
# 18                                             349193
# 19                                             349193
# 20                                             338196
#
# Event log column property Number of undefined entries  \
# 0                                                1495
# 1                                               16078
# 2                                               16078
# 3                                                 133
# 4                                                  11
# 5                                                  11
# 6                                                  11
# 7                                                 438
# 8                                                  11
# 9                                                  11
# 10                                                784
# 11                                                 11
# 12                                                 11
# 13                                                 11
# 14                                                  0
# 15                                                  0
# 16                                              16078
# 17                                              16078
# 18                                             103390
# 19                                             103390
# 20                                              16078
#
# Event log column property Percentage of undefined entries
# 0                                                    0.43
# 1                                                    4.60
# 2                                                    4.60
# 3                                                    0.04
# 4                                                    0.00
# 5                                                    0.00
# 6                                                    0.00
# 7                                                    0.13
# 8                                                    0.00
# 9                                                    0.00
# 10                                                   0.22
# 11                                                   0.00
# 12                                                   0.00
# 13                                                   0.00
# 14                                                   0.00
# 15                                                   0.00
# 16                                                   4.60
# 17                                                   4.60
# 18                                                  29.58
# 19                                                  29.58
# 20                                                   4.60

# %%
#This is an exploratory code snippet checking for the longest case to model the graph in a deperate database to reveal the event activity sequences in a directly follows graph
case_sizes = event_log_table.groupby(['caseID']).size()
#use of argmax() instead of max()
index_of_longest_case = case_sizes.argmax()
caseID_of_longest_case = case_sizes.index[index_of_longest_case] 
# assert caseID_of_longest_case == '4507000440 10'

# Without the .copy() suffix, we get: A value is trying to be set on a copy of a slice from a DataFrame
case_rows = event_log_table[event_log_table['caseID'] == caseID_of_longest_case].copy()
case_rows.sort_values(by='event time:timestamp', ascending=True, inplace=True)
case_rows.to_csv(f'analysis/longest_case_in_{event_log_name}.csv')

# a csv table is created in the analysis file which is then transformed into Neo4j commands
if not os.path.exists('analysis'):
    os.mkdir('analysis')
overview_table.to_csv(f'analysis/overview_{event_log_name}.csv')

(f'Written: datatype table to analysis/overview_{event_log_name}.csv')
# Out:
# 'Written: datatype table to analysis/overview_BPIC_Synthetic_Split_2.csv'

# %% [markdown]
# # End of Script 1 to generate the Meta-DataFrame
# Author: Kyle Smith <br>
# Script: For Masterthesis <br>
# University: University of Camerino & University of Applied Sciences Northwestern Switzerland
